# %% [markdown]
# <a href="https://colab.research.google.com/github/junhansong/deeplearning/blob/master/deeplearning/run_project/13_Boston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 라이브러리 호출

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

import numpy
import pandas as pd
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### seed 값 설정

# %%
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(3)

# %% [markdown]
# ### 데이터 로딩

# %%
df = pd.read_csv("https://raw.githubusercontent.com/junhansong/deeplearning/master/deeplearning/dataset/housing.csv", delim_whitespace=True, header=None)
'''
print(df.info())
print(df.head())
'''
# Out:
# '\nprint(df.info())\nprint(df.head())\n'

# %% [markdown]
# ###데이터 셋 분리

# %%
dataset = df.values
X = dataset[:,0:13]
Y = dataset[:,13]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=seed)

# %% [markdown]
# ### 모델 설정

# %%
model = Sequential()
model.add(Dense(30, input_dim=13, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))

# %% [markdown]
# ### 모델 컴파일

# %%
model.compile(loss='mean_squared_error',
              optimizer='adam')

# %% [markdown]
# ### 모델 실행

# %%
model.fit(X_train, Y_train, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 354/354 [==============================] - 0s 976us/step - loss: 1700.3443
# Epoch 2/200
# 354/354 [==============================] - 0s 118us/step - loss: 194.6200
# Epoch 3/200
# 354/354 [==============================] - 0s 122us/step - loss: 112.5905
# Epoch 4/200
# 354/354 [==============================] - 0s 117us/step - loss: 81.8547
# Epoch 5/200
# 354/354 [==============================] - 0s 126us/step - loss: 67.8956
# Epoch 6/200
# 354/354 [==============================] - 0s 127us/step - loss: 63.2675
# Epoch 7/200
# 354/354 [==============================] - 0s 120us/step - loss: 58.4390
# Epoch 8/200
# 354/354 [==============================] - 0s 122us/step - loss: 57.6857
# Epoch 9/200
# 354/354 [==============================] - 0s 137us/step - loss: 55.5897
# Epoch 10/200
# 354/354 [==============================] - 0s 139us/step - loss: 54.4821
# Epoch 11/200
# 354/354 [==============================] - 0s 125us/step - loss: 52.6920
# Epoch 12/200
# ...

# %% [markdown]
# ### 예측 값과 실제 값의 비교

# %%
Y_prediction = model.predict(X_test).flatten()
for i in range(10):
    label = Y_test[i]
    prediction = Y_prediction[i]
    print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label, prediction))
# Out:
# 실제가격: 22.600, 예상가격: 20.190
# 실제가격: 50.000, 예상가격: 24.216
# 실제가격: 23.000, 예상가격: 28.159
# 실제가격: 8.300, 예상가격: 13.293
# 실제가격: 21.200, 예상가격: 22.326
# 실제가격: 19.900, 예상가격: 23.273
# 실제가격: 20.600, 예상가격: 20.046
# 실제가격: 18.700, 예상가격: 26.360
# 실제가격: 16.100, 예상가격: 18.540
# 실제가격: 18.600, 예상가격: 11.116
