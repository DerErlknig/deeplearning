# %% [markdown]
# <a href="https://colab.research.google.com/github/junhansong/deeplearning/blob/master/deeplearning/run_project/20_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4624  g_loss:0.3282
# epoch:2  d_loss:0.5685  g_loss:0.1025
# epoch:3  d_loss:0.6584  g_loss:0.0836
# epoch:4  d_loss:0.5767  g_loss:0.1650
# epoch:5  d_loss:0.5087  g_loss:0.4209
# epoch:6  d_loss:0.4876  g_loss:0.6969
# epoch:7  d_loss:0.5092  g_loss:0.8694
# epoch:8  d_loss:0.4966  g_loss:0.8965
# epoch:9  d_loss:0.4858  g_loss:0.8719
# epoch:10  d_loss:0.4172  g_loss:0.7866
# epoch:11  d_loss:0.4383  g_loss:0.8100
# epoch:12  d_loss:0.4807  g_loss:0.8694
# epoch:13  d_loss:0.4729  g_loss:0.9202
# epoch:14  d_loss:0.5703  g_loss:0.9745
# epoch:15  d_loss:0.4727  g_loss:1.0477
# epoch:16  d_loss:0.4004  g_loss:1.0487
# epoch:17  d_loss:0.6235  g_loss:0.7707
# epoch:18  d_loss:0.5667  g_loss:0.6412
# epoch:19  d_loss:0.4569  g_loss:0.7277
# epoch:20  d_loss:0.4212  g_loss:0.8096
# epoch:21  d_loss:0.5023  g_loss:0.8362
# epoch:22  d_loss:0.5157  g_loss:0.6814
# epoch:23  d_loss:0.4571  g_loss:0.6288
# epoch:24  d_loss:0.4518  g_loss:0.6765
# epoch:25  d_loss:0.4695  g_loss:0.7268
# epoch:26  d_loss:0.5141  g_loss:0.7281
# epoch:27  d_loss:0.4787  g_loss:0.6030
# epoch:28  d_loss:0.4981  g_loss:0.5363
# epoch:29  d_loss:0.5250  g_loss:0.5565
# epoch:30  d_loss:0.4465  g_loss:0.6286
# epoch:31  d_loss:0.4850  g_loss:0.6964
# epoch:32  d_loss:0.4367  g_loss:0.5839
# epoch:33  d_loss:0.4474  g_loss:0.6066
# epoch:34  d_loss:0.3403  g_loss:0.6845
# epoch:35  d_loss:0.3769  g_loss:0.8643
# epoch:36  d_loss:0.4461  g_loss:0.5753
# epoch:37  d_loss:0.3644  g_loss:0.7392
# epoch:38  d_loss:0.3538  g_loss:0.8925
# epoch:39  d_loss:0.2402  g_loss:1.1669
# epoch:40  d_loss:0.3218  g_loss:1.2255
# epoch:41  d_loss:0.4382  g_loss:0.9431
# epoch:42  d_loss:0.3744  g_loss:0.8154
# epoch:43  d_loss:0.2530  g_loss:1.1235
# epoch:44  d_loss:0.2044  g_loss:1.4017
# epoch:45  d_loss:0.1590  g_loss:2.1818
# epoch:46  d_loss:0.3098  g_loss:1.8100
# epoch:47  d_loss:0.2282  g_loss:1.5364
# epoch:48  d_loss:0.2621  g_loss:1.4498
# epoch:49  d_loss:0.2994  g_loss:1.3824
# epoch:50  d_loss:0.2779  g_loss:1.6137
# epoch:51  d_loss:0.3615  g_loss:2.1434
# epoch:52  d_loss:0.3277  g_loss:2.2529
# epoch:53  d_loss:0.1727  g_loss:1.8732
# epoch:54  d_loss:0.1061  g_loss:2.0782
# epoch:55  d_loss:0.1093  g_loss:2.4814
# epoch:56  d_loss:0.1727  g_loss:2.0525
# epoch:57  d_loss:0.1697  g_loss:2.7392
# epoch:58  d_loss:0.1793  g_loss:2.8575
# epoch:59  d_loss:0.2323  g_loss:2.4401
# epoch:60  d_loss:0.4960  g_loss:2.0993
# epoch:61  d_loss:0.5810  g_loss:3.0609
# epoch:62  d_loss:0.7424  g_loss:2.8063
# epoch:63  d_loss:0.9068  g_loss:2.2697
# epoch:64  d_loss:0.6956  g_loss:2.4581
# epoch:65  d_loss:0.6956  g_loss:3.0880
# epoch:66  d_loss:0.4203  g_loss:3.0743
# epoch:67  d_loss:0.2130  g_loss:3.8091
# epoch:68  d_loss:0.2074  g_loss:3.8403
# epoch:69  d_loss:0.4023  g_loss:3.2895
# epoch:70  d_loss:0.5342  g_loss:2.4102
# epoch:71  d_loss:0.2925  g_loss:2.4511
# epoch:72  d_loss:0.6059  g_loss:2.1935
# epoch:73  d_loss:0.4025  g_loss:2.2907
# epoch:74  d_loss:0.8652  g_loss:1.3619
# epoch:75  d_loss:0.9373  g_loss:1.0964
# epoch:76  d_loss:0.7066  g_loss:1.4014
# epoch:77  d_loss:0.7551  g_loss:1.9226
# epoch:78  d_loss:0.5676  g_loss:1.9759
# epoch:79  d_loss:0.3415  g_loss:2.2386
# epoch:80  d_loss:0.2530  g_loss:2.7417
# epoch:81  d_loss:0.1536  g_loss:3.1627
# epoch:82  d_loss:0.1394  g_loss:3.8119
# epoch:83  d_loss:0.1053  g_loss:4.7124
# epoch:84  d_loss:0.1678  g_loss:4.1494
# epoch:85  d_loss:0.4129  g_loss:3.9841
# epoch:86  d_loss:0.3290  g_loss:4.4737
# epoch:87  d_loss:0.5016  g_loss:4.6767
# epoch:88  d_loss:0.9185  g_loss:3.9119
# epoch:89  d_loss:1.1849  g_loss:3.2075
# epoch:90  d_loss:0.7322  g_loss:4.2866
# epoch:91  d_loss:1.0075  g_loss:3.9839
# epoch:92  d_loss:1.3029  g_loss:2.7805
# epoch:93  d_loss:1.3624  g_loss:2.2153
# epoch:94  d_loss:1.0472  g_loss:1.6098
# epoch:95  d_loss:0.6882  g_loss:2.0879
# epoch:96  d_loss:0.6932  g_loss:1.6928
# epoch:97  d_loss:0.5797  g_loss:1.9134
# epoch:98  d_loss:0.5030  g_loss:1.7227
# epoch:99  d_loss:0.5212  g_loss:1.6396
# epoch:100  d_loss:0.5261  g_loss:1.5912
# epoch:101  d_loss:0.3499  g_loss:1.7774
# epoch:102  d_loss:0.3597  g_loss:1.7109
# epoch:103  d_loss:0.4497  g_loss:1.5140
# epoch:104  d_loss:0.3105  g_loss:1.4733
# epoch:105  d_loss:0.4459  g_loss:1.2763
# epoch:106  d_loss:0.4487  g_loss:1.2554
# epoch:107  d_loss:0.3630  g_loss:1.3511
# epoch:108  d_loss:0.4117  g_loss:1.2990
# epoch:109  d_loss:0.3031  g_loss:1.4472
# epoch:110  d_loss:0.3422  g_loss:1.4275
# epoch:111  d_loss:0.4288  g_loss:1.3265
# epoch:112  d_loss:0.3706  g_loss:1.2897
# epoch:113  d_loss:0.4858  g_loss:0.9943
# epoch:114  d_loss:0.5259  g_loss:1.0409
# epoch:115  d_loss:0.5140  g_loss:0.6796
# epoch:116  d_loss:0.4866  g_loss:0.9255
# epoch:117  d_loss:0.4545  g_loss:0.8696
# epoch:118  d_loss:0.5357  g_loss:1.1394
# epoch:119  d_loss:0.4257  g_loss:1.0000
# epoch:120  d_loss:0.5845  g_loss:0.7865
# epoch:121  d_loss:0.6759  g_loss:0.7389
# epoch:122  d_loss:0.8231  g_loss:0.6371
# epoch:123  d_loss:0.7155  g_loss:0.8322
# epoch:124  d_loss:0.6299  g_loss:0.8454
# epoch:125  d_loss:0.8840  g_loss:0.8704
# epoch:126  d_loss:0.6628  g_loss:0.9376
# epoch:127  d_loss:0.6707  g_loss:1.0102
# epoch:128  d_loss:0.7043  g_loss:0.9112
# epoch:129  d_loss:0.6349  g_loss:0.9373
# epoch:130  d_loss:0.5770  g_loss:0.9852
# epoch:131  d_loss:0.6071  g_loss:1.2588
# epoch:132  d_loss:0.5930  g_loss:1.1936
# epoch:133  d_loss:0.6109  g_loss:1.2748
# epoch:134  d_loss:0.5726  g_loss:1.3133
# epoch:135  d_loss:0.5168  g_loss:1.5129
# epoch:136  d_loss:0.4837  g_loss:1.5170
# epoch:137  d_loss:0.3779  g_loss:1.7186
# epoch:138  d_loss:0.4065  g_loss:1.7799
# epoch:139  d_loss:0.3508  g_loss:2.0942
# epoch:140  d_loss:0.3023  g_loss:2.3387
# epoch:141  d_loss:0.3319  g_loss:2.3699
# epoch:142  d_loss:0.3302  g_loss:2.1913
# epoch:143  d_loss:0.3092  g_loss:2.3035
# epoch:144  d_loss:0.3076  g_loss:2.2388
# epoch:145  d_loss:0.2854  g_loss:2.7591
# epoch:146  d_loss:0.3007  g_loss:3.2179
# epoch:147  d_loss:0.6134  g_loss:2.1079
# epoch:148  d_loss:0.4893  g_loss:2.1319
# epoch:149  d_loss:0.5333  g_loss:2.1954
# epoch:150  d_loss:0.4525  g_loss:2.7308
# epoch:151  d_loss:0.6859  g_loss:2.4754
# epoch:152  d_loss:0.8045  g_loss:1.8871
# epoch:153  d_loss:0.7559  g_loss:1.3779
# epoch:154  d_loss:0.5736  g_loss:1.5086
# epoch:155  d_loss:0.8395  g_loss:1.3077
# epoch:156  d_loss:0.7222  g_loss:1.5801
# epoch:157  d_loss:0.6225  g_loss:1.6436
# epoch:158  d_loss:0.6537  g_loss:1.4580
# epoch:159  d_loss:0.5451  g_loss:1.4769
# epoch:160  d_loss:0.6722  g_loss:1.6025
# epoch:161  d_loss:0.7254  g_loss:1.3527
# epoch:162  d_loss:0.5948  g_loss:1.3578
# epoch:163  d_loss:0.5348  g_loss:1.3952
# epoch:164  d_loss:0.6340  g_loss:1.3640
# epoch:165  d_loss:0.4294  g_loss:1.6021
# epoch:166  d_loss:0.4985  g_loss:1.8555
# epoch:167  d_loss:0.5666  g_loss:1.8823
# epoch:168  d_loss:0.5081  g_loss:1.5587
# epoch:169  d_loss:0.5071  g_loss:1.4657
# epoch:170  d_loss:0.4454  g_loss:1.2964
# epoch:171  d_loss:0.5055  g_loss:1.2070
# epoch:172  d_loss:0.4712  g_loss:1.3216
# epoch:173  d_loss:0.4022  g_loss:1.3876
# epoch:174  d_loss:0.4645  g_loss:1.3867
# epoch:175  d_loss:0.4588  g_loss:1.9123
# epoch:176  d_loss:0.5878  g_loss:1.5972
# epoch:177  d_loss:0.4747  g_loss:1.8434
# epoch:178  d_loss:0.3524  g_loss:1.8592
# epoch:179  d_loss:0.4454  g_loss:1.5050
# epoch:180  d_loss:0.4470  g_loss:1.5092
# epoch:181  d_loss:0.4456  g_loss:1.6115
# epoch:182  d_loss:0.4112  g_loss:1.8602
# epoch:183  d_loss:0.3413  g_loss:1.5463
# epoch:184  d_loss:0.3503  g_loss:1.5288
# epoch:185  d_loss:0.4753  g_loss:1.3377
# epoch:186  d_loss:0.3833  g_loss:1.5654
# epoch:187  d_loss:0.4439  g_loss:1.5975
# epoch:188  d_loss:0.4651  g_loss:1.7311
# epoch:189  d_loss:0.3457  g_loss:1.7239
# epoch:190  d_loss:0.3363  g_loss:1.8268
# epoch:191  d_loss:0.5028  g_loss:1.6005
# epoch:192  d_loss:0.4628  g_loss:1.6865
# epoch:193  d_loss:0.5066  g_loss:1.5504
# epoch:194  d_loss:0.4561  g_loss:1.5172
# epoch:195  d_loss:0.3839  g_loss:1.8806
# epoch:196  d_loss:0.5332  g_loss:1.4083
# epoch:197  d_loss:0.3486  g_loss:1.2760
# epoch:198  d_loss:0.5141  g_loss:1.5026
# epoch:199  d_loss:0.5564  g_loss:1.3791
# epoch:200  d_loss:0.4961  g_loss:1.5962
# epoch:201  d_loss:0.4444  g_loss:1.6008
# epoch:202  d_loss:0.6220  g_loss:1.4012
# epoch:203  d_loss:0.5178  g_loss:1.4418
# epoch:204  d_loss:0.5870  g_loss:1.5341
# epoch:205  d_loss:0.5784  g_loss:1.2531
# epoch:206  d_loss:0.4950  g_loss:1.3761
# epoch:207  d_loss:0.5743  g_loss:1.5912
# epoch:208  d_loss:0.6601  g_loss:1.5389
# epoch:209  d_loss:0.5179  g_loss:1.6830
# epoch:210  d_loss:0.5828  g_loss:1.4730
# epoch:211  d_loss:0.4998  g_loss:1.6386
# epoch:212  d_loss:0.5384  g_loss:1.6506
# epoch:213  d_loss:0.5916  g_loss:1.7126
# epoch:214  d_loss:0.5551  g_loss:1.5507
# epoch:215  d_loss:0.4586  g_loss:1.6208
# epoch:216  d_loss:0.5856  g_loss:1.6941
# epoch:217  d_loss:0.4796  g_loss:1.4397
# epoch:218  d_loss:0.4958  g_loss:1.8054
# epoch:219  d_loss:0.6008  g_loss:1.7338
# epoch:220  d_loss:0.4571  g_loss:1.9849
# epoch:221  d_loss:0.5213  g_loss:1.5638
# epoch:222  d_loss:0.5949  g_loss:1.4144
# epoch:223  d_loss:0.6045  g_loss:1.6101
# epoch:224  d_loss:0.5364  g_loss:1.8657
# epoch:225  d_loss:0.5609  g_loss:1.6609
# epoch:226  d_loss:0.4235  g_loss:1.6099
# epoch:227  d_loss:0.5555  g_loss:1.6000
# epoch:228  d_loss:0.5303  g_loss:1.5001
# epoch:229  d_loss:0.5105  g_loss:1.2223
# epoch:230  d_loss:0.5218  g_loss:1.6692
# epoch:231  d_loss:0.5241  g_loss:1.8254
# epoch:232  d_loss:0.4784  g_loss:1.9554
# epoch:233  d_loss:0.5336  g_loss:1.6824
# epoch:234  d_loss:0.5306  g_loss:1.2472
# epoch:235  d_loss:0.4483  g_loss:1.3631
# epoch:236  d_loss:0.4427  g_loss:1.4174
# epoch:237  d_loss:0.3986  g_loss:1.9797
# epoch:238  d_loss:0.4081  g_loss:1.7823
# epoch:239  d_loss:0.3738  g_loss:2.0146
# epoch:240  d_loss:0.4491  g_loss:1.5578
# epoch:241  d_loss:0.5632  g_loss:1.7181
# epoch:242  d_loss:0.5038  g_loss:1.3220
# epoch:243  d_loss:0.4950  g_loss:1.3122
# epoch:244  d_loss:0.4388  g_loss:1.6325
# epoch:245  d_loss:0.4055  g_loss:1.6566
# epoch:246  d_loss:0.5113  g_loss:1.5840
# epoch:247  d_loss:0.5181  g_loss:1.9002
# epoch:248  d_loss:0.4053  g_loss:2.0615
# epoch:249  d_loss:0.5034  g_loss:1.7277
# epoch:250  d_loss:0.4003  g_loss:1.9503
# epoch:251  d_loss:0.4460  g_loss:1.6427
# epoch:252  d_loss:0.4041  g_loss:1.3984
# epoch:253  d_loss:0.4998  g_loss:1.5211
# epoch:254  d_loss:0.4807  g_loss:1.9252
# epoch:255  d_loss:0.6024  g_loss:1.7377
# epoch:256  d_loss:0.5190  g_loss:1.5736
# epoch:257  d_loss:0.4013  g_loss:1.8676
# epoch:258  d_loss:0.6438  g_loss:1.5157
# epoch:259  d_loss:0.4980  g_loss:1.7571
# epoch:260  d_loss:0.4845  g_loss:1.5184
# epoch:261  d_loss:0.4790  g_loss:1.5678
# epoch:262  d_loss:0.4942  g_loss:1.7420
# epoch:263  d_loss:0.4685  g_loss:1.8374
# epoch:264  d_loss:0.4328  g_loss:1.5236
# epoch:265  d_loss:0.5584  g_loss:1.5618
# epoch:266  d_loss:0.4240  g_loss:1.4942
# epoch:267  d_loss:0.4045  g_loss:1.9123
# epoch:268  d_loss:0.5275  g_loss:1.7452
# epoch:269  d_loss:0.5947  g_loss:1.7790
# epoch:270  d_loss:0.4208  g_loss:2.1065
# epoch:271  d_loss:0.5313  g_loss:2.2055
# epoch:272  d_loss:0.4809  g_loss:2.1430
# epoch:273  d_loss:0.4490  g_loss:2.0123
# epoch:274  d_loss:0.5015  g_loss:1.6643
# epoch:275  d_loss:0.3913  g_loss:1.7217
# epoch:276  d_loss:0.5519  g_loss:1.5305
# epoch:277  d_loss:0.4115  g_loss:2.4480
# epoch:278  d_loss:0.3709  g_loss:2.1794
# epoch:279  d_loss:0.4758  g_loss:2.0132
# epoch:280  d_loss:0.3662  g_loss:1.8241
# epoch:281  d_loss:0.4057  g_loss:2.4339
# epoch:282  d_loss:0.4309  g_loss:2.2656
# epoch:283  d_loss:0.3315  g_loss:2.3835
# epoch:284  d_loss:0.4097  g_loss:2.4613
# epoch:285  d_loss:0.3908  g_loss:2.3828
# epoch:286  d_loss:0.3283  g_loss:2.3752
# epoch:287  d_loss:0.3188  g_loss:2.2838
# epoch:288  d_loss:0.3380  g_loss:2.4613
# epoch:289  d_loss:0.4336  g_loss:1.9119
# epoch:290  d_loss:0.4259  g_loss:1.8375
# epoch:291  d_loss:0.7513  g_loss:1.9590
# epoch:292  d_loss:0.4235  g_loss:2.2582
# epoch:293  d_loss:0.4086  g_loss:2.1477
# epoch:294  d_loss:0.4038  g_loss:1.9312
# epoch:295  d_loss:0.5549  g_loss:1.5654
# epoch:296  d_loss:0.4706  g_loss:1.4905
# epoch:297  d_loss:0.6094  g_loss:1.7480
# epoch:298  d_loss:0.5950  g_loss:1.9027
# epoch:299  d_loss:0.5059  g_loss:2.0210
# epoch:300  d_loss:0.8196  g_loss:1.5852
# epoch:301  d_loss:0.7395  g_loss:1.1012
# epoch:302  d_loss:0.6214  g_loss:1.3199
# epoch:303  d_loss:0.7267  g_loss:1.2890
# epoch:304  d_loss:0.8665  g_loss:1.1144
# epoch:305  d_loss:0.6666  g_loss:1.3198
# epoch:306  d_loss:0.6429  g_loss:1.4654
# epoch:307  d_loss:0.6549  g_loss:1.5991
# epoch:308  d_loss:0.4969  g_loss:1.7610
# epoch:309  d_loss:0.5882  g_loss:1.4392
# epoch:310  d_loss:0.5422  g_loss:1.3841
# epoch:311  d_loss:0.4361  g_loss:1.5024
# epoch:312  d_loss:0.4563  g_loss:1.4600
# epoch:313  d_loss:0.4976  g_loss:1.6050
# epoch:314  d_loss:0.4775  g_loss:1.7187
# epoch:315  d_loss:0.4711  g_loss:1.9870
# epoch:316  d_loss:0.4144  g_loss:1.7693
# epoch:317  d_loss:0.4258  g_loss:1.9348
# epoch:318  d_loss:0.3518  g_loss:2.0007
# epoch:319  d_loss:0.3640  g_loss:2.0257
# epoch:320  d_loss:0.4061  g_loss:1.9928
# epoch:321  d_loss:0.3862  g_loss:1.8354
# epoch:322  d_loss:0.3131  g_loss:1.9972
# epoch:323  d_loss:0.3671  g_loss:1.9177
# epoch:324  d_loss:0.3690  g_loss:1.6390
# epoch:325  d_loss:0.3607  g_loss:1.7298
# epoch:326  d_loss:0.4911  g_loss:1.5202
# epoch:327  d_loss:0.2965  g_loss:2.0546
# epoch:328  d_loss:0.3409  g_loss:2.0561
# epoch:329  d_loss:0.4028  g_loss:1.9593
# epoch:330  d_loss:0.3406  g_loss:2.3225
# epoch:331  d_loss:0.4037  g_loss:2.2849
# epoch:332  d_loss:0.4704  g_loss:1.8995
# epoch:333  d_loss:0.5406  g_loss:1.9525
# epoch:334  d_loss:0.3975  g_loss:1.8805
# epoch:335  d_loss:0.4404  g_loss:1.8310
# epoch:336  d_loss:0.3191  g_loss:1.8585
# epoch:337  d_loss:0.3678  g_loss:1.7693
# epoch:338  d_loss:0.3898  g_loss:1.6748
# epoch:339  d_loss:0.4648  g_loss:1.7000
# epoch:340  d_loss:0.4168  g_loss:1.8663
# epoch:341  d_loss:0.4299  g_loss:1.9693
# epoch:342  d_loss:0.3880  g_loss:2.0168
# epoch:343  d_loss:0.5290  g_loss:2.0426
# epoch:344  d_loss:0.4663  g_loss:1.9881
# epoch:345  d_loss:0.5227  g_loss:2.5020
# epoch:346  d_loss:0.6457  g_loss:1.7944
# epoch:347  d_loss:0.3829  g_loss:1.9756
# epoch:348  d_loss:0.3999  g_loss:1.9866
# epoch:349  d_loss:0.4623  g_loss:2.0654
# epoch:350  d_loss:0.6006  g_loss:1.5511
# epoch:351  d_loss:0.3670  g_loss:2.0927
# epoch:352  d_loss:0.4884  g_loss:1.8767
# epoch:353  d_loss:0.5025  g_loss:1.9110
# epoch:354  d_loss:0.6607  g_loss:1.6413
# epoch:355  d_loss:0.4944  g_loss:1.5490
# epoch:356  d_loss:0.4397  g_loss:1.5272
# epoch:357  d_loss:0.4708  g_loss:1.8264
# epoch:358  d_loss:0.4253  g_loss:2.1594
# epoch:359  d_loss:0.4227  g_loss:2.7307
# epoch:360  d_loss:0.4655  g_loss:3.1395
# epoch:361  d_loss:0.3376  g_loss:2.5502
# epoch:362  d_loss:0.3869  g_loss:2.0621
# epoch:363  d_loss:0.4441  g_loss:1.7466
# epoch:364  d_loss:0.4308  g_loss:1.6713
# epoch:365  d_loss:0.3628  g_loss:2.4081
# epoch:366  d_loss:0.2917  g_loss:2.6114
# epoch:367  d_loss:0.4651  g_loss:2.5080
# epoch:368  d_loss:0.4497  g_loss:1.9485
# epoch:369  d_loss:0.4799  g_loss:1.8120
# epoch:370  d_loss:0.5169  g_loss:1.6894
# epoch:371  d_loss:0.3434  g_loss:2.3284
# epoch:372  d_loss:0.3897  g_loss:2.6472
# epoch:373  d_loss:0.2600  g_loss:2.6478
# epoch:374  d_loss:0.3415  g_loss:2.1898
# epoch:375  d_loss:0.3799  g_loss:2.0969
# epoch:376  d_loss:0.3855  g_loss:1.9408
# epoch:377  d_loss:0.3367  g_loss:1.8408
# epoch:378  d_loss:0.3044  g_loss:2.4766
# epoch:379  d_loss:0.2270  g_loss:2.4791
# epoch:380  d_loss:0.3866  g_loss:2.2708
# epoch:381  d_loss:0.3641  g_loss:2.5192
# epoch:382  d_loss:0.2211  g_loss:2.1142
# epoch:383  d_loss:0.3070  g_loss:2.1068
# epoch:384  d_loss:0.2810  g_loss:1.7838
# epoch:385  d_loss:0.3592  g_loss:1.8103
# epoch:386  d_loss:0.2469  g_loss:2.5418
# epoch:387  d_loss:0.2408  g_loss:2.3149
# epoch:388  d_loss:0.3676  g_loss:2.2663
# epoch:389  d_loss:0.2559  g_loss:2.7930
# epoch:390  d_loss:0.3542  g_loss:2.5133
# epoch:391  d_loss:0.3701  g_loss:1.6404
# epoch:392  d_loss:0.3545  g_loss:1.8831
# epoch:393  d_loss:0.3238  g_loss:2.2014
# epoch:394  d_loss:0.2731  g_loss:2.1941
# epoch:395  d_loss:0.3973  g_loss:2.4773
# epoch:396  d_loss:0.2490  g_loss:2.7829
# epoch:397  d_loss:0.4213  g_loss:2.2717
# epoch:398  d_loss:0.4119  g_loss:2.1358
# epoch:399  d_loss:0.4260  g_loss:2.3042
# epoch:400  d_loss:0.4859  g_loss:1.8291
# epoch:401  d_loss:0.4091  g_loss:1.8188
# epoch:402  d_loss:0.3317  g_loss:1.9896
# epoch:403  d_loss:0.4209  g_loss:1.8553
# epoch:404  d_loss:0.4095  g_loss:1.9179
# epoch:405  d_loss:0.4386  g_loss:2.0443
# epoch:406  d_loss:0.4734  g_loss:1.8231
# epoch:407  d_loss:0.3225  g_loss:1.7818
# epoch:408  d_loss:0.4491  g_loss:1.7140
# epoch:409  d_loss:0.4186  g_loss:1.8197
# epoch:410  d_loss:0.4551  g_loss:1.7467
# epoch:411  d_loss:0.4342  g_loss:1.9632
# epoch:412  d_loss:0.4037  g_loss:1.8772
# epoch:413  d_loss:0.4820  g_loss:1.8088
# epoch:414  d_loss:0.4736  g_loss:1.3327
# epoch:415  d_loss:0.4650  g_loss:1.7969
# epoch:416  d_loss:0.3770  g_loss:2.0556
# epoch:417  d_loss:0.3781  g_loss:2.2244
# epoch:418  d_loss:0.4442  g_loss:2.0551
# epoch:419  d_loss:0.3782  g_loss:1.9577
# epoch:420  d_loss:0.3758  g_loss:2.1789
# epoch:421  d_loss:0.3406  g_loss:1.9432
# epoch:422  d_loss:0.4315  g_loss:2.0303
# epoch:423  d_loss:0.3204  g_loss:1.9110
# epoch:424  d_loss:0.4099  g_loss:2.1988
# epoch:425  d_loss:0.2621  g_loss:2.6114
# epoch:426  d_loss:0.3008  g_loss:2.7358
# epoch:427  d_loss:0.3818  g_loss:2.6464
# epoch:428  d_loss:0.2561  g_loss:2.4600
# epoch:429  d_loss:0.3401  g_loss:2.6805
# epoch:430  d_loss:0.3446  g_loss:1.8682
# epoch:431  d_loss:0.3027  g_loss:2.1139
# epoch:432  d_loss:0.4007  g_loss:2.3066
# epoch:433  d_loss:0.3100  g_loss:2.8518
# epoch:434  d_loss:0.4356  g_loss:2.4553
# epoch:435  d_loss:0.3299  g_loss:1.9615
# epoch:436  d_loss:0.3602  g_loss:1.8379
# epoch:437  d_loss:0.3377  g_loss:1.9728
# epoch:438  d_loss:0.3455  g_loss:1.9747
# epoch:439  d_loss:0.2613  g_loss:2.1160
# epoch:440  d_loss:0.3557  g_loss:2.3044
# epoch:441  d_loss:0.3273  g_loss:2.4014
# epoch:442  d_loss:0.3442  g_loss:2.4017
# epoch:443  d_loss:0.3174  g_loss:2.4076
# epoch:444  d_loss:0.4562  g_loss:2.3886
# epoch:445  d_loss:0.3301  g_loss:2.2360
# epoch:446  d_loss:0.3438  g_loss:1.6697
# epoch:447  d_loss:0.3525  g_loss:2.0483
# epoch:448  d_loss:0.4117  g_loss:2.0193
# epoch:449  d_loss:0.3052  g_loss:1.8761
# epoch:450  d_loss:0.4906  g_loss:1.5732
# epoch:451  d_loss:0.4655  g_loss:2.2535
# epoch:452  d_loss:0.4798  g_loss:2.2385
# epoch:453  d_loss:0.3362  g_loss:2.0318
# epoch:454  d_loss:0.3369  g_loss:1.7167
# epoch:455  d_loss:0.5053  g_loss:1.6264
# epoch:456  d_loss:0.4015  g_loss:1.5445
# epoch:457  d_loss:0.4151  g_loss:1.7397
# epoch:458  d_loss:0.4823  g_loss:1.7642
# epoch:459  d_loss:0.3006  g_loss:2.1478
# epoch:460  d_loss:0.3103  g_loss:1.9197
# epoch:461  d_loss:0.4112  g_loss:2.0033
# epoch:462  d_loss:0.4170  g_loss:1.6864
# epoch:463  d_loss:0.4017  g_loss:1.6964
# epoch:464  d_loss:0.2901  g_loss:2.1865
# epoch:465  d_loss:0.3238  g_loss:2.1449
# epoch:466  d_loss:0.3599  g_loss:1.7281
# epoch:467  d_loss:0.3726  g_loss:2.1729
# epoch:468  d_loss:0.2122  g_loss:1.8534
# epoch:469  d_loss:0.3546  g_loss:2.0165
# epoch:470  d_loss:0.3471  g_loss:2.3281
# epoch:471  d_loss:0.5053  g_loss:2.0552
# epoch:472  d_loss:0.3482  g_loss:2.1076
# epoch:473  d_loss:0.2668  g_loss:1.9406
# epoch:474  d_loss:0.3381  g_loss:1.9485
# epoch:475  d_loss:0.4243  g_loss:1.9507
# epoch:476  d_loss:0.2146  g_loss:2.4811
# epoch:477  d_loss:0.2303  g_loss:2.9513
# epoch:478  d_loss:0.2638  g_loss:2.2872
# epoch:479  d_loss:0.2238  g_loss:2.9183
# epoch:480  d_loss:0.3871  g_loss:2.5435
# epoch:481  d_loss:0.3125  g_loss:2.1800
# epoch:482  d_loss:0.2798  g_loss:2.3509
# epoch:483  d_loss:0.2335  g_loss:2.9299
# epoch:484  d_loss:0.2195  g_loss:2.9990
# epoch:485  d_loss:0.3201  g_loss:2.5695
# epoch:486  d_loss:0.3083  g_loss:2.1813
# epoch:487  d_loss:0.2130  g_loss:2.1748
# epoch:488  d_loss:0.2329  g_loss:2.2258
# epoch:489  d_loss:0.3717  g_loss:2.3754
# epoch:490  d_loss:0.2473  g_loss:2.5426
# epoch:491  d_loss:0.2072  g_loss:3.0481
# epoch:492  d_loss:0.2887  g_loss:2.8344
# epoch:493  d_loss:0.2578  g_loss:1.9938
# epoch:494  d_loss:0.2129  g_loss:2.4439
# epoch:495  d_loss:0.3750  g_loss:2.3209
# epoch:496  d_loss:0.2841  g_loss:2.9359
# epoch:497  d_loss:0.5125  g_loss:2.7041
# epoch:498  d_loss:0.4708  g_loss:2.1673
# epoch:499  d_loss:0.5119  g_loss:1.6311
# epoch:500  d_loss:0.4424  g_loss:1.9742
# epoch:501  d_loss:0.4547  g_loss:2.5063
# epoch:502  d_loss:0.4568  g_loss:2.4721
# epoch:503  d_loss:0.4607  g_loss:2.0038
# epoch:504  d_loss:0.4306  g_loss:2.1739
# epoch:505  d_loss:0.3022  g_loss:2.5416
# epoch:506  d_loss:0.6368  g_loss:1.9463
# epoch:507  d_loss:0.3819  g_loss:1.8139
# epoch:508  d_loss:0.2971  g_loss:2.0820
# epoch:509  d_loss:0.3079  g_loss:2.7853
# epoch:510  d_loss:0.3746  g_loss:2.9360
# epoch:511  d_loss:0.3171  g_loss:3.1888
# epoch:512  d_loss:0.4728  g_loss:2.6034
# epoch:513  d_loss:0.2148  g_loss:3.2046
# epoch:514  d_loss:0.1768  g_loss:2.8208
# epoch:515  d_loss:0.2476  g_loss:2.8551
# epoch:516  d_loss:0.1671  g_loss:3.1921
# epoch:517  d_loss:0.2785  g_loss:3.3128
# epoch:518  d_loss:0.3673  g_loss:3.0405
# epoch:519  d_loss:0.2017  g_loss:2.9354
# epoch:520  d_loss:0.1838  g_loss:2.9903
# epoch:521  d_loss:0.1705  g_loss:2.8623
# epoch:522  d_loss:0.1666  g_loss:3.8833
# epoch:523  d_loss:0.1860  g_loss:3.2857
# epoch:524  d_loss:0.2151  g_loss:3.3442
# epoch:525  d_loss:0.2431  g_loss:2.5715
# epoch:526  d_loss:0.1780  g_loss:2.5860
# epoch:527  d_loss:0.1898  g_loss:2.9873
# epoch:528  d_loss:0.1592  g_loss:2.9128
# epoch:529  d_loss:0.2322  g_loss:2.9396
# epoch:530  d_loss:0.4035  g_loss:2.1112
# epoch:531  d_loss:0.2636  g_loss:2.9405
# epoch:532  d_loss:0.3515  g_loss:2.6203
# epoch:533  d_loss:0.3355  g_loss:1.8807
# epoch:534  d_loss:0.2431  g_loss:2.3704
# epoch:535  d_loss:0.3552  g_loss:2.1490
# epoch:536  d_loss:0.2688  g_loss:2.6946
# epoch:537  d_loss:0.3939  g_loss:2.4968
# epoch:538  d_loss:0.4430  g_loss:1.9929
# epoch:539  d_loss:0.5440  g_loss:1.8260
# epoch:540  d_loss:0.3189  g_loss:2.0695
# epoch:541  d_loss:0.1417  g_loss:2.7089
# epoch:542  d_loss:0.3055  g_loss:3.4976
# epoch:543  d_loss:0.4604  g_loss:2.5764
# epoch:544  d_loss:0.3197  g_loss:2.2791
# epoch:545  d_loss:0.3377  g_loss:1.4038
# epoch:546  d_loss:0.2946  g_loss:2.2812
# epoch:547  d_loss:0.1673  g_loss:2.9208
# epoch:548  d_loss:0.2140  g_loss:3.9320
# epoch:549  d_loss:0.2425  g_loss:3.4344
# epoch:550  d_loss:0.1697  g_loss:3.1770
# epoch:551  d_loss:0.1220  g_loss:4.1048
# epoch:552  d_loss:0.2506  g_loss:3.0402
# epoch:553  d_loss:0.2979  g_loss:2.3630
# epoch:554  d_loss:0.2548  g_loss:2.3368
# epoch:555  d_loss:0.2163  g_loss:3.0613
# epoch:556  d_loss:0.1766  g_loss:3.5682
# epoch:557  d_loss:0.1448  g_loss:3.1716
# epoch:558  d_loss:0.2638  g_loss:2.9877
# epoch:559  d_loss:0.2649  g_loss:2.2566
# epoch:560  d_loss:0.5665  g_loss:1.5756
# epoch:561  d_loss:0.4197  g_loss:1.2676
# epoch:562  d_loss:0.1932  g_loss:2.1591
# epoch:563  d_loss:0.2628  g_loss:2.1234
# epoch:564  d_loss:0.2944  g_loss:2.4065
# epoch:565  d_loss:0.2020  g_loss:2.1455
# epoch:566  d_loss:0.2453  g_loss:2.4582
# epoch:567  d_loss:0.2178  g_loss:2.6787
# epoch:568  d_loss:0.3484  g_loss:2.4211
# epoch:569  d_loss:0.2598  g_loss:2.4131
# epoch:570  d_loss:0.2480  g_loss:2.4647
# epoch:571  d_loss:0.4952  g_loss:1.9255
# epoch:572  d_loss:0.2392  g_loss:1.8186
# epoch:573  d_loss:0.2584  g_loss:2.6463
# epoch:574  d_loss:0.3188  g_loss:2.6321
# epoch:575  d_loss:0.2939  g_loss:2.3677
# epoch:576  d_loss:0.3962  g_loss:2.8866
# epoch:577  d_loss:0.1838  g_loss:2.6813
# epoch:578  d_loss:0.2487  g_loss:2.2947
# epoch:579  d_loss:0.2159  g_loss:2.8591
# epoch:580  d_loss:0.3367  g_loss:2.2408
# epoch:581  d_loss:0.1897  g_loss:3.1849
# epoch:582  d_loss:0.1302  g_loss:3.0343
# epoch:583  d_loss:0.2287  g_loss:2.6033
# epoch:584  d_loss:0.2369  g_loss:2.5717
# epoch:585  d_loss:0.1810  g_loss:2.2604
# epoch:586  d_loss:0.1591  g_loss:2.7553
# epoch:587  d_loss:0.0955  g_loss:3.1409
# epoch:588  d_loss:0.2631  g_loss:3.1265
# epoch:589  d_loss:0.2105  g_loss:2.6710
# epoch:590  d_loss:0.2907  g_loss:2.4220
# epoch:591  d_loss:0.1478  g_loss:3.2843
# epoch:592  d_loss:0.1385  g_loss:2.7505
# epoch:593  d_loss:0.1712  g_loss:3.3195
# epoch:594  d_loss:0.2440  g_loss:2.5578
# epoch:595  d_loss:0.2057  g_loss:2.6224
# epoch:596  d_loss:0.2304  g_loss:2.6229
# epoch:597  d_loss:0.2044  g_loss:1.9506
# epoch:598  d_loss:0.2599  g_loss:1.6604
# epoch:599  d_loss:0.3398  g_loss:1.8170
# epoch:600  d_loss:0.6339  g_loss:1.6678
# epoch:601  d_loss:0.3188  g_loss:1.7517
# epoch:602  d_loss:0.2123  g_loss:2.3097
# epoch:603  d_loss:0.3485  g_loss:2.6582
# epoch:604  d_loss:0.3738  g_loss:1.4465
# epoch:605  d_loss:0.3257  g_loss:1.5072
# epoch:606  d_loss:0.3568  g_loss:1.7501
# epoch:607  d_loss:0.5412  g_loss:1.4644
# epoch:608  d_loss:0.4586  g_loss:1.4510
# epoch:609  d_loss:0.3872  g_loss:1.6059
# epoch:610  d_loss:0.4059  g_loss:1.8118
# epoch:611  d_loss:0.3418  g_loss:1.8188
# epoch:612  d_loss:0.3751  g_loss:1.6379
# epoch:613  d_loss:0.4686  g_loss:1.4606
# epoch:614  d_loss:0.2426  g_loss:1.7339
# epoch:615  d_loss:0.3280  g_loss:1.2533
# epoch:616  d_loss:0.2333  g_loss:1.5792
# epoch:617  d_loss:0.3059  g_loss:1.8296
# epoch:618  d_loss:0.2291  g_loss:1.8601
# epoch:619  d_loss:0.2642  g_loss:3.2077
# epoch:620  d_loss:0.3216  g_loss:2.6976
# epoch:621  d_loss:0.5598  g_loss:1.6076
# epoch:622  d_loss:0.3530  g_loss:1.3386
# epoch:623  d_loss:0.3715  g_loss:1.7000
# epoch:624  d_loss:0.5795  g_loss:1.8128
# epoch:625  d_loss:0.4173  g_loss:2.6820
# epoch:626  d_loss:0.4719  g_loss:2.2330
# epoch:627  d_loss:0.3184  g_loss:2.2217
# epoch:628  d_loss:0.5219  g_loss:1.2126
# epoch:629  d_loss:0.4185  g_loss:1.3401
# epoch:630  d_loss:0.5395  g_loss:1.1244
# epoch:631  d_loss:0.2684  g_loss:1.7701
# epoch:632  d_loss:0.3719  g_loss:1.7067
# epoch:633  d_loss:0.4650  g_loss:1.4242
# epoch:634  d_loss:0.3386  g_loss:1.5670
# epoch:635  d_loss:0.5562  g_loss:1.1692
# epoch:636  d_loss:0.4019  g_loss:1.3202
# epoch:637  d_loss:0.4581  g_loss:1.4568
# epoch:638  d_loss:0.4818  g_loss:1.1829
# epoch:639  d_loss:0.4425  g_loss:0.7737
# epoch:640  d_loss:0.4042  g_loss:1.0341
# epoch:641  d_loss:0.6998  g_loss:0.7272
# epoch:642  d_loss:0.6289  g_loss:0.5960
# epoch:643  d_loss:0.7215  g_loss:0.4976
# epoch:644  d_loss:0.8647  g_loss:0.5379
# epoch:645  d_loss:1.1734  g_loss:0.5669
# epoch:646  d_loss:1.2065  g_loss:0.4018
# epoch:647  d_loss:1.0363  g_loss:0.4863
# epoch:648  d_loss:1.0185  g_loss:0.3540
# epoch:649  d_loss:0.5790  g_loss:0.7711
# epoch:650  d_loss:0.7125  g_loss:1.0282
# epoch:651  d_loss:0.5573  g_loss:1.0351
# epoch:652  d_loss:0.3926  g_loss:1.2738
# epoch:653  d_loss:0.3745  g_loss:1.8536
# epoch:654  d_loss:0.3329  g_loss:2.3111
# epoch:655  d_loss:0.2284  g_loss:3.0172
# epoch:656  d_loss:0.2668  g_loss:2.8835
# epoch:657  d_loss:0.5582  g_loss:2.0821
# epoch:658  d_loss:0.4999  g_loss:1.8521
# epoch:659  d_loss:0.5541  g_loss:2.0525
# epoch:660  d_loss:0.6345  g_loss:3.3653
# epoch:661  d_loss:0.6685  g_loss:3.5646
# epoch:662  d_loss:0.5598  g_loss:2.2552
# epoch:663  d_loss:0.8146  g_loss:1.3972
# epoch:664  d_loss:0.8009  g_loss:0.8745
# epoch:665  d_loss:0.6579  g_loss:1.8890
# epoch:666  d_loss:0.4520  g_loss:2.1093
# epoch:667  d_loss:0.5443  g_loss:2.6419
# epoch:668  d_loss:0.6064  g_loss:2.2711
# epoch:669  d_loss:0.8992  g_loss:1.5480
# epoch:670  d_loss:0.4512  g_loss:1.6893
# epoch:671  d_loss:0.4033  g_loss:1.9387
# epoch:672  d_loss:0.2800  g_loss:2.1841
# epoch:673  d_loss:0.2575  g_loss:2.7817
# epoch:674  d_loss:0.2004  g_loss:3.0100
# epoch:675  d_loss:0.2505  g_loss:3.8583
# epoch:676  d_loss:0.3883  g_loss:3.5178
# epoch:677  d_loss:0.3024  g_loss:3.0608
# epoch:678  d_loss:0.1965  g_loss:3.3609
# epoch:679  d_loss:0.2752  g_loss:3.3756
# epoch:680  d_loss:0.3595  g_loss:3.1040
# epoch:681  d_loss:0.2780  g_loss:3.1881
# epoch:682  d_loss:0.8298  g_loss:2.9458
# epoch:683  d_loss:0.5563  g_loss:2.6162
# epoch:684  d_loss:0.7502  g_loss:2.4548
# epoch:685  d_loss:0.7178  g_loss:1.9953
# epoch:686  d_loss:1.1462  g_loss:1.4667
# epoch:687  d_loss:1.0580  g_loss:0.8669
# epoch:688  d_loss:0.9527  g_loss:1.1645
# epoch:689  d_loss:0.8957  g_loss:1.2404
# epoch:690  d_loss:0.7529  g_loss:2.0399
# epoch:691  d_loss:0.5645  g_loss:2.2212
# epoch:692  d_loss:0.5258  g_loss:1.8540
# epoch:693  d_loss:0.3333  g_loss:2.1578
# epoch:694  d_loss:0.3693  g_loss:2.0246
# epoch:695  d_loss:0.2697  g_loss:2.3960
# epoch:696  d_loss:0.2220  g_loss:2.5616
# epoch:697  d_loss:0.1730  g_loss:2.7654
# epoch:698  d_loss:0.1242  g_loss:2.9693
# epoch:699  d_loss:0.1706  g_loss:2.8877
# epoch:700  d_loss:0.1164  g_loss:3.0559
# epoch:701  d_loss:0.1083  g_loss:3.3061
# epoch:702  d_loss:0.1277  g_loss:3.1798
# epoch:703  d_loss:0.1188  g_loss:3.6799
# epoch:704  d_loss:0.1187  g_loss:3.4756
# epoch:705  d_loss:0.1520  g_loss:3.5482
# epoch:706  d_loss:0.2708  g_loss:3.0736
# epoch:707  d_loss:0.2109  g_loss:2.9717
# epoch:708  d_loss:0.3563  g_loss:2.2347
# epoch:709  d_loss:0.1953  g_loss:2.5182
# epoch:710  d_loss:0.2260  g_loss:2.6122
# epoch:711  d_loss:0.3338  g_loss:2.4958
# epoch:712  d_loss:0.2877  g_loss:2.6219
# epoch:713  d_loss:0.3366  g_loss:2.2820
# epoch:714  d_loss:0.3930  g_loss:2.7347
# epoch:715  d_loss:0.4990  g_loss:2.1178
# epoch:716  d_loss:0.5357  g_loss:1.7685
# epoch:717  d_loss:0.4729  g_loss:2.0499
# epoch:718  d_loss:0.4923  g_loss:1.8819
# epoch:719  d_loss:0.3340  g_loss:2.0152
# epoch:720  d_loss:0.4662  g_loss:1.9916
# epoch:721  d_loss:0.5790  g_loss:1.6537
# epoch:722  d_loss:0.5950  g_loss:1.5183
# epoch:723  d_loss:0.4588  g_loss:1.6872
# epoch:724  d_loss:0.3483  g_loss:2.1306
# epoch:725  d_loss:0.6549  g_loss:2.3137
# epoch:726  d_loss:0.4586  g_loss:2.1471
# epoch:727  d_loss:0.4650  g_loss:1.8054
# epoch:728  d_loss:0.4110  g_loss:2.0652
# epoch:729  d_loss:0.2091  g_loss:2.1198
# epoch:730  d_loss:0.5181  g_loss:1.7264
# epoch:731  d_loss:0.4210  g_loss:2.2480
# epoch:732  d_loss:0.2423  g_loss:2.7945
# epoch:733  d_loss:0.3116  g_loss:2.7020
# epoch:734  d_loss:0.2000  g_loss:2.9638
# epoch:735  d_loss:0.3521  g_loss:2.7809
# epoch:736  d_loss:0.2947  g_loss:2.8476
# epoch:737  d_loss:0.3586  g_loss:2.5565
# epoch:738  d_loss:0.4749  g_loss:2.0479
# epoch:739  d_loss:0.3039  g_loss:2.4832
# epoch:740  d_loss:0.2252  g_loss:3.0327
# epoch:741  d_loss:0.4323  g_loss:2.9911
# epoch:742  d_loss:0.3621  g_loss:2.9049
# epoch:743  d_loss:0.1760  g_loss:2.7561
# epoch:744  d_loss:0.1770  g_loss:2.8794
# epoch:745  d_loss:0.4510  g_loss:2.4238
# epoch:746  d_loss:0.4989  g_loss:3.1702
# epoch:747  d_loss:0.3997  g_loss:2.9621
# epoch:748  d_loss:0.4049  g_loss:2.7213
# epoch:749  d_loss:0.7247  g_loss:2.5052
# epoch:750  d_loss:0.4758  g_loss:2.7656
# epoch:751  d_loss:0.4502  g_loss:1.5268
# epoch:752  d_loss:0.5022  g_loss:1.2640
# epoch:753  d_loss:0.5080  g_loss:1.9156
# epoch:754  d_loss:0.4983  g_loss:2.0776
# epoch:755  d_loss:0.4928  g_loss:2.5273
# epoch:756  d_loss:0.6680  g_loss:2.2751
# epoch:757  d_loss:0.6687  g_loss:2.0626
# epoch:758  d_loss:0.7301  g_loss:1.4540
# epoch:759  d_loss:0.4683  g_loss:1.3270
# epoch:760  d_loss:0.5644  g_loss:1.4443
# epoch:761  d_loss:0.4653  g_loss:2.1148
# epoch:762  d_loss:0.5531  g_loss:1.7430
# epoch:763  d_loss:0.4382  g_loss:1.6359
# epoch:764  d_loss:0.4726  g_loss:1.8761
# epoch:765  d_loss:0.4468  g_loss:1.6261
# epoch:766  d_loss:0.5299  g_loss:1.5930
# epoch:767  d_loss:0.2483  g_loss:1.9097
# epoch:768  d_loss:0.2375  g_loss:2.2336
# epoch:769  d_loss:0.2412  g_loss:2.1732
# epoch:770  d_loss:0.2393  g_loss:2.4435
# epoch:771  d_loss:0.2182  g_loss:2.7463
# epoch:772  d_loss:0.2400  g_loss:2.8801
# epoch:773  d_loss:0.1681  g_loss:2.4547
# epoch:774  d_loss:0.1951  g_loss:2.5907
# epoch:775  d_loss:0.2390  g_loss:2.4044
# epoch:776  d_loss:0.2193  g_loss:2.8394
# epoch:777  d_loss:0.1644  g_loss:2.6496
# epoch:778  d_loss:0.2266  g_loss:2.6195
# epoch:779  d_loss:0.2089  g_loss:2.9829
# epoch:780  d_loss:0.2904  g_loss:2.6260
# epoch:781  d_loss:0.2510  g_loss:2.4308
# epoch:782  d_loss:0.1863  g_loss:2.4108
# epoch:783  d_loss:0.2143  g_loss:2.4932
# epoch:784  d_loss:0.4208  g_loss:1.8217
# epoch:785  d_loss:0.2256  g_loss:2.3535
# epoch:786  d_loss:0.2806  g_loss:2.0404
# epoch:787  d_loss:0.2296  g_loss:2.1540
# epoch:788  d_loss:0.2887  g_loss:1.9761
# epoch:789  d_loss:0.1962  g_loss:2.3698
# epoch:790  d_loss:0.4299  g_loss:1.8316
# epoch:791  d_loss:0.2788  g_loss:2.0383
# epoch:792  d_loss:0.3460  g_loss:1.7112
# epoch:793  d_loss:0.5099  g_loss:1.5673
# epoch:794  d_loss:0.4555  g_loss:1.6635
# epoch:795  d_loss:0.4690  g_loss:1.4920
# epoch:796  d_loss:0.4172  g_loss:1.8526
# epoch:797  d_loss:0.4948  g_loss:1.4604
# epoch:798  d_loss:0.5669  g_loss:1.6213
# epoch:799  d_loss:0.6461  g_loss:1.6776
# epoch:800  d_loss:0.4867  g_loss:1.4226
# epoch:801  d_loss:0.5045  g_loss:1.2292
# epoch:802  d_loss:0.6470  g_loss:1.3946
# epoch:803  d_loss:0.4503  g_loss:1.6131
# epoch:804  d_loss:0.4062  g_loss:1.6936
# epoch:805  d_loss:0.4533  g_loss:1.7989
# epoch:806  d_loss:0.5073  g_loss:1.3938
# epoch:807  d_loss:0.3296  g_loss:1.7758
# epoch:808  d_loss:0.3345  g_loss:2.0043
# epoch:809  d_loss:0.3117  g_loss:2.3245
# epoch:810  d_loss:0.2534  g_loss:2.3923
# epoch:811  d_loss:0.2345  g_loss:2.5512
# epoch:812  d_loss:0.2419  g_loss:2.7109
# epoch:813  d_loss:0.3405  g_loss:2.0703
# epoch:814  d_loss:0.2322  g_loss:2.4304
# epoch:815  d_loss:0.3999  g_loss:1.9399
# epoch:816  d_loss:0.2869  g_loss:2.2628
# epoch:817  d_loss:0.2999  g_loss:2.6011
# epoch:818  d_loss:0.2578  g_loss:2.5624
# epoch:819  d_loss:0.2859  g_loss:2.7268
# epoch:820  d_loss:0.3562  g_loss:2.0823
# epoch:821  d_loss:0.3218  g_loss:2.3293
# epoch:822  d_loss:0.2476  g_loss:2.7021
# epoch:823  d_loss:0.2854  g_loss:2.4923
# epoch:824  d_loss:0.3952  g_loss:2.2798
# epoch:825  d_loss:0.3932  g_loss:2.2701
# epoch:826  d_loss:0.3902  g_loss:2.4082
# epoch:827  d_loss:0.4487  g_loss:1.5673
# epoch:828  d_loss:0.2938  g_loss:1.8544
# epoch:829  d_loss:0.3883  g_loss:1.8432
# epoch:830  d_loss:0.4109  g_loss:1.7786
# epoch:831  d_loss:0.4549  g_loss:2.0270
# epoch:832  d_loss:0.4070  g_loss:1.8536
# epoch:833  d_loss:0.3576  g_loss:2.0411
# epoch:834  d_loss:0.4807  g_loss:1.7863
# epoch:835  d_loss:0.6345  g_loss:1.4734
# epoch:836  d_loss:0.5817  g_loss:1.4952
# epoch:837  d_loss:0.5680  g_loss:1.4713
# epoch:838  d_loss:0.4279  g_loss:1.5706
# epoch:839  d_loss:0.4502  g_loss:1.5724
# epoch:840  d_loss:0.4988  g_loss:1.3880
# epoch:841  d_loss:0.4986  g_loss:1.7283
# epoch:842  d_loss:0.4672  g_loss:1.5484
# epoch:843  d_loss:0.4378  g_loss:1.6631
# epoch:844  d_loss:0.6168  g_loss:1.4236
# epoch:845  d_loss:0.4299  g_loss:1.5808
# epoch:846  d_loss:0.3722  g_loss:1.7052
# epoch:847  d_loss:0.4623  g_loss:1.6911
# epoch:848  d_loss:0.4199  g_loss:1.6557
# epoch:849  d_loss:0.3058  g_loss:1.9425
# epoch:850  d_loss:0.3100  g_loss:2.3138
# epoch:851  d_loss:0.2852  g_loss:2.0522
# epoch:852  d_loss:0.3831  g_loss:2.1597
# epoch:853  d_loss:0.4589  g_loss:1.8402
# epoch:854  d_loss:0.3302  g_loss:2.1848
# epoch:855  d_loss:0.3469  g_loss:2.6949
# epoch:856  d_loss:0.2206  g_loss:2.7832
# epoch:857  d_loss:0.4124  g_loss:2.4996
# epoch:858  d_loss:0.3634  g_loss:2.2860
# epoch:859  d_loss:0.3123  g_loss:2.1626
# epoch:860  d_loss:0.4659  g_loss:1.5104
# epoch:861  d_loss:0.5183  g_loss:1.6482
# epoch:862  d_loss:0.4417  g_loss:2.4278
# epoch:863  d_loss:0.3581  g_loss:2.3001
# epoch:864  d_loss:0.2800  g_loss:2.9256
# epoch:865  d_loss:0.3774  g_loss:2.5646
# epoch:866  d_loss:0.5429  g_loss:2.5582
# epoch:867  d_loss:0.4541  g_loss:1.9697
# epoch:868  d_loss:0.5922  g_loss:1.6811
# epoch:869  d_loss:0.4246  g_loss:1.7238
# epoch:870  d_loss:0.7126  g_loss:1.1575
# epoch:871  d_loss:0.4769  g_loss:1.7332
# epoch:872  d_loss:0.5811  g_loss:1.6800
# epoch:873  d_loss:0.5808  g_loss:2.0205
# epoch:874  d_loss:0.3629  g_loss:1.7046
# epoch:875  d_loss:0.5965  g_loss:1.3555
# epoch:876  d_loss:0.5104  g_loss:1.7443
# epoch:877  d_loss:0.4345  g_loss:1.4589
# epoch:878  d_loss:0.5255  g_loss:1.8047
# epoch:879  d_loss:0.3272  g_loss:2.6005
# epoch:880  d_loss:0.2643  g_loss:2.7644
# epoch:881  d_loss:0.3846  g_loss:2.9101
# epoch:882  d_loss:0.2606  g_loss:2.5976
# epoch:883  d_loss:0.4304  g_loss:2.2076
# epoch:884  d_loss:0.4465  g_loss:2.4679
# epoch:885  d_loss:0.3330  g_loss:2.1113
# epoch:886  d_loss:0.2853  g_loss:2.4715
# epoch:887  d_loss:0.4074  g_loss:2.3652
# epoch:888  d_loss:0.5016  g_loss:2.5292
# epoch:889  d_loss:0.3574  g_loss:2.9426
# epoch:890  d_loss:0.3896  g_loss:2.6631
# epoch:891  d_loss:0.3794  g_loss:2.6759
# epoch:892  d_loss:0.3558  g_loss:2.5381
# epoch:893  d_loss:0.2792  g_loss:2.3319
# epoch:894  d_loss:0.3618  g_loss:1.9073
# epoch:895  d_loss:0.3324  g_loss:2.5720
# epoch:896  d_loss:0.3238  g_loss:2.5914
# epoch:897  d_loss:0.3060  g_loss:3.1184
# epoch:898  d_loss:0.3079  g_loss:2.3210
# epoch:899  d_loss:0.3581  g_loss:2.4098
# epoch:900  d_loss:0.3412  g_loss:1.9833
# epoch:901  d_loss:0.4717  g_loss:2.0866
# epoch:902  d_loss:0.4759  g_loss:1.9763
# epoch:903  d_loss:0.4248  g_loss:1.7194
# epoch:904  d_loss:0.4692  g_loss:1.9993
# epoch:905  d_loss:0.4996  g_loss:1.9836
# epoch:906  d_loss:0.4042  g_loss:1.9931
# epoch:907  d_loss:0.5317  g_loss:2.0953
# epoch:908  d_loss:0.4619  g_loss:1.8089
# epoch:909  d_loss:0.3988  g_loss:1.9658
# epoch:910  d_loss:0.3355  g_loss:2.0715
# epoch:911  d_loss:0.4526  g_loss:1.8846
# epoch:912  d_loss:0.4506  g_loss:2.0874
# epoch:913  d_loss:0.3355  g_loss:2.2749
# epoch:914  d_loss:0.3579  g_loss:2.2612
# epoch:915  d_loss:0.3414  g_loss:2.1227
# epoch:916  d_loss:0.3640  g_loss:2.2950
# epoch:917  d_loss:0.2123  g_loss:2.4344
# epoch:918  d_loss:0.3766  g_loss:2.5326
# epoch:919  d_loss:0.4672  g_loss:1.8586
# epoch:920  d_loss:0.4358  g_loss:1.6575
# epoch:921  d_loss:0.4638  g_loss:1.9561
# epoch:922  d_loss:0.4332  g_loss:2.1226
# epoch:923  d_loss:0.2626  g_loss:2.6751
# epoch:924  d_loss:0.2751  g_loss:2.5724
# epoch:925  d_loss:0.3967  g_loss:3.0716
# epoch:926  d_loss:0.3495  g_loss:2.1293
# epoch:927  d_loss:0.2641  g_loss:2.6689
# epoch:928  d_loss:0.2837  g_loss:2.6940
# epoch:929  d_loss:0.3161  g_loss:2.8352
# epoch:930  d_loss:0.2309  g_loss:2.7056
# epoch:931  d_loss:0.2609  g_loss:2.8709
# epoch:932  d_loss:0.3274  g_loss:2.8146
# epoch:933  d_loss:0.3136  g_loss:2.3482
# epoch:934  d_loss:0.2838  g_loss:2.7202
# epoch:935  d_loss:0.2933  g_loss:2.6329
# epoch:936  d_loss:0.2767  g_loss:2.7765
# epoch:937  d_loss:0.4783  g_loss:1.6991
# epoch:938  d_loss:0.3450  g_loss:1.6492
# epoch:939  d_loss:0.3084  g_loss:1.8853
# epoch:940  d_loss:0.3247  g_loss:2.2053
# epoch:941  d_loss:0.2267  g_loss:2.9271
# epoch:942  d_loss:0.3102  g_loss:2.8969
# epoch:943  d_loss:0.5111  g_loss:2.0147
# epoch:944  d_loss:0.5756  g_loss:1.7392
# epoch:945  d_loss:0.3624  g_loss:1.5994
# epoch:946  d_loss:0.3997  g_loss:1.8212
# epoch:947  d_loss:0.5838  g_loss:1.8117
# epoch:948  d_loss:0.3336  g_loss:2.0305
# epoch:949  d_loss:0.5186  g_loss:2.2261
# epoch:950  d_loss:0.3166  g_loss:2.1495
# epoch:951  d_loss:0.4764  g_loss:1.5277
# epoch:952  d_loss:0.5841  g_loss:1.5073
# epoch:953  d_loss:0.4607  g_loss:1.6380
# epoch:954  d_loss:0.4076  g_loss:1.5879
# epoch:955  d_loss:0.4629  g_loss:2.0649
# epoch:956  d_loss:0.4567  g_loss:1.9182
# epoch:957  d_loss:0.4443  g_loss:2.2435
# epoch:958  d_loss:0.4821  g_loss:1.7049
# epoch:959  d_loss:0.5438  g_loss:1.8114
# epoch:960  d_loss:0.5118  g_loss:1.4179
# epoch:961  d_loss:0.5339  g_loss:1.8679
# epoch:962  d_loss:0.3853  g_loss:1.9628
# epoch:963  d_loss:0.2499  g_loss:2.9282
# epoch:964  d_loss:0.1980  g_loss:2.9268
# epoch:965  d_loss:0.4989  g_loss:2.6947
# epoch:966  d_loss:0.4205  g_loss:2.2159
# epoch:967  d_loss:0.3317  g_loss:2.1866
# epoch:968  d_loss:0.4288  g_loss:1.7067
# epoch:969  d_loss:0.2742  g_loss:2.0438
# epoch:970  d_loss:0.3442  g_loss:2.4163
# epoch:971  d_loss:0.4611  g_loss:2.2503
# epoch:972  d_loss:0.4860  g_loss:1.4887
# epoch:973  d_loss:0.3838  g_loss:2.1119
# epoch:974  d_loss:0.2682  g_loss:2.6947
# epoch:975  d_loss:0.3452  g_loss:2.2928
# epoch:976  d_loss:0.3575  g_loss:2.3976
# epoch:977  d_loss:0.3822  g_loss:2.0840
# epoch:978  d_loss:0.3737  g_loss:1.9367
# epoch:979  d_loss:0.2942  g_loss:2.0446
# epoch:980  d_loss:0.3396  g_loss:1.9346
# epoch:981  d_loss:0.3643  g_loss:1.8602
# epoch:982  d_loss:0.4966  g_loss:1.8414
# epoch:983  d_loss:0.4655  g_loss:1.7612
# epoch:984  d_loss:0.5232  g_loss:2.0679
# epoch:985  d_loss:0.4057  g_loss:2.1084
# epoch:986  d_loss:0.3039  g_loss:2.4285
# epoch:987  d_loss:0.4355  g_loss:1.8094
# epoch:988  d_loss:0.3708  g_loss:1.8724
# epoch:989  d_loss:0.2933  g_loss:2.0947
# epoch:990  d_loss:0.4497  g_loss:1.8191
# epoch:991  d_loss:0.2815  g_loss:1.9660
# epoch:992  d_loss:0.4505  g_loss:2.3273
# epoch:993  d_loss:0.6553  g_loss:1.8262
# epoch:994  d_loss:0.3970  g_loss:1.9800
# epoch:995  d_loss:0.4845  g_loss:1.7107
# epoch:996  d_loss:0.4728  g_loss:1.8615
# epoch:997  d_loss:0.4262  g_loss:1.8358
# epoch:998  d_loss:0.4560  g_loss:2.2734
# epoch:999  d_loss:0.3171  g_loss:1.8206
# epoch:1000  d_loss:0.3725  g_loss:2.0389
# epoch:1001  d_loss:0.3931  g_loss:2.0895
# epoch:1002  d_loss:0.3980  g_loss:2.1453
# epoch:1003  d_loss:0.4274  g_loss:2.3796
# epoch:1004  d_loss:0.3957  g_loss:2.2562
# epoch:1005  d_loss:0.2813  g_loss:2.0165
# epoch:1006  d_loss:0.3169  g_loss:2.2486
# epoch:1007  d_loss:0.3054  g_loss:2.3738
# epoch:1008  d_loss:0.3878  g_loss:2.2742
# epoch:1009  d_loss:0.4065  g_loss:2.1382
# epoch:1010  d_loss:0.3444  g_loss:2.3973
# epoch:1011  d_loss:0.3750  g_loss:2.2337
# epoch:1012  d_loss:0.4690  g_loss:1.5045
# epoch:1013  d_loss:0.4619  g_loss:1.6078
# epoch:1014  d_loss:0.4278  g_loss:1.6656
# epoch:1015  d_loss:0.3758  g_loss:2.5896
# epoch:1016  d_loss:0.4129  g_loss:2.5811
# epoch:1017  d_loss:0.4558  g_loss:2.4894
# epoch:1018  d_loss:0.4255  g_loss:1.4891
# epoch:1019  d_loss:0.3892  g_loss:1.5868
# epoch:1020  d_loss:0.3910  g_loss:1.8316
# epoch:1021  d_loss:0.3353  g_loss:2.4645
# epoch:1022  d_loss:0.3001  g_loss:2.6377
# epoch:1023  d_loss:0.2516  g_loss:2.9803
# epoch:1024  d_loss:0.3232  g_loss:2.3801
# epoch:1025  d_loss:0.5815  g_loss:1.8716
# epoch:1026  d_loss:0.3926  g_loss:1.7882
# epoch:1027  d_loss:0.3842  g_loss:1.5496
# epoch:1028  d_loss:0.3570  g_loss:2.0713
# epoch:1029  d_loss:0.3645  g_loss:2.6412
# epoch:1030  d_loss:0.3227  g_loss:2.8337
# epoch:1031  d_loss:0.2925  g_loss:3.1053
# epoch:1032  d_loss:0.2807  g_loss:2.7767
# epoch:1033  d_loss:0.4723  g_loss:2.2261
# epoch:1034  d_loss:0.2399  g_loss:1.9734
# epoch:1035  d_loss:0.3504  g_loss:1.5130
# epoch:1036  d_loss:0.4014  g_loss:1.8778
# epoch:1037  d_loss:0.3556  g_loss:2.0094
# epoch:1038  d_loss:0.2919  g_loss:2.2854
# epoch:1039  d_loss:0.3907  g_loss:2.1898
# epoch:1040  d_loss:0.4005  g_loss:2.2226
# epoch:1041  d_loss:0.4077  g_loss:2.3984
# epoch:1042  d_loss:0.5592  g_loss:1.8246
# epoch:1043  d_loss:0.4614  g_loss:1.8923
# epoch:1044  d_loss:0.3573  g_loss:2.1531
# epoch:1045  d_loss:0.3541  g_loss:2.3789
# epoch:1046  d_loss:0.2574  g_loss:2.6658
# epoch:1047  d_loss:0.3443  g_loss:2.8485
# epoch:1048  d_loss:0.3344  g_loss:2.6697
# epoch:1049  d_loss:0.3758  g_loss:2.3721
# epoch:1050  d_loss:0.4570  g_loss:1.9249
# epoch:1051  d_loss:0.4302  g_loss:2.2784
# epoch:1052  d_loss:0.3885  g_loss:2.0057
# epoch:1053  d_loss:0.3358  g_loss:2.5211
# epoch:1054  d_loss:0.1766  g_loss:2.9310
# epoch:1055  d_loss:0.5016  g_loss:2.7015
# epoch:1056  d_loss:0.4519  g_loss:2.0378
# epoch:1057  d_loss:0.3347  g_loss:2.1009
# epoch:1058  d_loss:0.4479  g_loss:1.6615
# epoch:1059  d_loss:0.4111  g_loss:1.9719
# epoch:1060  d_loss:0.3751  g_loss:2.4644
# epoch:1061  d_loss:0.2906  g_loss:2.4840
# epoch:1062  d_loss:0.3539  g_loss:2.1790
# epoch:1063  d_loss:0.3989  g_loss:1.9157
# epoch:1064  d_loss:0.5074  g_loss:1.6307
# epoch:1065  d_loss:0.4077  g_loss:1.7011
# epoch:1066  d_loss:0.3442  g_loss:1.9201
# epoch:1067  d_loss:0.3172  g_loss:2.6340
# epoch:1068  d_loss:0.5163  g_loss:1.9581
# epoch:1069  d_loss:0.4323  g_loss:1.7737
# epoch:1070  d_loss:0.5074  g_loss:1.5442
# epoch:1071  d_loss:0.4306  g_loss:1.6562
# epoch:1072  d_loss:0.3156  g_loss:2.3286
# epoch:1073  d_loss:0.4006  g_loss:2.3586
# epoch:1074  d_loss:0.4755  g_loss:1.9051
# epoch:1075  d_loss:0.4924  g_loss:1.6338
# epoch:1076  d_loss:0.4723  g_loss:1.4459
# epoch:1077  d_loss:0.3790  g_loss:1.8030
# epoch:1078  d_loss:0.3684  g_loss:1.7802
# epoch:1079  d_loss:0.4285  g_loss:1.9889
# epoch:1080  d_loss:0.4490  g_loss:2.0895
# epoch:1081  d_loss:0.4692  g_loss:1.3488
# epoch:1082  d_loss:0.4029  g_loss:1.9673
# epoch:1083  d_loss:0.4819  g_loss:1.7401
# epoch:1084  d_loss:0.4799  g_loss:1.6604
# epoch:1085  d_loss:0.3121  g_loss:1.9045
# epoch:1086  d_loss:0.5146  g_loss:1.8469
# epoch:1087  d_loss:0.6021  g_loss:1.7433
# epoch:1088  d_loss:0.4255  g_loss:1.6413
# epoch:1089  d_loss:0.3171  g_loss:2.4233
# epoch:1090  d_loss:0.3681  g_loss:2.9597
# epoch:1091  d_loss:0.3803  g_loss:2.2034
# epoch:1092  d_loss:0.3344  g_loss:2.2226
# epoch:1093  d_loss:0.5177  g_loss:1.7542
# epoch:1094  d_loss:0.3716  g_loss:2.2239
# epoch:1095  d_loss:0.3227  g_loss:1.8266
# epoch:1096  d_loss:0.2653  g_loss:2.2941
# epoch:1097  d_loss:0.2920  g_loss:2.3331
# epoch:1098  d_loss:0.3205  g_loss:2.0276
# epoch:1099  d_loss:0.3782  g_loss:2.2976
# epoch:1100  d_loss:0.3776  g_loss:2.6233
# epoch:1101  d_loss:0.2409  g_loss:2.1276
# epoch:1102  d_loss:0.3418  g_loss:2.2661
# epoch:1103  d_loss:0.4183  g_loss:2.1194
# epoch:1104  d_loss:0.3114  g_loss:2.1926
# epoch:1105  d_loss:0.5270  g_loss:1.6807
# epoch:1106  d_loss:0.5031  g_loss:1.8320
# epoch:1107  d_loss:0.3563  g_loss:2.1998
# epoch:1108  d_loss:0.4427  g_loss:2.2042
# epoch:1109  d_loss:0.4579  g_loss:1.9450
# epoch:1110  d_loss:0.5787  g_loss:2.0023
# epoch:1111  d_loss:0.5074  g_loss:1.4093
# epoch:1112  d_loss:0.5854  g_loss:1.1453
# epoch:1113  d_loss:0.4692  g_loss:1.7750
# epoch:1114  d_loss:0.4208  g_loss:2.0840
# epoch:1115  d_loss:0.5429  g_loss:1.8792
# epoch:1116  d_loss:0.5385  g_loss:1.7504
# epoch:1117  d_loss:0.3561  g_loss:1.8059
# epoch:1118  d_loss:0.4692  g_loss:1.6144
# epoch:1119  d_loss:0.4591  g_loss:1.9542
# epoch:1120  d_loss:0.4387  g_loss:1.7881
# epoch:1121  d_loss:0.5673  g_loss:1.5916
# epoch:1122  d_loss:0.3567  g_loss:2.1172
# epoch:1123  d_loss:0.5121  g_loss:1.7542
# epoch:1124  d_loss:0.3819  g_loss:1.9736
# epoch:1125  d_loss:0.4707  g_loss:1.4796
# epoch:1126  d_loss:0.3429  g_loss:2.1335
# epoch:1127  d_loss:0.4865  g_loss:2.4497
# epoch:1128  d_loss:0.2948  g_loss:2.8165
# epoch:1129  d_loss:0.2634  g_loss:2.4706
# epoch:1130  d_loss:0.2773  g_loss:2.2349
# epoch:1131  d_loss:0.2255  g_loss:2.4849
# epoch:1132  d_loss:0.2836  g_loss:2.2835
# epoch:1133  d_loss:0.3633  g_loss:2.3707
# epoch:1134  d_loss:0.2999  g_loss:2.4895
# epoch:1135  d_loss:0.3493  g_loss:2.1093
# epoch:1136  d_loss:0.3440  g_loss:2.2253
# epoch:1137  d_loss:0.2774  g_loss:2.6449
# epoch:1138  d_loss:0.2727  g_loss:2.5839
# epoch:1139  d_loss:0.2248  g_loss:2.8746
# epoch:1140  d_loss:0.2617  g_loss:3.1208
# epoch:1141  d_loss:0.3205  g_loss:2.4393
# epoch:1142  d_loss:0.2533  g_loss:2.1478
# epoch:1143  d_loss:0.3440  g_loss:1.9307
# epoch:1144  d_loss:0.3334  g_loss:2.4981
# epoch:1145  d_loss:0.3446  g_loss:2.6151
# epoch:1146  d_loss:0.2502  g_loss:3.1815
# epoch:1147  d_loss:0.3217  g_loss:2.2778
# epoch:1148  d_loss:0.3183  g_loss:2.8943
# epoch:1149  d_loss:0.3124  g_loss:2.1766
# epoch:1150  d_loss:0.3709  g_loss:2.1313
# epoch:1151  d_loss:0.3367  g_loss:2.0109
# epoch:1152  d_loss:0.3636  g_loss:2.4104
# epoch:1153  d_loss:0.4747  g_loss:2.4299
# epoch:1154  d_loss:0.6230  g_loss:1.9645
# epoch:1155  d_loss:0.6181  g_loss:1.5449
# epoch:1156  d_loss:0.5637  g_loss:1.9456
# epoch:1157  d_loss:0.5502  g_loss:1.6640
# epoch:1158  d_loss:0.5888  g_loss:1.5479
# epoch:1159  d_loss:0.5987  g_loss:1.3240
# epoch:1160  d_loss:0.6039  g_loss:1.5071
# epoch:1161  d_loss:0.5055  g_loss:1.7087
# epoch:1162  d_loss:0.6415  g_loss:2.0410
# epoch:1163  d_loss:0.6084  g_loss:1.3340
# epoch:1164  d_loss:0.5739  g_loss:1.6782
# epoch:1165  d_loss:0.4942  g_loss:1.3537
# epoch:1166  d_loss:0.4611  g_loss:1.7990
# epoch:1167  d_loss:0.5922  g_loss:2.2706
# epoch:1168  d_loss:0.3392  g_loss:1.9712
# epoch:1169  d_loss:0.3843  g_loss:1.6956
# epoch:1170  d_loss:0.4330  g_loss:1.9519
# epoch:1171  d_loss:0.3628  g_loss:1.9106
# epoch:1172  d_loss:0.4016  g_loss:1.8030
# epoch:1173  d_loss:0.4061  g_loss:1.9212
# epoch:1174  d_loss:0.3096  g_loss:2.4719
# ...
# epoch:3619  d_loss:0.5677  g_loss:1.3715
# epoch:3620  d_loss:0.3597  g_loss:1.6342
# epoch:3621  d_loss:0.4680  g_loss:1.7739
# epoch:3622  d_loss:0.3510  g_loss:2.0696
# epoch:3623  d_loss:0.5835  g_loss:1.7396
# epoch:3624  d_loss:0.5178  g_loss:2.0036
# epoch:3625  d_loss:0.5582  g_loss:1.6711
# epoch:3626  d_loss:0.6043  g_loss:1.5717
# epoch:3627  d_loss:0.4933  g_loss:1.3250
# epoch:3628  d_loss:0.5814  g_loss:1.4181
# epoch:3629  d_loss:0.5200  g_loss:1.2919
# epoch:3630  d_loss:0.4549  g_loss:1.1245
# epoch:3631  d_loss:0.4923  g_loss:1.3271
# epoch:3632  d_loss:0.4221  g_loss:1.7952
# epoch:3633  d_loss:0.5707  g_loss:1.5947
# epoch:3634  d_loss:0.7116  g_loss:1.3172
# epoch:3635  d_loss:0.5034  g_loss:1.5127
# epoch:3636  d_loss:0.5608  g_loss:1.1636
# epoch:3637  d_loss:0.6223  g_loss:1.2639
# epoch:3638  d_loss:0.6257  g_loss:1.3862
# epoch:3639  d_loss:0.5186  g_loss:1.6678
# epoch:3640  d_loss:0.5793  g_loss:1.6879
# epoch:3641  d_loss:0.4532  g_loss:1.6340
# epoch:3642  d_loss:0.4797  g_loss:1.8910
# epoch:3643  d_loss:0.5012  g_loss:1.3398
# epoch:3644  d_loss:0.4694  g_loss:1.3233
# epoch:3645  d_loss:0.4604  g_loss:1.3788
# epoch:3646  d_loss:0.4559  g_loss:1.7705
# epoch:3647  d_loss:0.4505  g_loss:1.6077
# epoch:3648  d_loss:0.3763  g_loss:1.8084
# epoch:3649  d_loss:0.4879  g_loss:2.4314
# epoch:3650  d_loss:0.4956  g_loss:1.9100
# epoch:3651  d_loss:0.5016  g_loss:1.4843
# epoch:3652  d_loss:0.5420  g_loss:1.4542
# epoch:3653  d_loss:0.4436  g_loss:1.7750
# epoch:3654  d_loss:0.4796  g_loss:1.7179
# epoch:3655  d_loss:0.4418  g_loss:1.8240
# epoch:3656  d_loss:0.3790  g_loss:1.7409
# epoch:3657  d_loss:0.4143  g_loss:1.6440
# epoch:3658  d_loss:0.6974  g_loss:1.1034
# epoch:3659  d_loss:0.4280  g_loss:1.7026
# epoch:3660  d_loss:0.5635  g_loss:1.6928
# epoch:3661  d_loss:0.5339  g_loss:1.7835
# epoch:3662  d_loss:0.5546  g_loss:2.2549
# epoch:3663  d_loss:0.4020  g_loss:2.0939
# epoch:3664  d_loss:0.4922  g_loss:1.5412
# epoch:3665  d_loss:0.7080  g_loss:1.3072
# epoch:3666  d_loss:0.5455  g_loss:1.5228
# epoch:3667  d_loss:0.4915  g_loss:1.4020
# epoch:3668  d_loss:0.4740  g_loss:1.6184
# epoch:3669  d_loss:0.6058  g_loss:1.7117
# epoch:3670  d_loss:0.4933  g_loss:1.7379
# epoch:3671  d_loss:0.5891  g_loss:1.5087
# epoch:3672  d_loss:0.6740  g_loss:1.4887
# epoch:3673  d_loss:0.6038  g_loss:1.2828
# epoch:3674  d_loss:0.4913  g_loss:1.6565
# epoch:3675  d_loss:0.3687  g_loss:1.8040
# epoch:3676  d_loss:0.4724  g_loss:1.7463
# epoch:3677  d_loss:0.5208  g_loss:1.4886
# epoch:3678  d_loss:0.5602  g_loss:1.6154
# epoch:3679  d_loss:0.5219  g_loss:1.5300
# epoch:3680  d_loss:0.5194  g_loss:1.5311
# epoch:3681  d_loss:0.5269  g_loss:1.9820
# epoch:3682  d_loss:0.4627  g_loss:1.8411
# epoch:3683  d_loss:0.5953  g_loss:1.5792
# epoch:3684  d_loss:0.5163  g_loss:1.4855
# epoch:3685  d_loss:0.3252  g_loss:1.6949
# epoch:3686  d_loss:0.5244  g_loss:1.5759
# epoch:3687  d_loss:0.5331  g_loss:1.7109
# epoch:3688  d_loss:0.5787  g_loss:1.2559
# epoch:3689  d_loss:0.6424  g_loss:1.6078
# epoch:3690  d_loss:0.5394  g_loss:1.3708
# epoch:3691  d_loss:0.6129  g_loss:1.4356
# epoch:3692  d_loss:0.5168  g_loss:1.5395
# epoch:3693  d_loss:0.5627  g_loss:1.6641
# epoch:3694  d_loss:0.4720  g_loss:1.6736
# epoch:3695  d_loss:0.5017  g_loss:1.4545
# epoch:3696  d_loss:0.5390  g_loss:1.9299
# epoch:3697  d_loss:0.5724  g_loss:1.6228
# epoch:3698  d_loss:0.4462  g_loss:1.8043
# epoch:3699  d_loss:0.5299  g_loss:1.4860
# epoch:3700  d_loss:0.4179  g_loss:1.6885
# epoch:3701  d_loss:0.5005  g_loss:1.7524
# epoch:3702  d_loss:0.7972  g_loss:1.5499
# epoch:3703  d_loss:0.5206  g_loss:1.8072
# epoch:3704  d_loss:0.5079  g_loss:1.7633
# epoch:3705  d_loss:0.4235  g_loss:1.2818
# epoch:3706  d_loss:0.4172  g_loss:1.7541
# epoch:3707  d_loss:0.4036  g_loss:1.8157
# epoch:3708  d_loss:0.3855  g_loss:2.1415
# epoch:3709  d_loss:0.4551  g_loss:2.3418
# epoch:3710  d_loss:0.4349  g_loss:1.8768
# epoch:3711  d_loss:0.4464  g_loss:1.6350
# epoch:3712  d_loss:0.3337  g_loss:1.4405
# epoch:3713  d_loss:0.2990  g_loss:1.7284
# epoch:3714  d_loss:0.5073  g_loss:1.7077
# epoch:3715  d_loss:0.3122  g_loss:2.5421
# epoch:3716  d_loss:0.5050  g_loss:2.6773
# epoch:3717  d_loss:0.5082  g_loss:2.0298
# epoch:3718  d_loss:0.3683  g_loss:1.6996
# epoch:3719  d_loss:0.4179  g_loss:1.9486
# epoch:3720  d_loss:0.4319  g_loss:1.8877
# epoch:3721  d_loss:0.4132  g_loss:1.7999
# epoch:3722  d_loss:0.3878  g_loss:1.8460
# epoch:3723  d_loss:0.4523  g_loss:1.4609
# epoch:3724  d_loss:0.4307  g_loss:1.9098
# epoch:3725  d_loss:0.8511  g_loss:1.2993
# epoch:3726  d_loss:0.4894  g_loss:1.3621
# epoch:3727  d_loss:0.7832  g_loss:1.4111
# epoch:3728  d_loss:0.6258  g_loss:1.5474
# epoch:3729  d_loss:0.6368  g_loss:1.4591
# epoch:3730  d_loss:0.6819  g_loss:1.3953
# epoch:3731  d_loss:0.6992  g_loss:1.5195
# epoch:3732  d_loss:0.6819  g_loss:1.4508
# epoch:3733  d_loss:0.6425  g_loss:1.3346
# epoch:3734  d_loss:0.5884  g_loss:1.4452
# epoch:3735  d_loss:0.6212  g_loss:1.2958
# epoch:3736  d_loss:0.5527  g_loss:1.1345
# epoch:3737  d_loss:0.4225  g_loss:1.4972
# epoch:3738  d_loss:0.4889  g_loss:1.6515
# epoch:3739  d_loss:0.4605  g_loss:1.8097
# epoch:3740  d_loss:0.4125  g_loss:1.7547
# epoch:3741  d_loss:0.3695  g_loss:1.8640
# epoch:3742  d_loss:0.4365  g_loss:1.9403
# epoch:3743  d_loss:0.3730  g_loss:1.8170
# epoch:3744  d_loss:0.2561  g_loss:1.8441
# epoch:3745  d_loss:0.3216  g_loss:1.9546
# epoch:3746  d_loss:0.3032  g_loss:2.1495
# epoch:3747  d_loss:0.3161  g_loss:1.8386
# epoch:3748  d_loss:0.2558  g_loss:1.7956
# epoch:3749  d_loss:0.4270  g_loss:2.2394
# epoch:3750  d_loss:0.3271  g_loss:2.4032
# epoch:3751  d_loss:0.4431  g_loss:1.9820
# epoch:3752  d_loss:0.3821  g_loss:1.9453
# epoch:3753  d_loss:0.4228  g_loss:2.1015
# epoch:3754  d_loss:0.4746  g_loss:2.3488
# epoch:3755  d_loss:0.5735  g_loss:1.9314
# epoch:3756  d_loss:0.4753  g_loss:1.7196
# epoch:3757  d_loss:0.4280  g_loss:2.3148
# epoch:3758  d_loss:0.3713  g_loss:2.4451
# epoch:3759  d_loss:0.4657  g_loss:2.6677
# epoch:3760  d_loss:0.5550  g_loss:1.7359
# epoch:3761  d_loss:0.5957  g_loss:1.3223
# epoch:3762  d_loss:0.5166  g_loss:1.2437
# epoch:3763  d_loss:0.5546  g_loss:1.2665
# epoch:3764  d_loss:0.7263  g_loss:1.5462
# epoch:3765  d_loss:0.5330  g_loss:1.6010
# epoch:3766  d_loss:0.4624  g_loss:2.0236
# epoch:3767  d_loss:0.6155  g_loss:1.5134
# epoch:3768  d_loss:0.5410  g_loss:1.2568
# epoch:3769  d_loss:0.4108  g_loss:2.1157
# epoch:3770  d_loss:0.3978  g_loss:1.7202
# epoch:3771  d_loss:0.4665  g_loss:1.6323
# epoch:3772  d_loss:0.3814  g_loss:1.9984
# epoch:3773  d_loss:0.4613  g_loss:1.6719
# epoch:3774  d_loss:0.3851  g_loss:1.7793
# epoch:3775  d_loss:0.4480  g_loss:2.2532
# epoch:3776  d_loss:0.2872  g_loss:2.4953
# epoch:3777  d_loss:0.4180  g_loss:1.9704
# epoch:3778  d_loss:0.4116  g_loss:1.9288
# epoch:3779  d_loss:0.4379  g_loss:1.4717
# epoch:3780  d_loss:0.3366  g_loss:1.7383
# epoch:3781  d_loss:0.4526  g_loss:2.0268
# epoch:3782  d_loss:0.4223  g_loss:2.0416
# epoch:3783  d_loss:0.5721  g_loss:1.8770
# epoch:3784  d_loss:0.5058  g_loss:1.6529
# epoch:3785  d_loss:0.4287  g_loss:2.0703
# epoch:3786  d_loss:0.3768  g_loss:1.6344
# epoch:3787  d_loss:0.4097  g_loss:1.2583
# epoch:3788  d_loss:0.5296  g_loss:1.3789
# epoch:3789  d_loss:0.4464  g_loss:1.9048
# epoch:3790  d_loss:0.4818  g_loss:2.0472
# epoch:3791  d_loss:0.6498  g_loss:1.8627
# epoch:3792  d_loss:0.5202  g_loss:1.7720
# epoch:3793  d_loss:0.5317  g_loss:1.9784
# epoch:3794  d_loss:0.5441  g_loss:1.5032
# epoch:3795  d_loss:0.7273  g_loss:1.1884
# epoch:3796  d_loss:0.6139  g_loss:1.3740
# epoch:3797  d_loss:0.4843  g_loss:1.4110
# epoch:3798  d_loss:0.5287  g_loss:1.3976
# epoch:3799  d_loss:0.5647  g_loss:1.7671
# epoch:3800  d_loss:0.6577  g_loss:1.2978
# epoch:3801  d_loss:0.5769  g_loss:1.3005
# epoch:3802  d_loss:0.5364  g_loss:1.6693
# epoch:3803  d_loss:0.4693  g_loss:1.8824
# epoch:3804  d_loss:0.3660  g_loss:1.6412
# epoch:3805  d_loss:0.4359  g_loss:1.8490
# epoch:3806  d_loss:0.4783  g_loss:1.4663
# epoch:3807  d_loss:0.4317  g_loss:1.5409
# epoch:3808  d_loss:0.4510  g_loss:1.7469
# epoch:3809  d_loss:0.4078  g_loss:2.0474
# epoch:3810  d_loss:0.4759  g_loss:1.6697
# epoch:3811  d_loss:0.3539  g_loss:2.0663
# epoch:3812  d_loss:0.5602  g_loss:1.8813
# epoch:3813  d_loss:0.4619  g_loss:1.9754
# epoch:3814  d_loss:0.3733  g_loss:1.4284
# epoch:3815  d_loss:0.3608  g_loss:1.6575
# epoch:3816  d_loss:0.4830  g_loss:1.7700
# epoch:3817  d_loss:0.4144  g_loss:1.9688
# epoch:3818  d_loss:0.3426  g_loss:1.6852
# epoch:3819  d_loss:0.4797  g_loss:1.5903
# epoch:3820  d_loss:0.5530  g_loss:1.6191
# epoch:3821  d_loss:0.5853  g_loss:1.3686
# epoch:3822  d_loss:0.4784  g_loss:1.7018
# epoch:3823  d_loss:0.4616  g_loss:1.7646
# epoch:3824  d_loss:0.5522  g_loss:1.6871
# epoch:3825  d_loss:0.5017  g_loss:1.3337
# epoch:3826  d_loss:0.6208  g_loss:1.3648
# epoch:3827  d_loss:0.7516  g_loss:1.0430
# epoch:3828  d_loss:0.6331  g_loss:1.0984
# epoch:3829  d_loss:0.6339  g_loss:1.3919
# epoch:3830  d_loss:0.6023  g_loss:1.6168
# epoch:3831  d_loss:0.4890  g_loss:2.0620
# epoch:3832  d_loss:0.5967  g_loss:1.6218
# epoch:3833  d_loss:0.5107  g_loss:1.4033
# epoch:3834  d_loss:0.5674  g_loss:1.3019
# epoch:3835  d_loss:0.5783  g_loss:1.5116
# epoch:3836  d_loss:0.4444  g_loss:1.7180
# epoch:3837  d_loss:0.4510  g_loss:1.7607
# epoch:3838  d_loss:0.4820  g_loss:2.0877
# epoch:3839  d_loss:0.4897  g_loss:1.7039
# epoch:3840  d_loss:0.2962  g_loss:1.6728
# epoch:3841  d_loss:0.3930  g_loss:1.4889
# epoch:3842  d_loss:0.5289  g_loss:1.7514
# epoch:3843  d_loss:0.5019  g_loss:1.6956
# epoch:3844  d_loss:0.5237  g_loss:1.6955
# epoch:3845  d_loss:0.4544  g_loss:2.0702
# epoch:3846  d_loss:0.5329  g_loss:2.0931
# epoch:3847  d_loss:0.5690  g_loss:1.4369
# epoch:3848  d_loss:0.5096  g_loss:1.6316
# epoch:3849  d_loss:0.3643  g_loss:1.9704
# epoch:3850  d_loss:0.4116  g_loss:2.2813
# epoch:3851  d_loss:0.2806  g_loss:2.5445
# epoch:3852  d_loss:0.4893  g_loss:1.9400
# epoch:3853  d_loss:0.5211  g_loss:1.9523
# epoch:3854  d_loss:0.4810  g_loss:1.5418
# epoch:3855  d_loss:0.5213  g_loss:1.7625
# epoch:3856  d_loss:0.5179  g_loss:1.7374
# epoch:3857  d_loss:0.3950  g_loss:1.5316
# epoch:3858  d_loss:0.4493  g_loss:1.6477
# epoch:3859  d_loss:0.4367  g_loss:1.7083
# epoch:3860  d_loss:0.6860  g_loss:1.4905
# epoch:3861  d_loss:0.4577  g_loss:2.1162
# epoch:3862  d_loss:0.5470  g_loss:1.9134
# epoch:3863  d_loss:0.7233  g_loss:1.4529
# epoch:3864  d_loss:0.6174  g_loss:1.3274
# epoch:3865  d_loss:0.4595  g_loss:1.6258
# epoch:3866  d_loss:0.5256  g_loss:1.5596
# epoch:3867  d_loss:0.5927  g_loss:1.5123
# epoch:3868  d_loss:0.4455  g_loss:1.4358
# epoch:3869  d_loss:0.5180  g_loss:1.4746
# epoch:3870  d_loss:0.4628  g_loss:1.4306
# epoch:3871  d_loss:0.4515  g_loss:1.7960
# epoch:3872  d_loss:0.5919  g_loss:1.3498
# epoch:3873  d_loss:0.4101  g_loss:1.5122
# epoch:3874  d_loss:0.5694  g_loss:1.3470
# epoch:3875  d_loss:0.5237  g_loss:1.6692
# epoch:3876  d_loss:0.5853  g_loss:1.3651
# epoch:3877  d_loss:0.4142  g_loss:1.5248
# epoch:3878  d_loss:0.6752  g_loss:1.5454
# epoch:3879  d_loss:0.4538  g_loss:1.4060
# epoch:3880  d_loss:0.4166  g_loss:1.2382
# epoch:3881  d_loss:0.5200  g_loss:1.4451
# epoch:3882  d_loss:0.5064  g_loss:1.5819
# epoch:3883  d_loss:0.4562  g_loss:1.8725
# epoch:3884  d_loss:0.4845  g_loss:1.9401
# epoch:3885  d_loss:0.6549  g_loss:1.3435
# epoch:3886  d_loss:0.4849  g_loss:1.4507
# epoch:3887  d_loss:0.5483  g_loss:1.3790
# epoch:3888  d_loss:0.5854  g_loss:1.2594
# epoch:3889  d_loss:0.4403  g_loss:1.1896
# epoch:3890  d_loss:0.4850  g_loss:1.7682
# epoch:3891  d_loss:0.5829  g_loss:2.1624
# epoch:3892  d_loss:0.5740  g_loss:2.0121
# epoch:3893  d_loss:0.5911  g_loss:1.8317
# epoch:3894  d_loss:0.5575  g_loss:1.3334
# epoch:3895  d_loss:0.5731  g_loss:1.4656
# epoch:3896  d_loss:0.5506  g_loss:1.2070
# epoch:3897  d_loss:0.4357  g_loss:1.5166
# epoch:3898  d_loss:0.5724  g_loss:1.4902
# epoch:3899  d_loss:0.5557  g_loss:1.4742
# epoch:3900  d_loss:0.4262  g_loss:1.9338
# epoch:3901  d_loss:0.5191  g_loss:1.7359
# epoch:3902  d_loss:0.5146  g_loss:1.8020
# epoch:3903  d_loss:0.5630  g_loss:1.4274
# epoch:3904  d_loss:0.5103  g_loss:1.5433
# epoch:3905  d_loss:0.4661  g_loss:1.6486
# epoch:3906  d_loss:0.4121  g_loss:1.5717
# epoch:3907  d_loss:0.4621  g_loss:1.7681
# epoch:3908  d_loss:0.5430  g_loss:2.1003
# epoch:3909  d_loss:0.6416  g_loss:1.6424
# epoch:3910  d_loss:0.5860  g_loss:1.5148
# epoch:3911  d_loss:0.4914  g_loss:1.6025
# epoch:3912  d_loss:0.4750  g_loss:1.6230
# epoch:3913  d_loss:0.3867  g_loss:1.9999
# epoch:3914  d_loss:0.5058  g_loss:1.7800
# epoch:3915  d_loss:0.3826  g_loss:1.6800
# epoch:3916  d_loss:0.5899  g_loss:1.5572
# epoch:3917  d_loss:0.4329  g_loss:1.8514
# epoch:3918  d_loss:0.4851  g_loss:1.8406
# epoch:3919  d_loss:0.6136  g_loss:1.4537
# epoch:3920  d_loss:0.5223  g_loss:1.4225
# epoch:3921  d_loss:0.4615  g_loss:1.9192
# epoch:3922  d_loss:0.3925  g_loss:2.2032
# epoch:3923  d_loss:0.2958  g_loss:2.0066
# epoch:3924  d_loss:0.4285  g_loss:1.7674
# epoch:3925  d_loss:0.5797  g_loss:1.7626
# epoch:3926  d_loss:0.6417  g_loss:1.2685
# epoch:3927  d_loss:0.6263  g_loss:1.2872
# epoch:3928  d_loss:0.4823  g_loss:1.3578
# epoch:3929  d_loss:0.5470  g_loss:1.3937
# epoch:3930  d_loss:0.4014  g_loss:1.7501
# epoch:3931  d_loss:0.5819  g_loss:1.5963
# epoch:3932  d_loss:0.5050  g_loss:1.6949
# epoch:3933  d_loss:0.4320  g_loss:1.9879
# epoch:3934  d_loss:0.5603  g_loss:1.5867
# epoch:3935  d_loss:0.5747  g_loss:1.7937
# epoch:3936  d_loss:0.5348  g_loss:1.4505
# epoch:3937  d_loss:0.4784  g_loss:1.7463
# epoch:3938  d_loss:0.4004  g_loss:2.0216
# epoch:3939  d_loss:0.5270  g_loss:1.7292
# epoch:3940  d_loss:0.4688  g_loss:1.4339
# epoch:3941  d_loss:0.4717  g_loss:1.2226
# epoch:3942  d_loss:0.6085  g_loss:1.2449
# epoch:3943  d_loss:0.4992  g_loss:1.3578
# epoch:3944  d_loss:0.4433  g_loss:1.4612
# epoch:3945  d_loss:0.5011  g_loss:1.9412
# epoch:3946  d_loss:0.4565  g_loss:2.0431
# epoch:3947  d_loss:0.3698  g_loss:1.6691
# epoch:3948  d_loss:0.4615  g_loss:1.8069
# epoch:3949  d_loss:0.5991  g_loss:1.4858
# epoch:3950  d_loss:0.5379  g_loss:1.5251
# epoch:3951  d_loss:0.4498  g_loss:1.3943
# epoch:3952  d_loss:0.5160  g_loss:1.3927
# epoch:3953  d_loss:0.4310  g_loss:1.4534
# epoch:3954  d_loss:0.4206  g_loss:2.0649
# epoch:3955  d_loss:0.5378  g_loss:2.0638
# epoch:3956  d_loss:0.5273  g_loss:1.6493
# epoch:3957  d_loss:0.5590  g_loss:1.6888
# epoch:3958  d_loss:0.5008  g_loss:1.4848
# epoch:3959  d_loss:0.6806  g_loss:1.2604
# epoch:3960  d_loss:0.5431  g_loss:1.5438
# epoch:3961  d_loss:0.6240  g_loss:1.3016
# epoch:3962  d_loss:0.5319  g_loss:1.4035
# epoch:3963  d_loss:0.5253  g_loss:1.5367
# epoch:3964  d_loss:0.6561  g_loss:1.7464
# epoch:3965  d_loss:0.5294  g_loss:1.7565
# epoch:3966  d_loss:0.5929  g_loss:1.5859
# epoch:3967  d_loss:0.5770  g_loss:1.4532
# epoch:3968  d_loss:0.5685  g_loss:1.3067
# epoch:3969  d_loss:0.4923  g_loss:1.3501
# epoch:3970  d_loss:0.5969  g_loss:1.3959
# epoch:3971  d_loss:0.4885  g_loss:1.5617
# epoch:3972  d_loss:0.4801  g_loss:1.6725
# epoch:3973  d_loss:0.4564  g_loss:1.8667
# epoch:3974  d_loss:0.5598  g_loss:1.5514
# epoch:3975  d_loss:0.5355  g_loss:1.6834
# epoch:3976  d_loss:0.4882  g_loss:1.3783
# epoch:3977  d_loss:0.3877  g_loss:1.6120
# epoch:3978  d_loss:0.4871  g_loss:1.5223
# epoch:3979  d_loss:0.5167  g_loss:1.4246
# epoch:3980  d_loss:0.4333  g_loss:1.8338
# epoch:3981  d_loss:0.4555  g_loss:1.4288
# epoch:3982  d_loss:0.4677  g_loss:1.7589
# epoch:3983  d_loss:0.5019  g_loss:1.7016
# epoch:3984  d_loss:0.4887  g_loss:1.7196
# epoch:3985  d_loss:0.5228  g_loss:1.5712
# epoch:3986  d_loss:0.5204  g_loss:1.5583
# epoch:3987  d_loss:0.5031  g_loss:1.4930
# epoch:3988  d_loss:0.4730  g_loss:2.0113
# epoch:3989  d_loss:0.4377  g_loss:1.5278
# epoch:3990  d_loss:0.5415  g_loss:1.7134
# epoch:3991  d_loss:0.5323  g_loss:1.6444
# epoch:3992  d_loss:0.4509  g_loss:1.5013
# epoch:3993  d_loss:0.4599  g_loss:1.5907
# epoch:3994  d_loss:0.4734  g_loss:1.3588
# epoch:3995  d_loss:0.5190  g_loss:1.4374
# epoch:3996  d_loss:0.5377  g_loss:1.2283
# epoch:3997  d_loss:0.5000  g_loss:1.6157
# epoch:3998  d_loss:0.4587  g_loss:1.5260
# epoch:3999  d_loss:0.5077  g_loss:1.8205
# epoch:4000  d_loss:0.4801  g_loss:1.6344
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:93: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
