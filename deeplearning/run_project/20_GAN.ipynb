# %% [markdown]
# <a href="https://colab.research.google.com/github/junhansong/deeplearning/blob/master/deeplearning/run_project/20_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 라이브러리 호출

# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ### 이미지가 저장될 폴더가 없다면 만듭니다.

# %%
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

# %% [markdown]
# ### 생성자 모델을 만듭니다.

# %%
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %% [markdown]
# ### 판별자 모델을 만듭니다.

# %%
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# %% [markdown]
# ### 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.

# %%
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %% [markdown]
# ### 신경망을 실행시키는 함수를 만듭니다.

# %%
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기  
  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어 소스코드만 첨부합니다. 
        # 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4623  g_loss:0.3281
# epoch:2  d_loss:0.5688  g_loss:0.1024
# epoch:3  d_loss:0.6588  g_loss:0.0838
# epoch:4  d_loss:0.5764  g_loss:0.1649
# epoch:5  d_loss:0.5085  g_loss:0.4205
# epoch:6  d_loss:0.4876  g_loss:0.6947
# epoch:7  d_loss:0.5092  g_loss:0.8658
# epoch:8  d_loss:0.4971  g_loss:0.8922
# epoch:9  d_loss:0.4877  g_loss:0.8652
# epoch:10  d_loss:0.4209  g_loss:0.7781
# epoch:11  d_loss:0.4451  g_loss:0.7994
# epoch:12  d_loss:0.4897  g_loss:0.8518
# epoch:13  d_loss:0.4847  g_loss:0.8906
# epoch:14  d_loss:0.5825  g_loss:0.9525
# epoch:15  d_loss:0.4829  g_loss:1.0625
# epoch:16  d_loss:0.4076  g_loss:1.0470
# epoch:17  d_loss:0.6248  g_loss:0.8017
# epoch:18  d_loss:0.5606  g_loss:0.6459
# epoch:19  d_loss:0.4525  g_loss:0.7175
# epoch:20  d_loss:0.4282  g_loss:0.7485
# epoch:21  d_loss:0.4995  g_loss:0.8121
# epoch:22  d_loss:0.4975  g_loss:0.6719
# epoch:23  d_loss:0.4444  g_loss:0.6267
# epoch:24  d_loss:0.4404  g_loss:0.6900
# epoch:25  d_loss:0.4572  g_loss:0.6701
# epoch:26  d_loss:0.4891  g_loss:0.7118
# epoch:27  d_loss:0.4537  g_loss:0.5794
# epoch:28  d_loss:0.4776  g_loss:0.5219
# epoch:29  d_loss:0.4998  g_loss:0.5606
# epoch:30  d_loss:0.4250  g_loss:0.6375
# epoch:31  d_loss:0.4456  g_loss:0.6707
# epoch:32  d_loss:0.4002  g_loss:0.5534
# epoch:33  d_loss:0.3949  g_loss:0.6493
# epoch:34  d_loss:0.2989  g_loss:0.7428
# epoch:35  d_loss:0.3663  g_loss:0.7702
# epoch:36  d_loss:0.3775  g_loss:0.6320
# epoch:37  d_loss:0.3265  g_loss:0.7269
# epoch:38  d_loss:0.3200  g_loss:0.9164
# epoch:39  d_loss:0.1991  g_loss:1.3630
# epoch:40  d_loss:0.3134  g_loss:1.2443
# epoch:41  d_loss:0.3841  g_loss:0.9112
# epoch:42  d_loss:0.3307  g_loss:0.7695
# epoch:43  d_loss:0.2224  g_loss:1.1755
# epoch:44  d_loss:0.1629  g_loss:1.3159
# epoch:45  d_loss:0.2076  g_loss:1.7617
# epoch:46  d_loss:0.4359  g_loss:1.0550
# epoch:47  d_loss:0.4758  g_loss:0.8642
# epoch:48  d_loss:0.3172  g_loss:1.9411
# epoch:49  d_loss:0.3404  g_loss:2.5369
# epoch:50  d_loss:0.2555  g_loss:2.0851
# epoch:51  d_loss:0.1317  g_loss:1.7626
# epoch:52  d_loss:0.1110  g_loss:1.8279
# epoch:53  d_loss:0.1339  g_loss:2.1410
# epoch:54  d_loss:0.0809  g_loss:2.7393
# epoch:55  d_loss:0.1454  g_loss:3.7606
# epoch:56  d_loss:0.3803  g_loss:2.6927
# epoch:57  d_loss:0.5792  g_loss:2.7781
# epoch:58  d_loss:0.5486  g_loss:2.6535
# epoch:59  d_loss:0.7490  g_loss:2.6148
# epoch:60  d_loss:0.8600  g_loss:2.3956
# epoch:61  d_loss:0.6220  g_loss:3.1352
# epoch:62  d_loss:0.6838  g_loss:2.7802
# epoch:63  d_loss:0.3900  g_loss:3.3356
# epoch:64  d_loss:0.3564  g_loss:3.5901
# epoch:65  d_loss:0.4034  g_loss:3.7312
# epoch:66  d_loss:0.3974  g_loss:3.0257
# epoch:67  d_loss:0.2880  g_loss:3.0400
# epoch:68  d_loss:0.2506  g_loss:3.4443
# epoch:69  d_loss:0.4483  g_loss:3.4686
# epoch:70  d_loss:0.6611  g_loss:2.1712
# epoch:71  d_loss:0.4088  g_loss:1.7712
# epoch:72  d_loss:0.6506  g_loss:1.5072
# epoch:73  d_loss:0.4960  g_loss:1.9023
# epoch:74  d_loss:0.8330  g_loss:1.3520
# epoch:75  d_loss:0.9611  g_loss:0.8430
# epoch:76  d_loss:0.8967  g_loss:0.7848
# epoch:77  d_loss:0.7306  g_loss:1.5076
# epoch:78  d_loss:0.5995  g_loss:1.8908
# epoch:79  d_loss:0.5648  g_loss:2.2392
# epoch:80  d_loss:0.4019  g_loss:2.4059
# epoch:81  d_loss:0.3165  g_loss:2.5454
# epoch:82  d_loss:0.2513  g_loss:2.6758
# epoch:83  d_loss:0.1761  g_loss:3.5550
# epoch:84  d_loss:0.2372  g_loss:3.7086
# epoch:85  d_loss:0.5120  g_loss:3.7329
# epoch:86  d_loss:0.2839  g_loss:4.4216
# epoch:87  d_loss:0.5869  g_loss:3.7722
# epoch:88  d_loss:0.8796  g_loss:3.7105
# epoch:89  d_loss:0.8665  g_loss:3.7333
# epoch:90  d_loss:0.6797  g_loss:3.9630
# epoch:91  d_loss:0.7586  g_loss:4.1098
# epoch:92  d_loss:1.0044  g_loss:2.4958
# epoch:93  d_loss:1.1793  g_loss:2.0244
# epoch:94  d_loss:0.8741  g_loss:1.9330
# epoch:95  d_loss:0.7792  g_loss:1.8757
# epoch:96  d_loss:0.7033  g_loss:2.0032
# epoch:97  d_loss:0.6835  g_loss:1.7902
# epoch:98  d_loss:0.6249  g_loss:1.6394
# epoch:99  d_loss:0.5961  g_loss:1.6274
# epoch:100  d_loss:0.5051  g_loss:1.3785
# epoch:101  d_loss:0.4515  g_loss:1.4263
# epoch:102  d_loss:0.4105  g_loss:1.4313
# epoch:103  d_loss:0.5094  g_loss:1.5922
# epoch:104  d_loss:0.3733  g_loss:1.4492
# epoch:105  d_loss:0.4740  g_loss:1.3427
# epoch:106  d_loss:0.4414  g_loss:1.3065
# epoch:107  d_loss:0.3607  g_loss:1.0788
# epoch:108  d_loss:0.4513  g_loss:0.9319
# epoch:109  d_loss:0.3863  g_loss:1.0353
# epoch:110  d_loss:0.4174  g_loss:1.4437
# epoch:111  d_loss:0.3878  g_loss:1.2760
# epoch:112  d_loss:0.3965  g_loss:1.3489
# epoch:113  d_loss:0.4469  g_loss:1.2939
# epoch:114  d_loss:0.5980  g_loss:1.0110
# epoch:115  d_loss:0.5156  g_loss:0.8829
# epoch:116  d_loss:0.5325  g_loss:0.8864
# epoch:117  d_loss:0.4585  g_loss:0.8272
# epoch:118  d_loss:0.5509  g_loss:0.9010
# epoch:119  d_loss:0.3812  g_loss:1.0907
# epoch:120  d_loss:0.5281  g_loss:1.0438
# epoch:121  d_loss:0.6627  g_loss:0.9717
# epoch:122  d_loss:0.7987  g_loss:0.9026
# epoch:123  d_loss:0.6244  g_loss:0.9740
# epoch:124  d_loss:0.5585  g_loss:0.9063
# epoch:125  d_loss:0.7465  g_loss:0.7907
# epoch:126  d_loss:0.7369  g_loss:0.8385
# epoch:127  d_loss:0.6236  g_loss:1.0669
# epoch:128  d_loss:0.6500  g_loss:1.0107
# epoch:129  d_loss:0.5889  g_loss:1.2072
# epoch:130  d_loss:0.5330  g_loss:1.0898
# epoch:131  d_loss:0.5755  g_loss:1.3017
# epoch:132  d_loss:0.5782  g_loss:1.0938
# epoch:133  d_loss:0.5403  g_loss:1.2368
# epoch:134  d_loss:0.5767  g_loss:1.1115
# epoch:135  d_loss:0.4970  g_loss:1.5480
# epoch:136  d_loss:0.4354  g_loss:1.5179
# epoch:137  d_loss:0.4205  g_loss:1.7764
# epoch:138  d_loss:0.4495  g_loss:1.6178
# epoch:139  d_loss:0.3874  g_loss:1.8922
# epoch:140  d_loss:0.3286  g_loss:1.9276
# epoch:141  d_loss:0.4037  g_loss:1.8976
# epoch:142  d_loss:0.3841  g_loss:1.7057
# epoch:143  d_loss:0.3042  g_loss:2.1621
# epoch:144  d_loss:0.3077  g_loss:2.1211
# epoch:145  d_loss:0.3014  g_loss:2.0973
# epoch:146  d_loss:0.3325  g_loss:2.1505
# epoch:147  d_loss:0.5340  g_loss:2.4865
# epoch:148  d_loss:0.4573  g_loss:2.1900
# epoch:149  d_loss:0.4990  g_loss:2.2574
# epoch:150  d_loss:0.4294  g_loss:2.5838
# epoch:151  d_loss:0.5808  g_loss:1.9501
# epoch:152  d_loss:0.6477  g_loss:1.6857
# epoch:153  d_loss:0.5584  g_loss:2.0159
# epoch:154  d_loss:0.5147  g_loss:1.7966
# epoch:155  d_loss:0.7783  g_loss:1.3617
# epoch:156  d_loss:0.6914  g_loss:1.8224
# epoch:157  d_loss:0.5637  g_loss:1.8862
# epoch:158  d_loss:0.6467  g_loss:1.4674
# epoch:159  d_loss:0.4699  g_loss:1.8967
# epoch:160  d_loss:0.6004  g_loss:1.9209
# epoch:161  d_loss:0.5524  g_loss:1.9515
# epoch:162  d_loss:0.5106  g_loss:1.6890
# epoch:163  d_loss:0.5399  g_loss:1.6779
# epoch:164  d_loss:0.5725  g_loss:1.6075
# epoch:165  d_loss:0.4215  g_loss:1.8133
# epoch:166  d_loss:0.4551  g_loss:1.8482
# epoch:167  d_loss:0.5015  g_loss:1.9742
# epoch:168  d_loss:0.4345  g_loss:1.8735
# epoch:169  d_loss:0.5174  g_loss:1.7859
# epoch:170  d_loss:0.4709  g_loss:1.4660
# epoch:171  d_loss:0.5006  g_loss:1.3889
# epoch:172  d_loss:0.4600  g_loss:1.4206
# epoch:173  d_loss:0.3781  g_loss:1.4045
# epoch:174  d_loss:0.4222  g_loss:1.7688
# epoch:175  d_loss:0.4189  g_loss:1.6828
# epoch:176  d_loss:0.5147  g_loss:1.3497
# epoch:177  d_loss:0.5318  g_loss:1.5309
# epoch:178  d_loss:0.4201  g_loss:1.3250
# epoch:179  d_loss:0.3864  g_loss:1.2953
# epoch:180  d_loss:0.5283  g_loss:0.9299
# epoch:181  d_loss:0.3918  g_loss:1.4060
# epoch:182  d_loss:0.5080  g_loss:1.5294
# epoch:183  d_loss:0.4135  g_loss:1.6249
# epoch:184  d_loss:0.3989  g_loss:1.2708
# epoch:185  d_loss:0.5725  g_loss:1.1392
# epoch:186  d_loss:0.5106  g_loss:1.0077
# epoch:187  d_loss:0.5164  g_loss:0.8921
# epoch:188  d_loss:0.7123  g_loss:1.1016
# epoch:189  d_loss:0.5686  g_loss:0.8872
# epoch:190  d_loss:0.4216  g_loss:1.2011
# epoch:191  d_loss:0.6296  g_loss:1.2553
# epoch:192  d_loss:0.5491  g_loss:1.1277
# epoch:193  d_loss:0.5777  g_loss:1.1500
# epoch:194  d_loss:0.5512  g_loss:0.8835
# epoch:195  d_loss:0.6505  g_loss:0.8705
# epoch:196  d_loss:0.5360  g_loss:1.0555
# epoch:197  d_loss:0.4491  g_loss:1.1099
# epoch:198  d_loss:0.4954  g_loss:1.3220
# epoch:199  d_loss:0.5652  g_loss:1.2287
# epoch:200  d_loss:0.5955  g_loss:1.1673
# epoch:201  d_loss:0.5226  g_loss:1.2294
# epoch:202  d_loss:0.6517  g_loss:1.2452
# epoch:203  d_loss:0.4458  g_loss:1.4474
# epoch:204  d_loss:0.4685  g_loss:1.6290
# epoch:205  d_loss:0.4305  g_loss:1.8217
# epoch:206  d_loss:0.3966  g_loss:1.8648
# epoch:207  d_loss:0.4629  g_loss:1.8546
# epoch:208  d_loss:0.5236  g_loss:1.7463
# epoch:209  d_loss:0.3910  g_loss:1.9230
# epoch:210  d_loss:0.5044  g_loss:2.2018
# epoch:211  d_loss:0.3782  g_loss:2.7651
# epoch:212  d_loss:0.5044  g_loss:2.6351
# epoch:213  d_loss:0.6167  g_loss:2.4364
# epoch:214  d_loss:0.5514  g_loss:1.8291
# epoch:215  d_loss:0.5294  g_loss:1.6140
# epoch:216  d_loss:0.5160  g_loss:1.8622
# epoch:217  d_loss:0.4410  g_loss:1.9143
# epoch:218  d_loss:0.5513  g_loss:2.0495
# epoch:219  d_loss:0.4410  g_loss:2.4209
# epoch:220  d_loss:0.5821  g_loss:2.3194
# epoch:221  d_loss:0.5588  g_loss:1.8895
# epoch:222  d_loss:0.5278  g_loss:1.5869
# epoch:223  d_loss:0.5729  g_loss:1.4309
# epoch:224  d_loss:0.5413  g_loss:1.6142
# epoch:225  d_loss:0.5273  g_loss:1.5813
# epoch:226  d_loss:0.4209  g_loss:1.6794
# epoch:227  d_loss:0.5235  g_loss:1.8395
# epoch:228  d_loss:0.6068  g_loss:1.7140
# epoch:229  d_loss:0.5463  g_loss:1.6406
# epoch:230  d_loss:0.5261  g_loss:1.7217
# epoch:231  d_loss:0.5927  g_loss:1.8892
# epoch:232  d_loss:0.6857  g_loss:1.1865
# epoch:233  d_loss:0.6453  g_loss:1.3956
# epoch:234  d_loss:0.5253  g_loss:1.4495
# epoch:235  d_loss:0.4869  g_loss:1.2088
# epoch:236  d_loss:0.5985  g_loss:1.4845
# epoch:237  d_loss:0.4927  g_loss:1.8449
# epoch:238  d_loss:0.5218  g_loss:1.7685
# epoch:239  d_loss:0.3871  g_loss:2.0630
# epoch:240  d_loss:0.4934  g_loss:1.6827
# epoch:241  d_loss:0.5979  g_loss:1.4703
# epoch:242  d_loss:0.5375  g_loss:1.3839
# epoch:243  d_loss:0.5753  g_loss:1.3901
# epoch:244  d_loss:0.5700  g_loss:1.4022
# epoch:245  d_loss:0.4563  g_loss:1.6770
# epoch:246  d_loss:0.4651  g_loss:1.6924
# epoch:247  d_loss:0.3545  g_loss:2.0281
# epoch:248  d_loss:0.5430  g_loss:2.1382
# epoch:249  d_loss:0.5032  g_loss:1.6113
# epoch:250  d_loss:0.5434  g_loss:1.5451
# epoch:251  d_loss:0.4292  g_loss:1.5302
# epoch:252  d_loss:0.3273  g_loss:1.6786
# epoch:253  d_loss:0.3902  g_loss:1.6916
# epoch:254  d_loss:0.4631  g_loss:2.0589
# epoch:255  d_loss:0.6013  g_loss:1.9538
# epoch:256  d_loss:0.5783  g_loss:1.8504
# epoch:257  d_loss:0.3655  g_loss:2.4731
# epoch:258  d_loss:0.3986  g_loss:2.2198
# epoch:259  d_loss:0.5150  g_loss:1.8279
# epoch:260  d_loss:0.4664  g_loss:1.7801
# epoch:261  d_loss:0.4577  g_loss:1.4119
# epoch:262  d_loss:0.5233  g_loss:1.4094
# epoch:263  d_loss:0.3586  g_loss:1.7919
# epoch:264  d_loss:0.4728  g_loss:1.9017
# epoch:265  d_loss:0.5676  g_loss:1.8031
# epoch:266  d_loss:0.4491  g_loss:1.6259
# epoch:267  d_loss:0.5221  g_loss:1.9825
# epoch:268  d_loss:0.5821  g_loss:1.4534
# epoch:269  d_loss:0.5782  g_loss:1.3025
# epoch:270  d_loss:0.4922  g_loss:1.6189
# epoch:271  d_loss:0.3369  g_loss:1.5929
# epoch:272  d_loss:0.3461  g_loss:1.9109
# epoch:273  d_loss:0.4506  g_loss:1.8699
# epoch:274  d_loss:0.4457  g_loss:1.8338
# epoch:275  d_loss:0.4380  g_loss:1.7908
# epoch:276  d_loss:0.6951  g_loss:1.4569
# epoch:277  d_loss:0.4872  g_loss:1.6128
# epoch:278  d_loss:0.3872  g_loss:1.5427
# epoch:279  d_loss:0.3810  g_loss:1.7823
# epoch:280  d_loss:0.3769  g_loss:1.7269
# epoch:281  d_loss:0.4383  g_loss:2.0003
# epoch:282  d_loss:0.4010  g_loss:2.1733
# epoch:283  d_loss:0.3896  g_loss:2.0893
# epoch:284  d_loss:0.4067  g_loss:1.9428
# epoch:285  d_loss:0.4912  g_loss:1.7783
# epoch:286  d_loss:0.4493  g_loss:1.5652
# epoch:287  d_loss:0.4238  g_loss:1.8979
# epoch:288  d_loss:0.3477  g_loss:2.0118
# epoch:289  d_loss:0.4993  g_loss:1.8426
# epoch:290  d_loss:0.6776  g_loss:1.6202
# epoch:291  d_loss:0.3768  g_loss:2.1213
# epoch:292  d_loss:0.4424  g_loss:1.5456
# epoch:293  d_loss:0.5949  g_loss:1.1747
# epoch:294  d_loss:0.4364  g_loss:1.4750
# epoch:295  d_loss:0.5594  g_loss:1.5922
# epoch:296  d_loss:0.5692  g_loss:1.2791
# epoch:297  d_loss:0.5430  g_loss:1.3733
# epoch:298  d_loss:0.5310  g_loss:1.7396
# epoch:299  d_loss:0.4838  g_loss:2.0211
# epoch:300  d_loss:0.5706  g_loss:1.7394
# epoch:301  d_loss:0.5200  g_loss:1.5578
# epoch:302  d_loss:0.5036  g_loss:1.6339
# epoch:303  d_loss:0.4520  g_loss:1.8375
# epoch:304  d_loss:0.5284  g_loss:1.8176
# epoch:305  d_loss:0.5189  g_loss:1.5137
# epoch:306  d_loss:0.6209  g_loss:1.5192
# epoch:307  d_loss:0.4941  g_loss:1.4889
# epoch:308  d_loss:0.3882  g_loss:1.8841
# epoch:309  d_loss:0.5434  g_loss:1.8488
# epoch:310  d_loss:0.5755  g_loss:1.6613
# epoch:311  d_loss:0.5440  g_loss:1.5751
# epoch:312  d_loss:0.4633  g_loss:1.5887
# epoch:313  d_loss:0.4287  g_loss:1.9116
# epoch:314  d_loss:0.5212  g_loss:2.0463
# epoch:315  d_loss:0.4580  g_loss:2.1072
# epoch:316  d_loss:0.4290  g_loss:2.0049
# epoch:317  d_loss:0.3641  g_loss:1.9696
# epoch:318  d_loss:0.4833  g_loss:2.1421
# epoch:319  d_loss:0.5197  g_loss:1.9719
# epoch:320  d_loss:0.4814  g_loss:1.9452
# epoch:321  d_loss:0.4545  g_loss:1.8672
# epoch:322  d_loss:0.4118  g_loss:1.7597
# epoch:323  d_loss:0.4584  g_loss:1.7117
# epoch:324  d_loss:0.4479  g_loss:1.6144
# epoch:325  d_loss:0.3747  g_loss:1.7281
# epoch:326  d_loss:0.4835  g_loss:1.6484
# epoch:327  d_loss:0.4814  g_loss:1.9526
# epoch:328  d_loss:0.4592  g_loss:2.2000
# epoch:329  d_loss:0.3914  g_loss:2.7693
# epoch:330  d_loss:0.4554  g_loss:2.7529
# epoch:331  d_loss:0.4450  g_loss:2.7655
# epoch:332  d_loss:0.5152  g_loss:1.9927
# epoch:333  d_loss:0.6887  g_loss:1.9016
# epoch:334  d_loss:0.3777  g_loss:1.9236
# epoch:335  d_loss:0.5555  g_loss:1.7323
# epoch:336  d_loss:0.3705  g_loss:1.9443
# epoch:337  d_loss:0.3493  g_loss:2.3728
# epoch:338  d_loss:0.5319  g_loss:2.0208
# epoch:339  d_loss:0.5060  g_loss:1.9016
# epoch:340  d_loss:0.4403  g_loss:1.8668
# epoch:341  d_loss:0.4596  g_loss:1.5556
# epoch:342  d_loss:0.5449  g_loss:1.3486
# epoch:343  d_loss:0.3675  g_loss:1.8141
# epoch:344  d_loss:0.4598  g_loss:1.7881
# epoch:345  d_loss:0.4255  g_loss:2.1454
# epoch:346  d_loss:0.4583  g_loss:2.5903
# epoch:347  d_loss:0.3926  g_loss:2.3878
# epoch:348  d_loss:0.3612  g_loss:2.2622
# epoch:349  d_loss:0.4722  g_loss:1.9802
# epoch:350  d_loss:0.3513  g_loss:2.2852
# epoch:351  d_loss:0.2981  g_loss:2.3934
# epoch:352  d_loss:0.2737  g_loss:2.4016
# epoch:353  d_loss:0.2566  g_loss:2.2815
# epoch:354  d_loss:0.3664  g_loss:2.5025
# epoch:355  d_loss:0.2105  g_loss:2.2999
# epoch:356  d_loss:0.3301  g_loss:2.3980
# epoch:357  d_loss:0.2385  g_loss:2.4434
# epoch:358  d_loss:0.2859  g_loss:2.7107
# epoch:359  d_loss:0.3233  g_loss:3.1867
# epoch:360  d_loss:0.2766  g_loss:2.9006
# epoch:361  d_loss:0.2445  g_loss:2.6246
# epoch:362  d_loss:0.2952  g_loss:2.3446
# epoch:363  d_loss:0.3369  g_loss:2.1411
# epoch:364  d_loss:0.2524  g_loss:2.2962
# epoch:365  d_loss:0.3302  g_loss:2.4222
# epoch:366  d_loss:0.3226  g_loss:2.4380
# epoch:367  d_loss:0.3866  g_loss:2.6636
# epoch:368  d_loss:0.2697  g_loss:2.1190
# epoch:369  d_loss:0.3682  g_loss:2.0914
# epoch:370  d_loss:0.4055  g_loss:2.4220
# epoch:371  d_loss:0.2721  g_loss:2.1639
# epoch:372  d_loss:0.3262  g_loss:2.3272
# epoch:373  d_loss:0.2741  g_loss:2.5989
# epoch:374  d_loss:0.4547  g_loss:2.6859
# epoch:375  d_loss:0.4651  g_loss:2.1477
# epoch:376  d_loss:0.4891  g_loss:1.8014
# epoch:377  d_loss:0.3840  g_loss:2.0381
# epoch:378  d_loss:0.4497  g_loss:2.2581
# epoch:379  d_loss:0.4108  g_loss:2.1083
# epoch:380  d_loss:0.4139  g_loss:2.4573
# epoch:381  d_loss:0.3543  g_loss:2.4967
# epoch:382  d_loss:0.4061  g_loss:1.6239
# epoch:383  d_loss:0.5296  g_loss:1.7499
# epoch:384  d_loss:0.5634  g_loss:1.6199
# epoch:385  d_loss:0.4631  g_loss:1.9449
# epoch:386  d_loss:0.4216  g_loss:2.0923
# epoch:387  d_loss:0.4431  g_loss:1.8810
# epoch:388  d_loss:0.7133  g_loss:1.8202
# epoch:389  d_loss:0.4310  g_loss:1.8044
# epoch:390  d_loss:0.5753  g_loss:1.8277
# epoch:391  d_loss:0.3479  g_loss:1.9510
# epoch:392  d_loss:0.4212  g_loss:2.0460
# epoch:393  d_loss:0.4290  g_loss:2.0005
# epoch:394  d_loss:0.3665  g_loss:2.0893
# epoch:395  d_loss:0.5456  g_loss:1.6385
# epoch:396  d_loss:0.4042  g_loss:2.0531
# epoch:397  d_loss:0.3513  g_loss:2.2782
# epoch:398  d_loss:0.5851  g_loss:1.5231
# epoch:399  d_loss:0.3522  g_loss:2.1556
# epoch:400  d_loss:0.3255  g_loss:2.1396
# epoch:401  d_loss:0.3426  g_loss:2.2898
# epoch:402  d_loss:0.3566  g_loss:2.0175
# epoch:403  d_loss:0.2452  g_loss:2.2707
# epoch:404  d_loss:0.2563  g_loss:2.2479
# epoch:405  d_loss:0.3171  g_loss:2.6189
# epoch:406  d_loss:0.3057  g_loss:2.8591
# epoch:407  d_loss:0.2506  g_loss:2.7893
# epoch:408  d_loss:0.3054  g_loss:2.6013
# epoch:409  d_loss:0.3046  g_loss:2.2414
# epoch:410  d_loss:0.2901  g_loss:2.2847
# epoch:411  d_loss:0.2463  g_loss:2.5687
# epoch:412  d_loss:0.3297  g_loss:2.3512
# epoch:413  d_loss:0.2861  g_loss:2.4299
# epoch:414  d_loss:0.3546  g_loss:2.6896
# epoch:415  d_loss:0.3529  g_loss:2.4764
# epoch:416  d_loss:0.2524  g_loss:2.8431
# epoch:417  d_loss:0.3168  g_loss:2.3416
# epoch:418  d_loss:0.3004  g_loss:2.2106
# epoch:419  d_loss:0.3239  g_loss:2.7885
# epoch:420  d_loss:0.3859  g_loss:2.3246
# epoch:421  d_loss:0.3455  g_loss:1.9850
# epoch:422  d_loss:0.3689  g_loss:2.3544
# epoch:423  d_loss:0.3100  g_loss:2.1274
# epoch:424  d_loss:0.3121  g_loss:2.6136
# epoch:425  d_loss:0.1624  g_loss:3.1762
# epoch:426  d_loss:0.3645  g_loss:2.9417
# epoch:427  d_loss:0.2311  g_loss:3.6982
# epoch:428  d_loss:0.2951  g_loss:3.5417
# epoch:429  d_loss:0.4073  g_loss:3.1673
# epoch:430  d_loss:0.3651  g_loss:2.2540
# epoch:431  d_loss:0.3739  g_loss:2.2828
# epoch:432  d_loss:0.3164  g_loss:2.8580
# epoch:433  d_loss:0.2497  g_loss:3.6133
# epoch:434  d_loss:0.3377  g_loss:3.0447
# epoch:435  d_loss:0.2707  g_loss:2.9555
# epoch:436  d_loss:0.2538  g_loss:2.3038
# epoch:437  d_loss:0.2529  g_loss:2.1850
# epoch:438  d_loss:0.2534  g_loss:2.3926
# epoch:439  d_loss:0.2202  g_loss:2.6171
# epoch:440  d_loss:0.1977  g_loss:2.4389
# epoch:441  d_loss:0.2839  g_loss:2.7054
# epoch:442  d_loss:0.2445  g_loss:2.7281
# epoch:443  d_loss:0.2396  g_loss:2.8209
# epoch:444  d_loss:0.2754  g_loss:2.3850
# epoch:445  d_loss:0.3125  g_loss:2.7022
# epoch:446  d_loss:0.2132  g_loss:2.3117
# epoch:447  d_loss:0.2056  g_loss:2.3262
# epoch:448  d_loss:0.2733  g_loss:2.3973
# epoch:449  d_loss:0.2303  g_loss:2.1167
# epoch:450  d_loss:0.3267  g_loss:2.1040
# epoch:451  d_loss:0.3261  g_loss:2.6668
# epoch:452  d_loss:0.2033  g_loss:2.9504
# epoch:453  d_loss:0.2597  g_loss:2.7572
# epoch:454  d_loss:0.2804  g_loss:2.1274
# epoch:455  d_loss:0.3272  g_loss:2.0659
# epoch:456  d_loss:0.4098  g_loss:1.9737
# epoch:457  d_loss:0.2246  g_loss:2.4796
# epoch:458  d_loss:0.2233  g_loss:2.6437
# epoch:459  d_loss:0.2697  g_loss:2.3423
# epoch:460  d_loss:0.3103  g_loss:1.8165
# epoch:461  d_loss:0.3151  g_loss:2.4642
# epoch:462  d_loss:0.2872  g_loss:2.4507
# epoch:463  d_loss:0.2279  g_loss:2.5461
# epoch:464  d_loss:0.2365  g_loss:2.9134
# epoch:465  d_loss:0.3011  g_loss:2.2248
# epoch:466  d_loss:0.3584  g_loss:1.8052
# epoch:467  d_loss:0.3592  g_loss:2.4645
# epoch:468  d_loss:0.2262  g_loss:2.4951
# epoch:469  d_loss:0.2272  g_loss:3.7605
# epoch:470  d_loss:0.4624  g_loss:3.4422
# epoch:471  d_loss:0.3671  g_loss:2.5459
# epoch:472  d_loss:0.2362  g_loss:2.3928
# epoch:473  d_loss:0.3423  g_loss:2.1712
# epoch:474  d_loss:0.1759  g_loss:2.8359
# epoch:475  d_loss:0.2050  g_loss:3.1745
# epoch:476  d_loss:0.2473  g_loss:3.0692
# epoch:477  d_loss:0.2228  g_loss:3.0554
# epoch:478  d_loss:0.2170  g_loss:2.6829
# epoch:479  d_loss:0.1176  g_loss:3.1601
# epoch:480  d_loss:0.2047  g_loss:2.8207
# epoch:481  d_loss:0.1413  g_loss:3.8127
# epoch:482  d_loss:0.2653  g_loss:3.0918
# epoch:483  d_loss:0.2015  g_loss:2.8603
# epoch:484  d_loss:0.1775  g_loss:3.2538
# epoch:485  d_loss:0.1930  g_loss:2.5669
# epoch:486  d_loss:0.2117  g_loss:3.0040
# epoch:487  d_loss:0.3444  g_loss:2.7123
# epoch:488  d_loss:0.3050  g_loss:3.1447
# epoch:489  d_loss:0.3211  g_loss:2.7205
# epoch:490  d_loss:0.3229  g_loss:2.9114
# epoch:491  d_loss:0.2511  g_loss:2.9822
# epoch:492  d_loss:0.3849  g_loss:2.7907
# epoch:493  d_loss:0.2571  g_loss:2.8177
# epoch:494  d_loss:0.1919  g_loss:3.9805
# epoch:495  d_loss:0.2409  g_loss:2.6888
# epoch:496  d_loss:0.2512  g_loss:2.6364
# epoch:497  d_loss:0.1944  g_loss:2.7421
# epoch:498  d_loss:0.2001  g_loss:2.2357
# epoch:499  d_loss:0.2164  g_loss:2.6065
# epoch:500  d_loss:0.1778  g_loss:2.9554
# epoch:501  d_loss:0.1940  g_loss:3.4733
# epoch:502  d_loss:0.2857  g_loss:2.8679
# epoch:503  d_loss:0.1517  g_loss:3.3148
# epoch:504  d_loss:0.1879  g_loss:2.8707
# epoch:505  d_loss:0.1946  g_loss:2.7968
# epoch:506  d_loss:0.2599  g_loss:2.5696
# epoch:507  d_loss:0.1974  g_loss:2.9463
# epoch:508  d_loss:0.2192  g_loss:3.7066
# epoch:509  d_loss:0.2775  g_loss:3.1354
# epoch:510  d_loss:0.2530  g_loss:3.3689
# epoch:511  d_loss:0.3075  g_loss:2.8210
# epoch:512  d_loss:0.2397  g_loss:3.0196
# epoch:513  d_loss:0.2042  g_loss:3.3652
# epoch:514  d_loss:0.1799  g_loss:3.5300
# epoch:515  d_loss:0.2537  g_loss:2.8411
# epoch:516  d_loss:0.2514  g_loss:2.9589
# epoch:517  d_loss:0.2688  g_loss:3.3769
# epoch:518  d_loss:0.2923  g_loss:3.0198
# epoch:519  d_loss:0.3680  g_loss:2.5980
# epoch:520  d_loss:0.2022  g_loss:2.8088
# epoch:521  d_loss:0.2062  g_loss:3.1958
# epoch:522  d_loss:0.4178  g_loss:2.4632
# epoch:523  d_loss:0.2181  g_loss:2.4171
# epoch:524  d_loss:0.3408  g_loss:2.2216
# epoch:525  d_loss:0.2420  g_loss:2.3301
# epoch:526  d_loss:0.1650  g_loss:2.9347
# epoch:527  d_loss:0.3108  g_loss:2.2636
# epoch:528  d_loss:0.4172  g_loss:2.2044
# epoch:529  d_loss:0.2712  g_loss:1.8102
# epoch:530  d_loss:0.1532  g_loss:2.2860
# epoch:531  d_loss:0.1683  g_loss:3.4204
# epoch:532  d_loss:0.2216  g_loss:3.8189
# epoch:533  d_loss:0.1470  g_loss:3.8882
# epoch:534  d_loss:0.1266  g_loss:3.8445
# epoch:535  d_loss:0.1940  g_loss:2.9257
# epoch:536  d_loss:0.1744  g_loss:2.7915
# epoch:537  d_loss:0.1310  g_loss:3.2648
# epoch:538  d_loss:0.0994  g_loss:3.0667
# epoch:539  d_loss:0.1516  g_loss:3.8712
# epoch:540  d_loss:0.1260  g_loss:3.6143
# epoch:541  d_loss:0.1457  g_loss:3.3761
# epoch:542  d_loss:0.1778  g_loss:4.0611
# epoch:543  d_loss:0.1644  g_loss:3.1882
# epoch:544  d_loss:0.1610  g_loss:2.8473
# epoch:545  d_loss:0.2585  g_loss:2.5485
# epoch:546  d_loss:0.1223  g_loss:3.2801
# epoch:547  d_loss:0.1527  g_loss:3.2520
# epoch:548  d_loss:0.1574  g_loss:2.8710
# epoch:549  d_loss:0.1791  g_loss:3.3786
# epoch:550  d_loss:0.1584  g_loss:3.1758
# epoch:551  d_loss:0.1306  g_loss:2.9228
# epoch:552  d_loss:0.2280  g_loss:3.0034
# epoch:553  d_loss:0.2941  g_loss:2.8854
# epoch:554  d_loss:0.3317  g_loss:2.6668
# epoch:555  d_loss:0.1832  g_loss:3.1848
# epoch:556  d_loss:0.2219  g_loss:3.2601
# epoch:557  d_loss:0.2050  g_loss:2.9787
# epoch:558  d_loss:0.1969  g_loss:2.9416
# epoch:559  d_loss:0.2383  g_loss:3.0297
# epoch:560  d_loss:0.3676  g_loss:2.8054
# epoch:561  d_loss:0.2198  g_loss:2.4240
# epoch:562  d_loss:0.1085  g_loss:3.5783
# epoch:563  d_loss:0.2866  g_loss:3.2852
# epoch:564  d_loss:0.4707  g_loss:2.5613
# epoch:565  d_loss:0.2840  g_loss:1.9049
# epoch:566  d_loss:0.2647  g_loss:2.2928
# epoch:567  d_loss:0.2196  g_loss:3.0826
# epoch:568  d_loss:0.3080  g_loss:3.3470
# epoch:569  d_loss:0.2409  g_loss:3.3916
# epoch:570  d_loss:0.3223  g_loss:2.3818
# epoch:571  d_loss:0.3172  g_loss:2.3951
# epoch:572  d_loss:0.1395  g_loss:2.0394
# epoch:573  d_loss:0.3112  g_loss:2.8496
# epoch:574  d_loss:0.2758  g_loss:3.0062
# epoch:575  d_loss:0.2705  g_loss:3.0443
# epoch:576  d_loss:0.1627  g_loss:2.8328
# epoch:577  d_loss:0.3564  g_loss:2.4315
# epoch:578  d_loss:0.2592  g_loss:2.2821
# epoch:579  d_loss:0.2188  g_loss:2.2174
# epoch:580  d_loss:0.2286  g_loss:2.5175
# epoch:581  d_loss:0.2474  g_loss:2.5202
# epoch:582  d_loss:0.2863  g_loss:2.6430
# epoch:583  d_loss:0.3005  g_loss:2.5782
# epoch:584  d_loss:0.1936  g_loss:2.4044
# epoch:585  d_loss:0.2331  g_loss:2.1869
# epoch:586  d_loss:0.2156  g_loss:2.2897
# epoch:587  d_loss:0.2852  g_loss:1.9878
# epoch:588  d_loss:0.2181  g_loss:2.3782
# epoch:589  d_loss:0.3733  g_loss:1.9062
# epoch:590  d_loss:0.3515  g_loss:1.9520
# epoch:591  d_loss:0.2656  g_loss:2.1846
# epoch:592  d_loss:0.2870  g_loss:2.3857
# epoch:593  d_loss:0.3329  g_loss:2.9445
# epoch:594  d_loss:0.2655  g_loss:2.1537
# epoch:595  d_loss:0.3724  g_loss:1.5374
# epoch:596  d_loss:0.4086  g_loss:1.5376
# epoch:597  d_loss:0.3604  g_loss:1.7728
# epoch:598  d_loss:0.4051  g_loss:2.5468
# epoch:599  d_loss:0.2947  g_loss:2.2519
# epoch:600  d_loss:0.6004  g_loss:2.1290
# epoch:601  d_loss:0.4813  g_loss:1.6553
# epoch:602  d_loss:0.4683  g_loss:1.4855
# epoch:603  d_loss:0.3054  g_loss:1.7244
# epoch:604  d_loss:0.3414  g_loss:1.6225
# epoch:605  d_loss:0.2945  g_loss:1.8630
# epoch:606  d_loss:0.2944  g_loss:1.8518
# epoch:607  d_loss:0.1786  g_loss:2.2581
# epoch:608  d_loss:0.3498  g_loss:1.3935
# epoch:609  d_loss:0.3219  g_loss:2.1472
# epoch:610  d_loss:0.3411  g_loss:2.6398
# epoch:611  d_loss:0.4720  g_loss:2.7365
# epoch:612  d_loss:0.3566  g_loss:2.5382
# epoch:613  d_loss:0.4289  g_loss:2.3294
# epoch:614  d_loss:0.7906  g_loss:2.4112
# epoch:615  d_loss:0.6071  g_loss:2.0769
# epoch:616  d_loss:0.7680  g_loss:1.7660
# epoch:617  d_loss:1.2706  g_loss:1.9183
# epoch:618  d_loss:0.8086  g_loss:2.0281
# epoch:619  d_loss:1.3713  g_loss:1.2160
# epoch:620  d_loss:1.1934  g_loss:1.7147
# epoch:621  d_loss:1.3503  g_loss:0.9088
# epoch:622  d_loss:1.1641  g_loss:0.5339
# epoch:623  d_loss:1.0577  g_loss:0.8495
# epoch:624  d_loss:1.2130  g_loss:1.5208
# epoch:625  d_loss:0.6523  g_loss:1.9531
# epoch:626  d_loss:0.5697  g_loss:2.2766
# epoch:627  d_loss:0.2675  g_loss:2.7553
# epoch:628  d_loss:0.3239  g_loss:2.1478
# epoch:629  d_loss:0.2009  g_loss:1.9890
# epoch:630  d_loss:0.5865  g_loss:1.9204
# epoch:631  d_loss:0.6003  g_loss:2.0602
# epoch:632  d_loss:0.6415  g_loss:2.4761
# epoch:633  d_loss:0.8361  g_loss:2.4458
# epoch:634  d_loss:0.8209  g_loss:2.5904
# epoch:635  d_loss:0.5423  g_loss:2.7461
# epoch:636  d_loss:0.3961  g_loss:3.3268
# epoch:637  d_loss:0.5595  g_loss:2.9295
# epoch:638  d_loss:0.4958  g_loss:4.0022
# epoch:639  d_loss:0.5619  g_loss:3.6112
# epoch:640  d_loss:0.4171  g_loss:3.2085
# epoch:641  d_loss:0.6673  g_loss:3.0321
# epoch:642  d_loss:0.5670  g_loss:2.1016
# epoch:643  d_loss:0.6139  g_loss:2.1438
# epoch:644  d_loss:0.8231  g_loss:1.4965
# epoch:645  d_loss:0.8067  g_loss:1.3852
# epoch:646  d_loss:0.8995  g_loss:1.0579
# epoch:647  d_loss:0.7712  g_loss:1.2491
# epoch:648  d_loss:0.5112  g_loss:1.5833
# epoch:649  d_loss:0.5046  g_loss:1.7479
# epoch:650  d_loss:0.3716  g_loss:2.0840
# epoch:651  d_loss:0.4246  g_loss:1.9622
# epoch:652  d_loss:0.1582  g_loss:2.3148
# epoch:653  d_loss:0.2459  g_loss:2.3050
# epoch:654  d_loss:0.1978  g_loss:2.3806
# epoch:655  d_loss:0.1279  g_loss:2.6995
# epoch:656  d_loss:0.1703  g_loss:3.2221
# epoch:657  d_loss:0.2159  g_loss:2.5879
# epoch:658  d_loss:0.2735  g_loss:1.9486
# epoch:659  d_loss:0.2286  g_loss:2.5471
# epoch:660  d_loss:0.2606  g_loss:2.9831
# epoch:661  d_loss:0.3248  g_loss:2.8829
# epoch:662  d_loss:0.4612  g_loss:2.4700
# epoch:663  d_loss:0.4636  g_loss:2.0484
# epoch:664  d_loss:0.4633  g_loss:1.7104
# epoch:665  d_loss:0.7396  g_loss:1.7159
# epoch:666  d_loss:0.5001  g_loss:1.8225
# epoch:667  d_loss:0.5453  g_loss:1.9270
# epoch:668  d_loss:0.5189  g_loss:1.7946
# epoch:669  d_loss:0.3757  g_loss:1.6252
# epoch:670  d_loss:0.4939  g_loss:1.5465
# epoch:671  d_loss:0.4552  g_loss:1.8970
# epoch:672  d_loss:0.5068  g_loss:1.8676
# epoch:673  d_loss:0.3834  g_loss:1.7204
# epoch:674  d_loss:0.3754  g_loss:1.5122
# epoch:675  d_loss:0.6269  g_loss:1.2775
# epoch:676  d_loss:0.6146  g_loss:1.5145
# epoch:677  d_loss:0.4804  g_loss:1.9230
# epoch:678  d_loss:0.4621  g_loss:1.6392
# epoch:679  d_loss:0.5422  g_loss:1.7802
# epoch:680  d_loss:0.4414  g_loss:2.1226
# epoch:681  d_loss:0.3988  g_loss:1.8809
# epoch:682  d_loss:0.4981  g_loss:1.8801
# epoch:683  d_loss:0.5301  g_loss:1.3168
# epoch:684  d_loss:0.4362  g_loss:1.4333
# epoch:685  d_loss:0.3099  g_loss:1.8231
# epoch:686  d_loss:0.4674  g_loss:1.9458
# epoch:687  d_loss:0.3245  g_loss:1.9275
# epoch:688  d_loss:0.3860  g_loss:2.1147
# epoch:689  d_loss:0.3308  g_loss:2.6158
# epoch:690  d_loss:0.2535  g_loss:1.9662
# epoch:691  d_loss:0.2779  g_loss:2.0331
# epoch:692  d_loss:0.3437  g_loss:2.1279
# epoch:693  d_loss:0.2879  g_loss:2.7114
# epoch:694  d_loss:0.3041  g_loss:2.4963
# epoch:695  d_loss:0.3187  g_loss:2.4972
# epoch:696  d_loss:0.3913  g_loss:2.3003
# epoch:697  d_loss:0.4273  g_loss:2.9126
# epoch:698  d_loss:0.3920  g_loss:3.1141
# epoch:699  d_loss:0.4854  g_loss:2.2416
# epoch:700  d_loss:0.5227  g_loss:1.7826
# epoch:701  d_loss:0.5125  g_loss:1.6389
# epoch:702  d_loss:0.3413  g_loss:1.7798
# epoch:703  d_loss:0.4454  g_loss:1.8329
# epoch:704  d_loss:0.4798  g_loss:2.0097
# epoch:705  d_loss:0.5954  g_loss:2.1692
# epoch:706  d_loss:0.4272  g_loss:2.0935
# epoch:707  d_loss:0.3174  g_loss:1.7039
# epoch:708  d_loss:0.4315  g_loss:1.8621
# epoch:709  d_loss:0.4198  g_loss:1.8215
# epoch:710  d_loss:0.2835  g_loss:2.2666
# epoch:711  d_loss:0.3562  g_loss:1.9047
# epoch:712  d_loss:0.4304  g_loss:2.0995
# epoch:713  d_loss:0.3234  g_loss:1.9635
# epoch:714  d_loss:0.2823  g_loss:1.9470
# epoch:715  d_loss:0.2992  g_loss:2.1467
# epoch:716  d_loss:0.3202  g_loss:2.2013
# epoch:717  d_loss:0.4720  g_loss:2.2107
# epoch:718  d_loss:0.3365  g_loss:2.1140
# epoch:719  d_loss:0.4005  g_loss:1.7930
# epoch:720  d_loss:0.5887  g_loss:1.3681
# epoch:721  d_loss:0.4627  g_loss:1.7415
# epoch:722  d_loss:0.5528  g_loss:1.3351
# epoch:723  d_loss:0.2897  g_loss:1.8048
# epoch:724  d_loss:0.4282  g_loss:1.8794
# epoch:725  d_loss:0.4730  g_loss:2.0849
# epoch:726  d_loss:0.3635  g_loss:1.7652
# epoch:727  d_loss:0.4250  g_loss:1.5127
# epoch:728  d_loss:0.3619  g_loss:1.6596
# epoch:729  d_loss:0.3834  g_loss:2.0029
# epoch:730  d_loss:0.3356  g_loss:2.1228
# epoch:731  d_loss:0.3104  g_loss:2.2626
# epoch:732  d_loss:0.2717  g_loss:1.9456
# epoch:733  d_loss:0.5117  g_loss:1.5144
# epoch:734  d_loss:0.4436  g_loss:1.7823
# epoch:735  d_loss:0.3078  g_loss:2.5495
# epoch:736  d_loss:0.3197  g_loss:2.2210
# epoch:737  d_loss:0.4236  g_loss:2.4635
# epoch:738  d_loss:0.4901  g_loss:2.3144
# epoch:739  d_loss:0.5302  g_loss:1.4389
# epoch:740  d_loss:0.4437  g_loss:1.5619
# epoch:741  d_loss:0.3958  g_loss:1.7246
# epoch:742  d_loss:0.4758  g_loss:1.6632
# epoch:743  d_loss:0.3021  g_loss:1.7993
# epoch:744  d_loss:0.4022  g_loss:1.6609
# epoch:745  d_loss:0.2982  g_loss:1.6296
# epoch:746  d_loss:0.4685  g_loss:1.7809
# epoch:747  d_loss:0.2793  g_loss:2.0496
# epoch:748  d_loss:0.3244  g_loss:1.7743
# epoch:749  d_loss:0.5336  g_loss:1.3701
# epoch:750  d_loss:0.5508  g_loss:1.2337
# epoch:751  d_loss:0.5094  g_loss:1.3722
# epoch:752  d_loss:0.4693  g_loss:1.3329
# epoch:753  d_loss:0.6542  g_loss:1.5009
# epoch:754  d_loss:0.4791  g_loss:1.4719
# epoch:755  d_loss:0.7025  g_loss:1.7418
# epoch:756  d_loss:0.4713  g_loss:1.7584
# epoch:757  d_loss:0.6258  g_loss:1.4119
# epoch:758  d_loss:0.8490  g_loss:0.8267
# epoch:759  d_loss:0.5177  g_loss:1.4036
# epoch:760  d_loss:0.5121  g_loss:1.4729
# epoch:761  d_loss:0.5817  g_loss:1.9656
# epoch:762  d_loss:0.7403  g_loss:1.2534
# epoch:763  d_loss:0.5902  g_loss:1.0995
# epoch:764  d_loss:0.6143  g_loss:1.3966
# epoch:765  d_loss:0.5540  g_loss:1.5518
# epoch:766  d_loss:0.6425  g_loss:1.2783
# epoch:767  d_loss:0.4505  g_loss:1.4236
# epoch:768  d_loss:0.5179  g_loss:1.4274
# epoch:769  d_loss:0.3839  g_loss:1.6488
# epoch:770  d_loss:0.4228  g_loss:2.0831
# epoch:771  d_loss:0.4600  g_loss:1.6818
# epoch:772  d_loss:0.4279  g_loss:1.6647
# epoch:773  d_loss:0.5338  g_loss:1.2473
# epoch:774  d_loss:0.4111  g_loss:1.4233
# epoch:775  d_loss:0.4954  g_loss:1.6393
# epoch:776  d_loss:0.3767  g_loss:2.0698
# epoch:777  d_loss:0.1479  g_loss:2.5796
# epoch:778  d_loss:0.2980  g_loss:2.5987
# epoch:779  d_loss:0.3230  g_loss:2.4015
# epoch:780  d_loss:0.3031  g_loss:2.8657
# epoch:781  d_loss:0.3301  g_loss:2.1322
# epoch:782  d_loss:0.3091  g_loss:2.3574
# epoch:783  d_loss:0.3013  g_loss:2.1343
# epoch:784  d_loss:0.3949  g_loss:1.7559
# epoch:785  d_loss:0.2116  g_loss:2.3601
# epoch:786  d_loss:0.5313  g_loss:1.8925
# epoch:787  d_loss:0.3737  g_loss:2.0457
# epoch:788  d_loss:0.3877  g_loss:2.0505
# epoch:789  d_loss:0.4106  g_loss:2.0665
# epoch:790  d_loss:0.4849  g_loss:2.1985
# epoch:791  d_loss:0.3710  g_loss:2.5849
# epoch:792  d_loss:0.5344  g_loss:2.2322
# epoch:793  d_loss:0.5924  g_loss:2.2452
# epoch:794  d_loss:0.4632  g_loss:2.2569
# epoch:795  d_loss:0.4425  g_loss:1.8310
# epoch:796  d_loss:0.5725  g_loss:1.7353
# epoch:797  d_loss:0.2996  g_loss:2.0836
# epoch:798  d_loss:0.3682  g_loss:2.2491
# epoch:799  d_loss:0.3871  g_loss:2.6353
# epoch:800  d_loss:0.5352  g_loss:2.2147
# epoch:801  d_loss:0.3114  g_loss:2.2405
# epoch:802  d_loss:0.3703  g_loss:2.0641
# epoch:803  d_loss:0.2958  g_loss:2.1973
# epoch:804  d_loss:0.2984  g_loss:1.9229
# epoch:805  d_loss:0.3704  g_loss:2.3133
# epoch:806  d_loss:0.3548  g_loss:2.1872
# epoch:807  d_loss:0.2907  g_loss:2.4735
# epoch:808  d_loss:0.4179  g_loss:2.2484
# epoch:809  d_loss:0.2940  g_loss:2.5032
# epoch:810  d_loss:0.5032  g_loss:2.4100
# epoch:811  d_loss:0.3305  g_loss:2.1039
# epoch:812  d_loss:0.4527  g_loss:2.2925
# epoch:813  d_loss:0.4227  g_loss:2.0958
# epoch:814  d_loss:0.6601  g_loss:1.5664
# epoch:815  d_loss:0.5016  g_loss:1.5916
# epoch:816  d_loss:0.5915  g_loss:1.6880
# epoch:817  d_loss:0.4730  g_loss:1.5397
# epoch:818  d_loss:0.5365  g_loss:1.6857
# epoch:819  d_loss:0.7151  g_loss:1.5064
# epoch:820  d_loss:0.6205  g_loss:1.7695
# epoch:821  d_loss:0.6139  g_loss:1.5101
# epoch:822  d_loss:0.6389  g_loss:1.3775
# epoch:823  d_loss:0.4595  g_loss:1.6890
# epoch:824  d_loss:0.5428  g_loss:2.0501
# epoch:825  d_loss:0.4530  g_loss:2.0440
# epoch:826  d_loss:0.6662  g_loss:1.5686
# epoch:827  d_loss:0.3980  g_loss:1.9906
# epoch:828  d_loss:0.3186  g_loss:1.6032
# epoch:829  d_loss:0.2207  g_loss:2.0127
# epoch:830  d_loss:0.2027  g_loss:2.6113
# epoch:831  d_loss:0.1850  g_loss:3.2529
# epoch:832  d_loss:0.1127  g_loss:3.5096
# epoch:833  d_loss:0.1404  g_loss:3.8388
# epoch:834  d_loss:0.1435  g_loss:3.6807
# epoch:835  d_loss:0.2135  g_loss:3.0600
# epoch:836  d_loss:0.1446  g_loss:2.6392
# epoch:837  d_loss:0.1866  g_loss:2.8729
# epoch:838  d_loss:0.2742  g_loss:3.0261
# epoch:839  d_loss:0.3138  g_loss:4.0410
# epoch:840  d_loss:0.3725  g_loss:3.3884
# epoch:841  d_loss:0.2125  g_loss:3.5238
# epoch:842  d_loss:0.4257  g_loss:2.9263
# epoch:843  d_loss:0.2899  g_loss:2.7100
# epoch:844  d_loss:0.4541  g_loss:2.9102
# epoch:845  d_loss:0.3916  g_loss:2.8523
# epoch:846  d_loss:0.5753  g_loss:2.0918
# epoch:847  d_loss:0.6334  g_loss:1.7714
# epoch:848  d_loss:0.8645  g_loss:1.3638
# epoch:849  d_loss:0.7620  g_loss:1.8423
# epoch:850  d_loss:0.5752  g_loss:1.9519
# epoch:851  d_loss:0.7630  g_loss:2.0264
# epoch:852  d_loss:0.6908  g_loss:1.9262
# epoch:853  d_loss:0.7033  g_loss:1.0950
# epoch:854  d_loss:0.5850  g_loss:1.2830
# epoch:855  d_loss:0.5283  g_loss:1.3489
# epoch:856  d_loss:0.3821  g_loss:1.4910
# epoch:857  d_loss:0.5880  g_loss:1.5724
# epoch:858  d_loss:0.4100  g_loss:1.9139
# epoch:859  d_loss:0.4383  g_loss:1.8177
# epoch:860  d_loss:0.3483  g_loss:2.0570
# epoch:861  d_loss:0.4304  g_loss:1.6790
# epoch:862  d_loss:0.3919  g_loss:1.6153
# epoch:863  d_loss:0.2869  g_loss:2.3243
# epoch:864  d_loss:0.2624  g_loss:2.7533
# epoch:865  d_loss:0.2775  g_loss:2.8193
# epoch:866  d_loss:0.3356  g_loss:3.1341
# epoch:867  d_loss:0.3237  g_loss:2.1294
# epoch:868  d_loss:0.3067  g_loss:2.5995
# epoch:869  d_loss:0.2447  g_loss:2.3568
# epoch:870  d_loss:0.2380  g_loss:2.0180
# epoch:871  d_loss:0.2176  g_loss:2.4391
# epoch:872  d_loss:0.2973  g_loss:2.5774
# epoch:873  d_loss:0.3831  g_loss:2.5575
# epoch:874  d_loss:0.3002  g_loss:2.6693
# epoch:875  d_loss:0.2467  g_loss:3.1552
# epoch:876  d_loss:0.3183  g_loss:2.9439
# epoch:877  d_loss:0.3434  g_loss:2.5418
# epoch:878  d_loss:0.3774  g_loss:2.4621
# epoch:879  d_loss:0.5144  g_loss:2.2598
# epoch:880  d_loss:0.3360  g_loss:2.1214
# epoch:881  d_loss:0.3650  g_loss:2.7102
# epoch:882  d_loss:0.3174  g_loss:2.7222
# epoch:883  d_loss:0.4484  g_loss:2.3622
# epoch:884  d_loss:0.4471  g_loss:2.1839
# epoch:885  d_loss:0.5854  g_loss:1.8996
# epoch:886  d_loss:0.4345  g_loss:2.2400
# epoch:887  d_loss:0.6177  g_loss:2.0890
# epoch:888  d_loss:0.4928  g_loss:2.2640
# epoch:889  d_loss:0.5460  g_loss:2.3352
# epoch:890  d_loss:0.5599  g_loss:1.8913
# epoch:891  d_loss:0.3635  g_loss:1.5958
# epoch:892  d_loss:0.3881  g_loss:1.8921
# epoch:893  d_loss:0.5480  g_loss:1.8035
# epoch:894  d_loss:0.3350  g_loss:2.1264
# epoch:895  d_loss:0.5416  g_loss:2.2525
# epoch:896  d_loss:0.4465  g_loss:2.3700
# epoch:897  d_loss:0.4435  g_loss:2.3977
# epoch:898  d_loss:0.2963  g_loss:2.1195
# epoch:899  d_loss:0.2714  g_loss:2.2479
# epoch:900  d_loss:0.3681  g_loss:1.6909
# epoch:901  d_loss:0.4287  g_loss:1.9472
# epoch:902  d_loss:0.3485  g_loss:2.2078
# epoch:903  d_loss:0.3365  g_loss:2.4364
# epoch:904  d_loss:0.3256  g_loss:2.5088
# epoch:905  d_loss:0.4106  g_loss:1.9964
# epoch:906  d_loss:0.4077  g_loss:1.6954
# epoch:907  d_loss:0.4035  g_loss:1.7013
# epoch:908  d_loss:0.4654  g_loss:1.9377
# epoch:909  d_loss:0.3931  g_loss:2.1726
# epoch:910  d_loss:0.3421  g_loss:2.4418
# epoch:911  d_loss:0.3404  g_loss:2.1966
# epoch:912  d_loss:0.4106  g_loss:1.8524
# epoch:913  d_loss:0.3407  g_loss:1.7000
# epoch:914  d_loss:0.3981  g_loss:2.0732
# epoch:915  d_loss:0.2564  g_loss:1.9460
# epoch:916  d_loss:0.2737  g_loss:1.9691
# epoch:917  d_loss:0.2276  g_loss:2.0071
# epoch:918  d_loss:0.3634  g_loss:2.2201
# epoch:919  d_loss:0.3574  g_loss:2.5387
# epoch:920  d_loss:0.3439  g_loss:2.5870
# epoch:921  d_loss:0.3893  g_loss:2.4325
# epoch:922  d_loss:0.3904  g_loss:2.2460
# epoch:923  d_loss:0.3273  g_loss:2.1230
# epoch:924  d_loss:0.4038  g_loss:1.7183
# epoch:925  d_loss:0.5094  g_loss:1.5040
# epoch:926  d_loss:0.2821  g_loss:1.9302
# epoch:927  d_loss:0.3133  g_loss:2.2053
# epoch:928  d_loss:0.3284  g_loss:2.0008
# epoch:929  d_loss:0.3681  g_loss:1.9465
# epoch:930  d_loss:0.3972  g_loss:2.1882
# epoch:931  d_loss:0.4533  g_loss:2.3476
# epoch:932  d_loss:0.3617  g_loss:2.2230
# epoch:933  d_loss:0.3826  g_loss:2.1558
# epoch:934  d_loss:0.2243  g_loss:2.2062
# epoch:935  d_loss:0.3517  g_loss:2.1446
# epoch:936  d_loss:0.3628  g_loss:2.5929
# epoch:937  d_loss:0.4852  g_loss:2.0879
# epoch:938  d_loss:0.4425  g_loss:1.4541
# epoch:939  d_loss:0.5313  g_loss:1.2404
# epoch:940  d_loss:0.4843  g_loss:1.7043
# epoch:941  d_loss:0.3572  g_loss:2.1272
# epoch:942  d_loss:0.3670  g_loss:2.3252
# epoch:943  d_loss:0.3640  g_loss:2.3669
# epoch:944  d_loss:0.3886  g_loss:1.8915
# epoch:945  d_loss:0.3841  g_loss:1.8446
# epoch:946  d_loss:0.4752  g_loss:1.5375
# epoch:947  d_loss:0.4224  g_loss:1.7271
# epoch:948  d_loss:0.3449  g_loss:1.7944
# epoch:949  d_loss:0.4012  g_loss:1.7593
# epoch:950  d_loss:0.3331  g_loss:1.4542
# epoch:951  d_loss:0.3984  g_loss:1.5709
# epoch:952  d_loss:0.3565  g_loss:2.1782
# epoch:953  d_loss:0.5004  g_loss:1.9233
# epoch:954  d_loss:0.3740  g_loss:1.8505
# epoch:955  d_loss:0.4207  g_loss:1.8705
# epoch:956  d_loss:0.4730  g_loss:1.8622
# epoch:957  d_loss:0.3738  g_loss:2.0333
# epoch:958  d_loss:0.4634  g_loss:1.8703
# epoch:959  d_loss:0.5313  g_loss:1.5744
# epoch:960  d_loss:0.4059  g_loss:1.4827
# epoch:961  d_loss:0.2758  g_loss:1.9006
# epoch:962  d_loss:0.4106  g_loss:1.6771
# epoch:963  d_loss:0.2544  g_loss:1.9223
# epoch:964  d_loss:0.2413  g_loss:2.1838
# epoch:965  d_loss:0.4504  g_loss:2.1621
# epoch:966  d_loss:0.4055  g_loss:1.7122
# epoch:967  d_loss:0.3864  g_loss:1.4137
# epoch:968  d_loss:0.3212  g_loss:1.8849
# epoch:969  d_loss:0.4023  g_loss:1.5988
# epoch:970  d_loss:0.3770  g_loss:1.6715
# epoch:971  d_loss:0.4885  g_loss:1.9562
# epoch:972  d_loss:0.4107  g_loss:1.6726
# epoch:973  d_loss:0.3683  g_loss:1.4909
# epoch:974  d_loss:0.3087  g_loss:1.8636
# epoch:975  d_loss:0.3887  g_loss:1.5559
# epoch:976  d_loss:0.3475  g_loss:2.3569
# epoch:977  d_loss:0.4153  g_loss:2.0874
# epoch:978  d_loss:0.4193  g_loss:1.9249
# epoch:979  d_loss:0.5451  g_loss:1.5651
# epoch:980  d_loss:0.3942  g_loss:1.6967
# epoch:981  d_loss:0.3053  g_loss:2.0156
# epoch:982  d_loss:0.4375  g_loss:1.7704
# epoch:983  d_loss:0.4768  g_loss:1.5682
# epoch:984  d_loss:0.4471  g_loss:1.9032
# epoch:985  d_loss:0.3927  g_loss:1.8295
# epoch:986  d_loss:0.3554  g_loss:1.8679
# epoch:987  d_loss:0.4061  g_loss:1.7249
# epoch:988  d_loss:0.3080  g_loss:2.2866
# epoch:989  d_loss:0.3287  g_loss:2.0635
# epoch:990  d_loss:0.2951  g_loss:1.9144
# epoch:991  d_loss:0.2928  g_loss:2.2555
# epoch:992  d_loss:0.4329  g_loss:1.9672
# epoch:993  d_loss:0.2763  g_loss:2.1027
# epoch:994  d_loss:0.4389  g_loss:1.9298
# epoch:995  d_loss:0.5888  g_loss:1.8393
# epoch:996  d_loss:0.5578  g_loss:1.4411
# epoch:997  d_loss:0.4541  g_loss:1.6554
# epoch:998  d_loss:0.4620  g_loss:2.2008
# epoch:999  d_loss:0.3413  g_loss:1.7919
# epoch:1000  d_loss:0.3363  g_loss:1.9967
# epoch:1001  d_loss:0.4546  g_loss:1.4944
# epoch:1002  d_loss:0.3677  g_loss:1.7310
# epoch:1003  d_loss:0.5091  g_loss:1.4114
# epoch:1004  d_loss:0.3950  g_loss:1.6725
# epoch:1005  d_loss:0.3986  g_loss:1.7399
# epoch:1006  d_loss:0.3799  g_loss:2.0180
# epoch:1007  d_loss:0.3682  g_loss:2.1194
# epoch:1008  d_loss:0.3000  g_loss:2.0864
# epoch:1009  d_loss:0.2605  g_loss:2.1030
# epoch:1010  d_loss:0.2842  g_loss:1.8944
# epoch:1011  d_loss:0.4701  g_loss:1.5773
# epoch:1012  d_loss:0.4155  g_loss:1.3429
# epoch:1013  d_loss:0.2704  g_loss:2.1932
# epoch:1014  d_loss:0.3277  g_loss:2.0188
# epoch:1015  d_loss:0.3625  g_loss:2.6065
# epoch:1016  d_loss:0.3710  g_loss:2.7228
# epoch:1017  d_loss:0.4217  g_loss:2.4188
# epoch:1018  d_loss:0.2907  g_loss:1.8243
# epoch:1019  d_loss:0.2725  g_loss:1.6615
# epoch:1020  d_loss:0.3388  g_loss:2.0386
# epoch:1021  d_loss:0.2943  g_loss:2.4504
# epoch:1022  d_loss:0.2617  g_loss:2.6653
# epoch:1023  d_loss:0.2924  g_loss:2.8978
# epoch:1024  d_loss:0.5601  g_loss:2.0435
# epoch:1025  d_loss:0.4106  g_loss:1.7953
# epoch:1026  d_loss:0.3388  g_loss:1.5209
# epoch:1027  d_loss:0.3196  g_loss:1.9618
# epoch:1028  d_loss:0.3117  g_loss:2.8656
# epoch:1029  d_loss:0.2637  g_loss:3.0623
# epoch:1030  d_loss:0.2129  g_loss:2.7876
# epoch:1031  d_loss:0.4159  g_loss:2.1724
# epoch:1032  d_loss:0.4031  g_loss:1.8300
# epoch:1033  d_loss:0.4073  g_loss:2.2789
# epoch:1034  d_loss:0.5344  g_loss:1.6422
# epoch:1035  d_loss:0.2910  g_loss:2.4732
# epoch:1036  d_loss:0.5552  g_loss:2.3079
# epoch:1037  d_loss:0.4260  g_loss:1.9534
# epoch:1038  d_loss:0.3637  g_loss:1.6811
# epoch:1039  d_loss:0.4843  g_loss:1.5846
# epoch:1040  d_loss:0.4778  g_loss:2.0525
# epoch:1041  d_loss:0.6886  g_loss:2.0846
# epoch:1042  d_loss:0.5889  g_loss:1.6480
# epoch:1043  d_loss:0.4056  g_loss:1.8063
# epoch:1044  d_loss:0.6026  g_loss:1.8264
# epoch:1045  d_loss:0.5819  g_loss:1.2387
# epoch:1046  d_loss:0.4172  g_loss:1.7848
# epoch:1047  d_loss:0.3663  g_loss:2.5634
# epoch:1048  d_loss:0.2922  g_loss:2.5215
# epoch:1049  d_loss:0.4127  g_loss:2.3151
# epoch:1050  d_loss:0.5214  g_loss:2.0224
# epoch:1051  d_loss:0.4023  g_loss:1.7165
# epoch:1052  d_loss:0.4524  g_loss:1.5118
# epoch:1053  d_loss:0.4359  g_loss:1.7795
# epoch:1054  d_loss:0.3264  g_loss:2.0357
# epoch:1055  d_loss:0.3300  g_loss:2.7159
# epoch:1056  d_loss:0.2775  g_loss:2.7975
# epoch:1057  d_loss:0.2399  g_loss:2.4570
# epoch:1058  d_loss:0.2165  g_loss:2.2700
# epoch:1059  d_loss:0.3033  g_loss:2.0245
# epoch:1060  d_loss:0.2357  g_loss:2.2813
# epoch:1061  d_loss:0.3210  g_loss:2.3735
# epoch:1062  d_loss:0.3144  g_loss:2.1319
# epoch:1063  d_loss:0.3597  g_loss:2.4219
# epoch:1064  d_loss:0.3243  g_loss:2.3523
# epoch:1065  d_loss:0.3330  g_loss:2.3696
# epoch:1066  d_loss:0.2395  g_loss:2.7810
# epoch:1067  d_loss:0.4336  g_loss:2.2052
# epoch:1068  d_loss:0.2521  g_loss:2.3112
# epoch:1069  d_loss:0.2572  g_loss:2.7158
# epoch:1070  d_loss:0.4771  g_loss:2.1892
# epoch:1071  d_loss:0.3607  g_loss:2.2779
# epoch:1072  d_loss:0.4256  g_loss:2.6582
# epoch:1073  d_loss:0.2586  g_loss:2.5562
# epoch:1074  d_loss:0.3062  g_loss:2.5310
# epoch:1075  d_loss:0.3366  g_loss:2.0757
# epoch:1076  d_loss:0.3039  g_loss:2.2172
# epoch:1077  d_loss:0.2263  g_loss:2.3734
# epoch:1078  d_loss:0.3011  g_loss:2.6149
# epoch:1079  d_loss:0.3231  g_loss:2.3217
# epoch:1080  d_loss:0.5354  g_loss:2.3929
# epoch:1081  d_loss:0.2656  g_loss:2.6980
# epoch:1082  d_loss:0.4789  g_loss:2.0443
# epoch:1083  d_loss:0.4066  g_loss:1.9312
# epoch:1084  d_loss:0.4329  g_loss:2.0562
# epoch:1085  d_loss:0.3819  g_loss:2.0692
# epoch:1086  d_loss:0.4817  g_loss:2.1858
# epoch:1087  d_loss:0.5342  g_loss:2.3025
# epoch:1088  d_loss:0.4742  g_loss:2.0682
# epoch:1089  d_loss:0.3458  g_loss:1.9308
# epoch:1090  d_loss:0.4570  g_loss:1.9482
# epoch:1091  d_loss:0.5053  g_loss:1.6513
# epoch:1092  d_loss:0.2802  g_loss:2.4607
# epoch:1093  d_loss:0.3767  g_loss:2.4850
# epoch:1094  d_loss:0.4145  g_loss:2.6421
# epoch:1095  d_loss:0.3120  g_loss:2.3212
# epoch:1096  d_loss:0.4161  g_loss:1.9715
# epoch:1097  d_loss:0.3943  g_loss:2.1730
# epoch:1098  d_loss:0.3276  g_loss:2.2648
# epoch:1099  d_loss:0.3843  g_loss:2.2420
# epoch:1100  d_loss:0.4265  g_loss:2.2008
# epoch:1101  d_loss:0.2780  g_loss:2.7974
# epoch:1102  d_loss:0.3920  g_loss:2.5339
# epoch:1103  d_loss:0.5118  g_loss:2.2999
# epoch:1104  d_loss:0.3997  g_loss:2.0095
# epoch:1105  d_loss:0.4357  g_loss:1.7648
# epoch:1106  d_loss:0.3886  g_loss:2.0618
# epoch:1107  d_loss:0.4694  g_loss:2.2553
# epoch:1108  d_loss:0.3000  g_loss:2.3745
# epoch:1109  d_loss:0.4187  g_loss:2.1699
# epoch:1110  d_loss:0.4656  g_loss:1.6666
# epoch:1111  d_loss:0.5234  g_loss:1.9392
# epoch:1112  d_loss:0.2768  g_loss:2.3906
# epoch:1113  d_loss:0.4614  g_loss:2.3501
# epoch:1114  d_loss:0.4436  g_loss:2.0935
# epoch:1115  d_loss:0.4439  g_loss:2.7074
# epoch:1116  d_loss:0.5783  g_loss:1.7114
# epoch:1117  d_loss:0.4054  g_loss:1.8827
# epoch:1118  d_loss:0.4716  g_loss:2.0237
# epoch:1119  d_loss:0.3907  g_loss:1.9384
# epoch:1120  d_loss:0.4119  g_loss:1.9431
# epoch:1121  d_loss:0.3958  g_loss:2.1158
# epoch:1122  d_loss:0.3053  g_loss:2.5356
# epoch:1123  d_loss:0.5774  g_loss:2.2498
# epoch:1124  d_loss:0.4558  g_loss:1.5809
# epoch:1125  d_loss:0.5801  g_loss:1.5279
# epoch:1126  d_loss:0.3591  g_loss:1.5050
# epoch:1127  d_loss:0.4307  g_loss:2.0613
# epoch:1128  d_loss:0.2935  g_loss:2.4641
# epoch:1129  d_loss:0.4850  g_loss:1.8704
# epoch:1130  d_loss:0.5116  g_loss:1.6734
# epoch:1131  d_loss:0.3666  g_loss:1.7779
# epoch:1132  d_loss:0.4491  g_loss:1.4302
# epoch:1133  d_loss:0.3753  g_loss:1.7239
# epoch:1134  d_loss:0.4619  g_loss:2.4058
# epoch:1135  d_loss:0.5644  g_loss:2.2469
# epoch:1136  d_loss:0.5984  g_loss:2.0231
# epoch:1137  d_loss:0.3738  g_loss:1.9003
# epoch:1138  d_loss:0.4084  g_loss:2.2597
# epoch:1139  d_loss:0.4287  g_loss:1.9557
# epoch:1140  d_loss:0.4526  g_loss:2.0273
# epoch:1141  d_loss:0.5339  g_loss:2.2498
# epoch:1142  d_loss:0.4099  g_loss:2.2664
# epoch:1143  d_loss:0.4216  g_loss:2.1136
# epoch:1144  d_loss:0.6623  g_loss:2.2733
# epoch:1145  d_loss:0.4750  g_loss:1.9012
# epoch:1146  d_loss:0.4939  g_loss:1.7035
# epoch:1147  d_loss:0.4185  g_loss:1.4148
# epoch:1148  d_loss:0.3034  g_loss:2.0971
# epoch:1149  d_loss:0.3118  g_loss:2.4640
# epoch:1150  d_loss:0.3939  g_loss:2.3371
# epoch:1151  d_loss:0.2942  g_loss:2.2679
# epoch:1152  d_loss:0.3958  g_loss:2.5133
# epoch:1153  d_loss:0.5164  g_loss:1.9952
# epoch:1154  d_loss:0.4171  g_loss:1.5547
# epoch:1155  d_loss:0.4371  g_loss:2.0485
# epoch:1156  d_loss:0.4440  g_loss:1.9661
# epoch:1157  d_loss:0.3875  g_loss:2.4707
# epoch:1158  d_loss:0.4801  g_loss:2.3964
# epoch:1159  d_loss:0.4740  g_loss:2.0128
# epoch:1160  d_loss:0.5455  g_loss:1.5740
# epoch:1161  d_loss:0.3537  g_loss:1.6171
# epoch:1162  d_loss:0.5055  g_loss:1.8398
# epoch:1163  d_loss:0.4301  g_loss:2.1543
# epoch:1164  d_loss:0.3596  g_loss:2.2982
# epoch:1165  d_loss:0.4484  g_loss:1.9670
# epoch:1166  d_loss:0.3989  g_loss:2.2131
# epoch:1167  d_loss:0.4738  g_loss:2.0440
# epoch:1168  d_loss:0.3479  g_loss:1.6511
# epoch:1169  d_loss:0.5106  g_loss:1.7152
# epoch:1170  d_loss:0.3848  g_loss:1.6059
# epoch:1171  d_loss:0.4592  g_loss:1.7103
# epoch:1172  d_loss:0.4634  g_loss:1.9149
# epoch:1173  d_loss:0.3885  g_loss:2.1427
# epoch:1174  d_loss:0.4184  g_loss:1.7065
# epoch:1175  d_loss:0.3682  g_loss:2.3957
# epoch:1176  d_loss:0.5004  g_loss:1.7507
# epoch:1177  d_loss:0.5039  g_loss:1.8480
# epoch:1178  d_loss:0.4842  g_loss:1.8927
# epoch:1179  d_loss:0.3271  g_loss:2.5712
# epoch:1180  d_loss:0.4645  g_loss:2.3300
# epoch:1181  d_loss:0.4155  g_loss:1.7303
# epoch:1182  d_loss:0.3465  g_loss:2.2200
# epoch:1183  d_loss:0.4012  g_loss:2.2215
# epoch:1184  d_loss:0.4991  g_loss:1.4520
# epoch:1185  d_loss:0.5212  g_loss:1.6584
# epoch:1186  d_loss:0.4005  g_loss:1.7208
# epoch:1187  d_loss:0.5428  g_loss:2.0028
# epoch:1188  d_loss:0.4944  g_loss:3.0438
# epoch:1189  d_loss:0.6354  g_loss:2.4975
# epoch:1190  d_loss:0.4410  g_loss:1.8266
# epoch:1191  d_loss:0.4382  g_loss:1.4000
# epoch:1192  d_loss:0.4906  g_loss:1.1086
# ...
# epoch:3619  d_loss:0.4038  g_loss:1.5375
# epoch:3620  d_loss:0.5292  g_loss:1.5118
# epoch:3621  d_loss:0.4335  g_loss:1.8132
# epoch:3622  d_loss:0.5111  g_loss:1.9076
# epoch:3623  d_loss:0.5911  g_loss:1.5652
# epoch:3624  d_loss:0.5004  g_loss:1.7343
# epoch:3625  d_loss:0.4800  g_loss:1.4542
# epoch:3626  d_loss:0.5502  g_loss:1.4701
# epoch:3627  d_loss:0.5031  g_loss:1.6661
# epoch:3628  d_loss:0.5325  g_loss:1.7343
# epoch:3629  d_loss:0.5321  g_loss:1.6652
# epoch:3630  d_loss:0.6801  g_loss:1.3104
# epoch:3631  d_loss:0.5264  g_loss:1.7163
# epoch:3632  d_loss:0.4506  g_loss:1.7685
# epoch:3633  d_loss:0.3754  g_loss:2.6591
# epoch:3634  d_loss:0.5585  g_loss:2.3035
# epoch:3635  d_loss:0.6260  g_loss:1.6197
# epoch:3636  d_loss:0.5001  g_loss:1.7855
# epoch:3637  d_loss:0.5209  g_loss:1.4002
# epoch:3638  d_loss:0.4450  g_loss:1.8121
# epoch:3639  d_loss:0.4667  g_loss:2.5039
# epoch:3640  d_loss:0.7699  g_loss:1.8180
# epoch:3641  d_loss:0.4223  g_loss:2.3635
# epoch:3642  d_loss:0.5765  g_loss:2.2371
# epoch:3643  d_loss:0.4002  g_loss:2.3082
# epoch:3644  d_loss:0.4501  g_loss:2.1149
# epoch:3645  d_loss:0.5493  g_loss:1.6058
# epoch:3646  d_loss:0.4224  g_loss:1.7533
# epoch:3647  d_loss:0.5422  g_loss:1.6898
# epoch:3648  d_loss:0.4157  g_loss:1.7720
# epoch:3649  d_loss:0.4101  g_loss:1.7269
# epoch:3650  d_loss:0.4562  g_loss:1.8107
# epoch:3651  d_loss:0.3853  g_loss:2.2795
# epoch:3652  d_loss:0.5116  g_loss:1.6526
# epoch:3653  d_loss:0.4615  g_loss:1.4435
# epoch:3654  d_loss:0.5114  g_loss:1.4352
# epoch:3655  d_loss:0.5630  g_loss:1.5656
# epoch:3656  d_loss:0.6504  g_loss:1.4061
# epoch:3657  d_loss:0.5278  g_loss:1.3112
# epoch:3658  d_loss:0.6230  g_loss:1.4699
# epoch:3659  d_loss:0.3432  g_loss:1.8075
# epoch:3660  d_loss:0.5429  g_loss:1.6867
# epoch:3661  d_loss:0.4599  g_loss:2.2724
# epoch:3662  d_loss:0.5827  g_loss:2.1060
# epoch:3663  d_loss:0.4913  g_loss:2.0788
# epoch:3664  d_loss:0.5941  g_loss:1.6130
# epoch:3665  d_loss:0.5541  g_loss:1.5446
# epoch:3666  d_loss:0.4495  g_loss:1.4510
# epoch:3667  d_loss:0.4531  g_loss:1.9763
# epoch:3668  d_loss:0.3918  g_loss:2.2554
# epoch:3669  d_loss:0.4555  g_loss:2.3182
# epoch:3670  d_loss:0.4127  g_loss:2.1838
# epoch:3671  d_loss:0.3246  g_loss:2.6698
# epoch:3672  d_loss:0.5061  g_loss:2.0525
# epoch:3673  d_loss:0.4503  g_loss:2.0906
# epoch:3674  d_loss:0.4025  g_loss:1.9400
# epoch:3675  d_loss:0.4007  g_loss:1.7589
# epoch:3676  d_loss:0.5250  g_loss:1.4424
# epoch:3677  d_loss:0.3657  g_loss:2.1407
# epoch:3678  d_loss:0.4764  g_loss:1.7222
# epoch:3679  d_loss:0.5850  g_loss:1.8235
# epoch:3680  d_loss:0.4074  g_loss:1.7962
# epoch:3681  d_loss:0.4199  g_loss:2.1137
# epoch:3682  d_loss:0.5698  g_loss:1.4460
# epoch:3683  d_loss:0.6829  g_loss:1.1287
# epoch:3684  d_loss:0.3949  g_loss:1.5476
# epoch:3685  d_loss:0.5422  g_loss:1.6355
# epoch:3686  d_loss:0.3728  g_loss:2.0682
# epoch:3687  d_loss:0.4968  g_loss:1.8596
# epoch:3688  d_loss:0.5365  g_loss:1.6489
# epoch:3689  d_loss:0.6104  g_loss:1.1790
# epoch:3690  d_loss:0.7899  g_loss:1.2371
# epoch:3691  d_loss:0.6412  g_loss:1.8376
# epoch:3692  d_loss:0.6619  g_loss:1.9427
# epoch:3693  d_loss:0.5477  g_loss:2.1775
# epoch:3694  d_loss:0.4357  g_loss:2.3527
# epoch:3695  d_loss:0.5776  g_loss:1.8089
# epoch:3696  d_loss:0.5799  g_loss:1.7336
# epoch:3697  d_loss:0.4905  g_loss:1.5752
# epoch:3698  d_loss:0.5289  g_loss:1.4722
# epoch:3699  d_loss:0.4627  g_loss:1.7963
# epoch:3700  d_loss:0.3686  g_loss:2.6495
# epoch:3701  d_loss:0.3537  g_loss:2.0691
# epoch:3702  d_loss:0.5651  g_loss:2.2627
# epoch:3703  d_loss:0.5268  g_loss:1.9813
# epoch:3704  d_loss:0.4712  g_loss:1.8558
# epoch:3705  d_loss:0.4045  g_loss:1.8281
# epoch:3706  d_loss:0.3965  g_loss:2.3179
# epoch:3707  d_loss:0.4214  g_loss:2.4361
# epoch:3708  d_loss:0.4625  g_loss:2.0470
# epoch:3709  d_loss:0.5885  g_loss:2.1308
# epoch:3710  d_loss:0.5053  g_loss:2.1217
# epoch:3711  d_loss:0.4611  g_loss:2.1635
# epoch:3712  d_loss:0.3586  g_loss:1.8637
# epoch:3713  d_loss:0.3667  g_loss:2.1939
# epoch:3714  d_loss:0.6168  g_loss:1.4912
# epoch:3715  d_loss:0.4907  g_loss:1.7941
# epoch:3716  d_loss:0.4366  g_loss:1.8177
# epoch:3717  d_loss:0.5358  g_loss:1.9599
# epoch:3718  d_loss:0.4639  g_loss:1.9581
# epoch:3719  d_loss:0.4330  g_loss:2.0919
# epoch:3720  d_loss:0.5169  g_loss:2.4059
# epoch:3721  d_loss:0.7206  g_loss:2.2057
# epoch:3722  d_loss:0.4072  g_loss:2.2430
# epoch:3723  d_loss:0.4332  g_loss:2.0600
# epoch:3724  d_loss:0.6303  g_loss:1.8478
# epoch:3725  d_loss:0.6162  g_loss:1.8214
# epoch:3726  d_loss:0.5046  g_loss:1.5037
# epoch:3727  d_loss:0.5863  g_loss:1.2936
# epoch:3728  d_loss:0.6389  g_loss:1.3442
# epoch:3729  d_loss:0.4893  g_loss:1.6295
# epoch:3730  d_loss:0.5676  g_loss:1.5921
# epoch:3731  d_loss:0.5907  g_loss:1.9000
# epoch:3732  d_loss:0.6610  g_loss:1.4841
# epoch:3733  d_loss:0.4965  g_loss:1.3501
# epoch:3734  d_loss:0.4940  g_loss:1.6143
# epoch:3735  d_loss:0.5422  g_loss:1.7173
# epoch:3736  d_loss:0.4056  g_loss:1.7371
# epoch:3737  d_loss:0.3231  g_loss:1.8442
# epoch:3738  d_loss:0.4641  g_loss:1.8351
# epoch:3739  d_loss:0.3466  g_loss:1.8696
# epoch:3740  d_loss:0.4496  g_loss:1.6685
# epoch:3741  d_loss:0.4845  g_loss:1.9402
# epoch:3742  d_loss:0.4922  g_loss:2.1238
# epoch:3743  d_loss:0.4841  g_loss:2.1781
# epoch:3744  d_loss:0.3294  g_loss:2.3230
# epoch:3745  d_loss:0.4470  g_loss:2.3015
# epoch:3746  d_loss:0.4374  g_loss:1.7179
# epoch:3747  d_loss:0.3923  g_loss:1.7454
# epoch:3748  d_loss:0.2967  g_loss:1.7962
# epoch:3749  d_loss:0.3734  g_loss:1.8943
# epoch:3750  d_loss:0.4557  g_loss:1.6813
# epoch:3751  d_loss:0.3619  g_loss:1.8390
# epoch:3752  d_loss:0.3795  g_loss:1.9448
# epoch:3753  d_loss:0.4344  g_loss:1.7734
# epoch:3754  d_loss:0.4869  g_loss:2.0124
# epoch:3755  d_loss:0.4501  g_loss:1.7291
# epoch:3756  d_loss:0.5906  g_loss:1.4063
# epoch:3757  d_loss:0.4112  g_loss:1.9119
# epoch:3758  d_loss:0.4970  g_loss:2.1529
# epoch:3759  d_loss:0.5399  g_loss:2.0623
# epoch:3760  d_loss:0.7314  g_loss:2.0590
# epoch:3761  d_loss:0.6748  g_loss:1.6914
# epoch:3762  d_loss:0.4385  g_loss:1.5340
# epoch:3763  d_loss:0.6686  g_loss:1.5379
# epoch:3764  d_loss:0.5697  g_loss:1.6771
# epoch:3765  d_loss:0.4436  g_loss:1.9261
# epoch:3766  d_loss:0.3770  g_loss:2.1860
# epoch:3767  d_loss:0.5766  g_loss:2.1058
# epoch:3768  d_loss:0.6166  g_loss:1.4694
# epoch:3769  d_loss:0.4967  g_loss:1.5656
# epoch:3770  d_loss:0.4221  g_loss:1.5521
# epoch:3771  d_loss:0.4391  g_loss:1.8027
# epoch:3772  d_loss:0.4601  g_loss:1.5933
# epoch:3773  d_loss:0.4142  g_loss:1.7169
# epoch:3774  d_loss:0.4697  g_loss:1.5512
# epoch:3775  d_loss:0.5780  g_loss:1.9567
# epoch:3776  d_loss:0.4266  g_loss:1.8630
# epoch:3777  d_loss:0.4356  g_loss:2.1546
# epoch:3778  d_loss:0.4153  g_loss:1.9597
# epoch:3779  d_loss:0.4340  g_loss:1.8875
# epoch:3780  d_loss:0.3539  g_loss:1.9223
# epoch:3781  d_loss:0.4588  g_loss:1.7582
# epoch:3782  d_loss:0.4815  g_loss:1.6434
# epoch:3783  d_loss:0.5742  g_loss:1.2881
# epoch:3784  d_loss:0.6016  g_loss:1.8476
# epoch:3785  d_loss:0.4545  g_loss:2.1494
# epoch:3786  d_loss:0.5225  g_loss:1.7243
# epoch:3787  d_loss:0.4662  g_loss:1.7949
# epoch:3788  d_loss:0.4932  g_loss:1.6705
# epoch:3789  d_loss:0.4563  g_loss:1.5779
# epoch:3790  d_loss:0.4719  g_loss:1.7032
# epoch:3791  d_loss:0.5018  g_loss:1.8147
# epoch:3792  d_loss:0.3632  g_loss:2.0838
# epoch:3793  d_loss:0.5299  g_loss:2.0005
# epoch:3794  d_loss:0.4585  g_loss:1.8907
# epoch:3795  d_loss:0.5047  g_loss:2.2213
# epoch:3796  d_loss:0.5295  g_loss:2.0522
# epoch:3797  d_loss:0.4849  g_loss:1.6857
# epoch:3798  d_loss:0.5052  g_loss:1.2913
# epoch:3799  d_loss:0.6148  g_loss:1.4746
# epoch:3800  d_loss:0.4911  g_loss:1.4330
# epoch:3801  d_loss:0.4324  g_loss:1.7827
# epoch:3802  d_loss:0.4832  g_loss:1.4842
# epoch:3803  d_loss:0.5120  g_loss:1.6708
# epoch:3804  d_loss:0.4462  g_loss:1.9715
# epoch:3805  d_loss:0.6485  g_loss:1.6970
# epoch:3806  d_loss:0.5988  g_loss:1.7500
# epoch:3807  d_loss:0.4759  g_loss:1.5902
# epoch:3808  d_loss:0.5238  g_loss:1.5787
# epoch:3809  d_loss:0.4980  g_loss:1.5291
# epoch:3810  d_loss:0.5602  g_loss:1.4807
# epoch:3811  d_loss:0.5289  g_loss:1.5796
# epoch:3812  d_loss:0.4787  g_loss:1.8095
# epoch:3813  d_loss:0.4467  g_loss:1.6763
# epoch:3814  d_loss:0.4616  g_loss:1.7570
# epoch:3815  d_loss:0.4396  g_loss:1.8875
# epoch:3816  d_loss:0.4505  g_loss:1.6306
# epoch:3817  d_loss:0.5934  g_loss:1.3758
# epoch:3818  d_loss:0.3865  g_loss:1.7288
# epoch:3819  d_loss:0.5366  g_loss:1.6189
# epoch:3820  d_loss:0.5193  g_loss:1.6779
# epoch:3821  d_loss:0.5083  g_loss:1.2185
# epoch:3822  d_loss:0.4081  g_loss:1.7763
# epoch:3823  d_loss:0.4024  g_loss:1.4555
# epoch:3824  d_loss:0.4415  g_loss:2.0434
# epoch:3825  d_loss:0.5679  g_loss:1.8310
# epoch:3826  d_loss:0.7173  g_loss:1.2672
# epoch:3827  d_loss:0.4349  g_loss:1.6884
# epoch:3828  d_loss:0.5013  g_loss:1.6835
# epoch:3829  d_loss:0.4512  g_loss:1.9951
# epoch:3830  d_loss:0.4797  g_loss:1.8464
# epoch:3831  d_loss:0.4661  g_loss:1.7928
# epoch:3832  d_loss:0.5221  g_loss:2.0355
# epoch:3833  d_loss:0.3391  g_loss:1.9455
# epoch:3834  d_loss:0.3849  g_loss:1.9510
# epoch:3835  d_loss:0.4247  g_loss:2.0072
# epoch:3836  d_loss:0.4350  g_loss:1.8288
# epoch:3837  d_loss:0.4999  g_loss:1.8568
# epoch:3838  d_loss:0.3762  g_loss:2.0495
# epoch:3839  d_loss:0.4503  g_loss:2.0286
# epoch:3840  d_loss:0.3659  g_loss:1.7234
# epoch:3841  d_loss:0.3491  g_loss:2.3143
# epoch:3842  d_loss:0.5261  g_loss:1.9380
# epoch:3843  d_loss:0.4332  g_loss:1.5437
# epoch:3844  d_loss:0.5533  g_loss:1.2607
# epoch:3845  d_loss:0.5210  g_loss:1.2536
# epoch:3846  d_loss:0.5477  g_loss:1.2860
# epoch:3847  d_loss:0.5269  g_loss:1.7944
# epoch:3848  d_loss:0.4068  g_loss:1.9765
# epoch:3849  d_loss:0.3183  g_loss:2.5345
# epoch:3850  d_loss:0.4910  g_loss:1.8782
# epoch:3851  d_loss:0.4863  g_loss:1.6831
# epoch:3852  d_loss:0.4242  g_loss:1.7904
# epoch:3853  d_loss:0.5447  g_loss:1.6978
# epoch:3854  d_loss:0.4879  g_loss:1.3324
# epoch:3855  d_loss:0.5640  g_loss:1.6019
# epoch:3856  d_loss:0.5544  g_loss:1.6505
# epoch:3857  d_loss:0.4966  g_loss:1.9253
# epoch:3858  d_loss:0.5520  g_loss:1.6787
# epoch:3859  d_loss:0.6498  g_loss:1.9737
# epoch:3860  d_loss:0.4509  g_loss:1.7761
# epoch:3861  d_loss:0.4691  g_loss:1.6043
# epoch:3862  d_loss:0.6590  g_loss:1.3887
# epoch:3863  d_loss:0.6641  g_loss:1.4497
# epoch:3864  d_loss:0.4814  g_loss:1.7744
# epoch:3865  d_loss:0.4670  g_loss:1.7029
# epoch:3866  d_loss:0.4630  g_loss:1.6955
# epoch:3867  d_loss:0.6007  g_loss:1.7217
# epoch:3868  d_loss:0.4676  g_loss:1.6918
# epoch:3869  d_loss:0.5120  g_loss:1.5298
# epoch:3870  d_loss:0.4262  g_loss:1.7931
# epoch:3871  d_loss:0.6189  g_loss:1.5561
# epoch:3872  d_loss:0.5238  g_loss:1.5576
# epoch:3873  d_loss:0.4269  g_loss:1.7995
# epoch:3874  d_loss:0.6070  g_loss:1.7171
# epoch:3875  d_loss:0.5754  g_loss:1.8897
# epoch:3876  d_loss:0.5110  g_loss:1.4624
# epoch:3877  d_loss:0.4203  g_loss:1.6383
# epoch:3878  d_loss:0.5994  g_loss:1.2909
# epoch:3879  d_loss:0.5762  g_loss:1.7311
# epoch:3880  d_loss:0.2841  g_loss:2.1727
# epoch:3881  d_loss:0.4744  g_loss:2.0481
# epoch:3882  d_loss:0.4208  g_loss:2.2666
# epoch:3883  d_loss:0.5857  g_loss:1.6795
# epoch:3884  d_loss:0.5081  g_loss:1.5262
# epoch:3885  d_loss:0.6216  g_loss:1.5839
# epoch:3886  d_loss:0.3885  g_loss:1.6492
# epoch:3887  d_loss:0.6412  g_loss:1.5601
# epoch:3888  d_loss:0.5927  g_loss:1.9166
# epoch:3889  d_loss:0.3179  g_loss:2.8597
# epoch:3890  d_loss:0.5473  g_loss:2.4012
# epoch:3891  d_loss:0.4664  g_loss:2.4267
# epoch:3892  d_loss:0.4994  g_loss:1.6531
# epoch:3893  d_loss:0.4431  g_loss:1.3960
# epoch:3894  d_loss:0.4600  g_loss:1.8802
# epoch:3895  d_loss:0.3134  g_loss:1.8773
# epoch:3896  d_loss:0.4720  g_loss:2.0406
# epoch:3897  d_loss:0.3733  g_loss:1.9734
# epoch:3898  d_loss:0.4632  g_loss:1.7302
# epoch:3899  d_loss:0.4601  g_loss:1.7384
# epoch:3900  d_loss:0.4042  g_loss:1.6485
# epoch:3901  d_loss:0.3877  g_loss:1.9206
# epoch:3902  d_loss:0.4454  g_loss:2.0358
# epoch:3903  d_loss:0.4705  g_loss:1.7470
# epoch:3904  d_loss:0.4298  g_loss:1.8474
# epoch:3905  d_loss:0.4974  g_loss:1.6366
# epoch:3906  d_loss:0.5028  g_loss:1.9244
# epoch:3907  d_loss:0.4807  g_loss:1.7586
# epoch:3908  d_loss:0.4875  g_loss:1.7590
# epoch:3909  d_loss:0.7143  g_loss:1.5278
# epoch:3910  d_loss:0.4763  g_loss:1.8370
# epoch:3911  d_loss:0.5047  g_loss:1.8401
# epoch:3912  d_loss:0.6126  g_loss:2.0835
# epoch:3913  d_loss:0.4602  g_loss:1.8335
# epoch:3914  d_loss:0.5348  g_loss:1.4475
# epoch:3915  d_loss:0.6100  g_loss:1.4920
# epoch:3916  d_loss:0.5299  g_loss:1.4682
# epoch:3917  d_loss:0.4706  g_loss:1.5507
# epoch:3918  d_loss:0.5393  g_loss:1.5981
# epoch:3919  d_loss:0.6755  g_loss:1.5933
# epoch:3920  d_loss:0.6010  g_loss:1.2874
# epoch:3921  d_loss:0.4768  g_loss:1.6009
# epoch:3922  d_loss:0.4506  g_loss:1.5907
# epoch:3923  d_loss:0.3432  g_loss:1.4320
# epoch:3924  d_loss:0.5572  g_loss:1.5379
# epoch:3925  d_loss:0.5387  g_loss:1.4041
# epoch:3926  d_loss:0.5111  g_loss:1.5095
# epoch:3927  d_loss:0.5308  g_loss:1.5482
# epoch:3928  d_loss:0.4452  g_loss:1.4902
# epoch:3929  d_loss:0.6925  g_loss:1.6939
# epoch:3930  d_loss:0.4405  g_loss:1.5348
# epoch:3931  d_loss:0.4507  g_loss:1.6013
# epoch:3932  d_loss:0.5217  g_loss:1.2663
# epoch:3933  d_loss:0.3587  g_loss:1.6865
# epoch:3934  d_loss:0.5541  g_loss:1.6883
# epoch:3935  d_loss:0.4861  g_loss:1.9284
# epoch:3936  d_loss:0.4940  g_loss:1.9933
# epoch:3937  d_loss:0.5135  g_loss:1.6262
# epoch:3938  d_loss:0.5546  g_loss:1.5681
# epoch:3939  d_loss:0.4014  g_loss:1.7640
# epoch:3940  d_loss:0.4801  g_loss:1.5803
# epoch:3941  d_loss:0.3689  g_loss:1.6882
# epoch:3942  d_loss:0.4633  g_loss:2.0192
# epoch:3943  d_loss:0.4952  g_loss:2.0712
# epoch:3944  d_loss:0.6219  g_loss:1.6257
# epoch:3945  d_loss:0.4850  g_loss:2.0086
# epoch:3946  d_loss:0.5521  g_loss:1.2530
# epoch:3947  d_loss:0.4045  g_loss:1.5197
# epoch:3948  d_loss:0.4368  g_loss:1.6825
# epoch:3949  d_loss:0.4224  g_loss:1.7905
# epoch:3950  d_loss:0.5210  g_loss:1.6155
# epoch:3951  d_loss:0.5236  g_loss:1.3696
# epoch:3952  d_loss:0.4833  g_loss:1.6689
# epoch:3953  d_loss:0.5348  g_loss:1.3186
# epoch:3954  d_loss:0.5017  g_loss:1.3645
# epoch:3955  d_loss:0.5651  g_loss:1.4345
# epoch:3956  d_loss:0.4865  g_loss:2.1356
# epoch:3957  d_loss:0.4313  g_loss:2.3206
# epoch:3958  d_loss:0.6059  g_loss:2.1501
# epoch:3959  d_loss:0.5354  g_loss:1.5939
# epoch:3960  d_loss:0.5889  g_loss:1.5822
# epoch:3961  d_loss:0.5383  g_loss:1.7793
# epoch:3962  d_loss:0.4278  g_loss:1.9049
# epoch:3963  d_loss:0.5278  g_loss:1.7479
# epoch:3964  d_loss:0.5233  g_loss:1.7895
# epoch:3965  d_loss:0.4914  g_loss:1.7713
# epoch:3966  d_loss:0.4502  g_loss:1.6476
# epoch:3967  d_loss:0.5749  g_loss:1.6048
# epoch:3968  d_loss:0.4476  g_loss:1.4561
# epoch:3969  d_loss:0.4066  g_loss:1.7472
# epoch:3970  d_loss:0.3570  g_loss:1.9793
# epoch:3971  d_loss:0.5148  g_loss:1.7963
# epoch:3972  d_loss:0.4412  g_loss:1.7387
# epoch:3973  d_loss:0.4607  g_loss:1.5338
# epoch:3974  d_loss:0.5072  g_loss:1.8799
# epoch:3975  d_loss:0.4856  g_loss:1.7148
# epoch:3976  d_loss:0.5402  g_loss:1.6005
# epoch:3977  d_loss:0.4736  g_loss:1.5419
# epoch:3978  d_loss:0.4379  g_loss:1.8373
# epoch:3979  d_loss:0.5165  g_loss:2.0999
# epoch:3980  d_loss:0.5155  g_loss:1.9899
# epoch:3981  d_loss:0.6181  g_loss:1.6716
# epoch:3982  d_loss:0.3924  g_loss:1.5824
# epoch:3983  d_loss:0.5433  g_loss:1.9315
# epoch:3984  d_loss:0.6561  g_loss:1.5194
# epoch:3985  d_loss:0.4769  g_loss:1.4989
# epoch:3986  d_loss:0.5846  g_loss:1.6892
# epoch:3987  d_loss:0.4574  g_loss:2.1580
# epoch:3988  d_loss:0.5588  g_loss:1.7819
# epoch:3989  d_loss:0.4901  g_loss:1.6358
# epoch:3990  d_loss:0.4873  g_loss:1.4952
# epoch:3991  d_loss:0.4455  g_loss:1.9959
# epoch:3992  d_loss:0.5430  g_loss:1.4600
# epoch:3993  d_loss:0.5557  g_loss:1.2314
# epoch:3994  d_loss:0.4665  g_loss:1.4365
# epoch:3995  d_loss:0.4684  g_loss:1.8197
# epoch:3996  d_loss:0.4771  g_loss:2.1512
# epoch:3997  d_loss:0.5451  g_loss:1.7187
# epoch:3998  d_loss:0.4038  g_loss:2.0662
# epoch:3999  d_loss:0.5833  g_loss:1.9953
# epoch:4000  d_loss:0.4369  g_loss:1.2410
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
