# %% [markdown]
# <a href="https://colab.research.google.com/github/junhansong/deeplearning/blob/master/deeplearning/run_project/12_Wine_Check_and_Stop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 라이브러리 호출

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import os
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### seed 값 설정

# %%
numpy.random.seed(3)
tf.random.set_seed(3)

# %% [markdown]
# ### 데이터 로딩

# %%
df_pre = pd.read_csv('https://raw.githubusercontent.com/junhansong/deeplearning/master/deeplearning/dataset/wine.csv', header=None)
df = df_pre.sample(frac=0.15)

# %% [markdown]
# ### 데이터셋 분리

# %%
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %% [markdown]
# ### 모델 설정

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### 모델 컴파일

# %%
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# %% [markdown]
# ### 모델 저장 폴더 만들기

# %%
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# %% [markdown]
# ### 모델 업데이트 및 저장

# %%
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# %% [markdown]
# ### 학습 자동 중단 설정

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# %% [markdown]
# ### 모델 실행

# %%
model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.79636, saving model to ./model/01-0.7964.hdf5
#
# Epoch 00002: val_loss improved from 0.79636 to 0.67185, saving model to ./model/02-0.6719.hdf5
#
# Epoch 00003: val_loss improved from 0.67185 to 0.56826, saving model to ./model/03-0.5683.hdf5
#
# Epoch 00004: val_loss improved from 0.56826 to 0.48467, saving model to ./model/04-0.4847.hdf5
#
# Epoch 00005: val_loss improved from 0.48467 to 0.41737, saving model to ./model/05-0.4174.hdf5
#
# Epoch 00006: val_loss improved from 0.41737 to 0.37048, saving model to ./model/06-0.3705.hdf5
#
# Epoch 00007: val_loss improved from 0.37048 to 0.35335, saving model to ./model/07-0.3534.hdf5
#
# Epoch 00008: val_loss did not improve from 0.35335
#
# Epoch 00009: val_loss did not improve from 0.35335
#
# Epoch 00010: val_loss did not improve from 0.35335
#
# Epoch 00011: val_loss did not improve from 0.35335
#
# Epoch 00012: val_loss did not improve from 0.35335
#
# ...
