# %% [markdown]
# <a href="https://colab.research.google.com/github/junhansong/deeplearning/blob/master/deeplearning/run_project/07_Sonar-K-fold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 라이브러리 호출

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

import numpy
import pandas as pd
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### seed 값 설정

# %%
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(3)

# %% [markdown]
# ### 데이터 로딩

# %%
df = pd.read_csv('https://raw.githubusercontent.com/junhansong/deeplearning/master/deeplearning/dataset/sonar.csv', header=None)

# %% [markdown]
# ### 데이터 셋 분리

# %%
dataset = df.values
X = dataset[:,0:60]
Y_obj = dataset[:,60]

# %% [markdown]
# ### 데이터 변환

# %%
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)

# %% [markdown]
# ### 10개의 파일로 쪼갬

# %%
n_fold = 10
skf = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)

# %% [markdown]
# ### 빈 accuracy 배열

# %%
accuracy = []

# %% [markdown]
# ### 모델의 설정, 컴파일, 실행

# %%
for train, test in skf.split(X, Y):
    model = Sequential()
    model.add(Dense(24, input_dim=60, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='mean_squared_error',
                  optimizer='adam',
                  metrics=['accuracy'])
    model.fit(X[train], Y[train], epochs=100, batch_size=5)
    k_accuracy = "%.4f" % (model.evaluate(X[test], Y[test])[1])
    accuracy.append(k_accuracy)
# Out:
# Epoch 1/100
# 187/187 [==============================] - 0s 2ms/step - loss: 0.2469 - accuracy: 0.5348
# Epoch 2/100
# 187/187 [==============================] - 0s 259us/step - loss: 0.2286 - accuracy: 0.7380
# Epoch 3/100
# 187/187 [==============================] - 0s 223us/step - loss: 0.2172 - accuracy: 0.6738
# Epoch 4/100
# 187/187 [==============================] - 0s 226us/step - loss: 0.1973 - accuracy: 0.7219
# Epoch 5/100
# 187/187 [==============================] - 0s 236us/step - loss: 0.1882 - accuracy: 0.7701
# Epoch 6/100
# 187/187 [==============================] - 0s 236us/step - loss: 0.1747 - accuracy: 0.7968
# Epoch 7/100
# 187/187 [==============================] - 0s 280us/step - loss: 0.1661 - accuracy: 0.8289
# Epoch 8/100
# 187/187 [==============================] - 0s 271us/step - loss: 0.1585 - accuracy: 0.7968
# Epoch 9/100
# 187/187 [==============================] - 0s 248us/step - loss: 0.1505 - accuracy: 0.8128
# Epoch 10/100
# ...

# %% [markdown]
# ### 결과 출력

# %%
print("\n %.f fold accuracy:" % n_fold, accuracy)
# Out:
#  10 fold accuracy: ['0.7143', '0.6667', '0.7619', '0.7619', '0.8571', '0.7619', '0.8571', '0.8095', '0.9000', '0.8500']
